# %%
import numpy
import pandas
import datetime

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers.core import Dropout
from keras.layers.normalization import BatchNormalization

from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# Using Theano backend.

# %%
############################################################
# SibSp　-> one hot enconding
# One hot encoding SibSp
############################################################
def get_dummies_sibSp(df_all, df, df_test) :

    categories = set(df_all['SibSp'].unique())
    df['SibSp'] = pandas.Categorical(df['SibSp'], categories=categories)
    df_test['SibSp'] = pandas.Categorical(df_test['SibSp'], categories=categories)

    df = pandas.get_dummies(df, columns=['SibSp'])
    df_test = pandas.get_dummies(df_test, columns=['SibSp'])

    return df, df_test

############################################################
# Parch　-> one hot enconding
# One hot encoding SibSp
############################################################
def get_dummies_parch(df_all, df, df_test) :

    categories = set(df_all['Parch'].unique())
    df['Parch'] = pandas.Categorical(df['Parch'], categories=categories)
    df_test['Parch'] = pandas.Categorical(df_test['Parch'], categories=categories)

    df = pandas.get_dummies(df, columns=['Parch'])
    df_test = pandas.get_dummies(df_test, columns=['Parch'])

    return df, df_test

############################################################
# Ticket　-> one hot enconding
# One hot encoding Ticket
############################################################
def get_dummies_ticket(df_all, df, df_test) :

    ticket_values = df_all['Ticket'].value_counts()
    ticket_values = ticket_values[ticket_values > 1]
    ticket_values = pandas.Series(ticket_values.index, name='Ticket')
    categories = set(ticket_values.tolist())
    df['Ticket'] = pandas.Categorical(df['Ticket'], categories=categories)
    df_test['Ticket'] = pandas.Categorical(df_test['Ticket'], categories=categories)

    df = pandas.get_dummies(df, columns=['Ticket'])
    df_test = pandas.get_dummies(df_test, columns=['Ticket'])

    return df, df_test

############################################################
# Cabin
## 
############################################################
def get_dummies_Cabin(df_all, df, df_test) :

    Cabin_values = df_all['Cabin'].value_counts()
    Cabin_values = Cabin_values[Cabin_values > 1]
    Cabin_values = pandas.Series(Cabin_values.index, name='Cabin')
    categories = set(Cabin_values.tolist())
    df['Cabin'] = pandas.Categorical(df['Cabin'], categories=categories)
    df_test['Cabin'] = pandas.Categorical(df_test['Cabin'], categories=categories)

    df = pandas.get_dummies(df, columns=['Cabin'])
    df_test = pandas.get_dummies(df_test, columns=['Cabin'])

    return df, df_test

############################################################
# Standardization
############################################################
def standardization(df, df_test) :

    standard = StandardScaler()
    df_std = pandas.DataFrame(standard.fit_transform(df[['Pclass', 'Fare']].values), columns=['Pclass', 'Fare'])
    df.loc[:,'Pclass'] = df_std['Pclass']
    df.loc[:,'Fare'] = df_std['Fare']

    df_test_std = pandas.DataFrame(standard.transform(df_test[['Pclass', 'Fare']].values), columns=['Pclass', 'Fare'])
    df_test.loc[:,'Pclass'] = df_test_std['Pclass']
    df_test.loc[:,'Fare'] = df_test_std['Fare']

    return df, df_test

############################################################
# prepare Data
############################################################
def prepareData() :

    ##############################
    # Data preprocessing
    # Extract necessary items
    ##############################
    # Load gender_submission.csv
    df = pandas.read_csv('train.csv')
    df_test = pandas.read_csv('test.csv')

    df_all = pandas.concat([df, df_test], sort=False)

    df_test_index = df_test[['PassengerId']]

    df = df[['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Fare', 'Age', 'Name']]
    df_test = df_test[['Pclass', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Fare', 'Age', 'Name']]

    ##############################
    # Data preprocessing
    # Fill or remove missing values
    ##############################
    df = df[df['Fare'] != 5].reset_index(drop=True)
    df = df[df['Fare'] != 0].reset_index(drop=True)

    ##############################
    # Data preprocessing
    # Digitize labels
    ##############################
    # Gender
    ##############################
    encoder_sex = LabelEncoder()
    df['Sex'] = encoder_sex.fit_transform(df['Sex'].values)
    df_test['Sex'] = encoder_sex.transform(df_test['Sex'].values)

    ##############################
    # Data preprocessing
    # One-Hot Encoding
    ##############################
    ##############################
    # SibSp
    ##############################
    df, df_test = get_dummies_sibSp(df_all, df, df_test)

    ##############################
    # Parch
    ##############################
    df, df_test = get_dummies_parch(df_all, df, df_test)

    ##############################
    # Ticket
    ##############################
    df, df_test = get_dummies_ticket(df_all, df, df_test)

    ##############################
    # Cabin
    ##############################
    df, df_test = get_dummies_Cabin(df_all, df, df_test)
    
    ##############################
    df, df_test = standardization(df, df_test)

    ##############################
    # Data preprocessing
    # Fill or remove missing values
    ##############################
    df.fillna({'Fare':0}, inplace=True)
    df_test.fillna({'Fare':0}, inplace=True)
    df.fillna({'Cabin':0}, inplace=True)
    df_test.fillna({'Cabin':0}, inplace=True) 
    ##############################
    # Age 
    ## class별로 Fare을 가지고 나이를 추정한 다음, 추정 그룹의 평균으로 결측치를 채움
    ##############################
    chlid_Age_mean = df[(df["Age"] < 16)]["Age"].mean()
    class3_Age_mean = df[(df["Pclass"]==3)]["Age"].mean()
    class2_Age_mean = df[(df["Pclass"]==2)]["Age"].mean()
    class1_Age_mean = df[(df["Pclass"]==1)]["Age"].mean()

    df.loc[df["Age"].isna() & (df["Pclass"]==3) & (df["Fare"] > 10)]["Age"] = class3_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==3) & (df["Fare"] < 10)]["Age"] = chlid_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==2) & (df["Fare"] == 0)]["Age"] = chlid_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==2) & (df["Fare"] != 0)]["Age"] = class2_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==1) & (df["Fare"] == 0)]["Age"] = chlid_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==1) & (df["Fare"] != 0)]["Age"] = class1_Age_mean
    
    df["Age_Category"] = df["Age"].apply(lambda x: 1 if (x >= 16) & (x < 32)\
                                        else 2 if (x >= 32) & (x < 48)\
                                        else 3 if (x >= 48) & (x < 64)\
                                        else 4 if (x >= 64)\
                                        else 0 if (x < 16)\
                                        else -1)
    
    df["Age"] = df["Age_Category"]
    df.drop(["Age_Category"], axis=1)
    
    chlid_Age_mean = df_test[(df_test["Age"] < 16)]["Age"].mean()
    class3_Age_mean = df_test[(df_test["Pclass"]==3)]["Age"].mean()
    class2_Age_mean = df_test[(df_test["Pclass"]==2)]["Age"].mean()
    class1_Age_mean = df_test[(df_test["Pclass"]==1)]["Age"].mean()

    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==3) & (df_test["Fare"] > 10)]["Age"] = class3_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==3) & (df_test["Fare"] < 10)]["Age"] = chlid_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==2) & (df_test["Fare"] == 0)]["Age"] = chlid_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==2) & (df_test["Fare"] != 0)]["Age"] = class2_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==1) & (df_test["Fare"] == 0)]["Age"] = chlid_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==1) & (df_test["Fare"] != 0)]["Age"] = class1_Age_mean
    
    df_test["Age_Category"] = df_test["Age"].apply(lambda x: 1 if (x >= 16) & (x < 32)\
                                        else 2 if (x >= 32) & (x < 48)\
                                        else 3 if (x >= 48) & (x < 64)\
                                        else 4 if (x >= 64)\
                                        else 0 if (x < 16)\
                                        else -1)
    
    df_test["Age"] = df_test["Age_Category"]
    df_test.drop(["Age_Category"], axis=1)
    
    ##############################
    # Title
    ##############################
    df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

    df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don',\
                                             'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],\
                                             'Rare')
    df['Title'] = df['Title'].replace('Mlle', 'Miss')
    df['Title'] = df['Title'].replace('Ms', 'Miss')
    df['Title'] = df['Title'].replace('Mme', 'Mrs')
    
    _, df['Title'] = numpy.unique(df['Title'], return_inverse=True)
    
    df_test['Title'] = df_test.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

    df_test['Title'] = df_test['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don',\
                                             'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],\
                                             'Rare')
    df_test['Title'] = df_test['Title'].replace('Mlle', 'Miss')
    df_test['Title'] = df_test['Title'].replace('Ms', 'Miss')
    df_test['Title'] = df_test['Title'].replace('Mme', 'Mrs')
    
    _, df_test['Title'] = numpy.unique(df_test['Title'], return_inverse=True)
    
    ##############################
    # Split training data and test data
    ##############################
    x = df.drop(columns='Survived')
    x = x.drop(columns='Name')
    df_test = df_test.drop(columns = "Name")
    y = df[['Survived']]

    return x, y, df_test, df_test_index

##############################
# Model -> 5perceptron
##############################
def create_model_5dim_layer_perceptron(input_dim, \
                                       activation="relu", \
                                       optimizer="adam", \
                                       out_dim=100, \
                                       dropout=0.5):

    model = Sequential()

    # Input - Hidden1
    model.add(Dense(input_dim=input_dim, units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))

    # Hidden1 - Hidden2
    model.add(Dense(units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))

    # Hidden2 - Hidden3
    model.add(Dense(units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))
    
    model.add(Dense(units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))

    # Hidden3 - Output
    model.add(Dense(units=1))
    model.add(Activation("sigmoid"))

    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    print(f"activation: {activation}, optimizer={optimizer}")
    return model

# %%
x_train, y_train, x_test, y_test_index = prepareData()

model = KerasClassifier(build_fn=create_model_5dim_layer_perceptron, verbose=1)
param_grid ={
    'input_dim':[len(x_train.columns)],
    'activation': ["relu", "sigmoid", "tanh"],
    'optimizer' :["adam", 'adagrad'],
    'out_dim':[300,500,700],
    'dropout':[0.2,0.5],
    
}
grid= GridSearchCV(estimator=model,
                   param_grid=param_grid)

# %%
# Training
# fit = model.fit(x_train, y_train, epochs=40, batch_size=16, verbose=2)
fit = grid.fit(x_train, y_train, epochs=25, batch_size=16, verbose=2)
print("="*30)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5834 - accuracy: 0.7243
# Epoch 2/25
#  - 0s - loss: 0.4951 - accuracy: 0.7800
# Epoch 3/25
#  - 1s - loss: 0.4831 - accuracy: 0.8014
# Epoch 4/25
#  - 0s - loss: 0.4413 - accuracy: 0.8200
# Epoch 5/25
#  - 1s - loss: 0.3974 - accuracy: 0.8386
# Epoch 6/25
#  - 0s - loss: 0.4091 - accuracy: 0.8343
# Epoch 7/25
#  - 1s - loss: 0.3810 - accuracy: 0.8500
# Epoch 8/25
#  - 1s - loss: 0.3574 - accuracy: 0.8586
# Epoch 9/25
#  - 1s - loss: 0.3758 - accuracy: 0.8457
# Epoch 10/25
#  - 1s - loss: 0.3445 - accuracy: 0.8700
# Epoch 11/25
#  - 1s - loss: 0.3367 - accuracy: 0.8686
# Epoch 12/25
#  - 1s - loss: 0.3053 - accuracy: 0.8786
# Epoch 13/25
#  - 1s - loss: 0.2911 - accuracy: 0.8871
# Epoch 14/25
#  - 1s - loss: 0.2948 - accuracy: 0.8757
# Epoch 15/25
#  - 1s - loss: 0.3217 - accuracy: 0.8771
# Epoch 16/25
#  - 1s - loss: 0.3037 - accuracy: 0.8886
# Epoch 17/25
#  - 1s - loss: 0.2811 - accuracy: 0.8857
# Epoch 18/25
#  - 0s - loss: 0.3063 - accuracy: 0.8900
# Epoch 19/25
#  - 1s - loss: 0.2841 - accuracy: 0.8843
# Epoch 20/25
#  - 0s - loss: 0.3227 - accuracy: 0.8729
# Epoch 21/25
#  - 1s - loss: 0.2781 - accuracy: 0.8929
# Epoch 22/25
#  - 1s - loss: 0.2887 - accuracy: 0.8886
# Epoch 23/25
#  - 1s - loss: 0.2745 - accuracy: 0.8857
# Epoch 24/25
#  - 1s - loss: 0.2916 - accuracy: 0.8829
# Epoch 25/25
#  - 1s - loss: 0.2936 - accuracy: 0.8929
# 175/175 [==============================] - 0s 541us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5629 - accuracy: 0.7286
# Epoch 2/25
#  - 1s - loss: 0.5156 - accuracy: 0.7857
# Epoch 3/25
#  - 1s - loss: 0.4581 - accuracy: 0.8143
# Epoch 4/25
#  - 1s - loss: 0.4112 - accuracy: 0.8329
# Epoch 5/25
#  - 0s - loss: 0.3844 - accuracy: 0.8486
# Epoch 6/25
#  - 1s - loss: 0.3645 - accuracy: 0.8586
# Epoch 7/25
#  - 1s - loss: 0.3355 - accuracy: 0.8671
# Epoch 8/25
#  - 0s - loss: 0.3455 - accuracy: 0.8686
# Epoch 9/25
#  - 1s - loss: 0.3100 - accuracy: 0.8743
# Epoch 10/25
#  - 1s - loss: 0.3169 - accuracy: 0.8671
# Epoch 11/25
#  - 1s - loss: 0.3054 - accuracy: 0.8843
# Epoch 12/25
#  - 1s - loss: 0.3219 - accuracy: 0.8829
# Epoch 13/25
#  - 0s - loss: 0.2998 - accuracy: 0.8871
# Epoch 14/25
#  - 1s - loss: 0.3053 - accuracy: 0.8914
# Epoch 15/25
#  - 1s - loss: 0.2868 - accuracy: 0.8886
# Epoch 16/25
#  - 0s - loss: 0.2474 - accuracy: 0.9057
# Epoch 17/25
#  - 1s - loss: 0.2826 - accuracy: 0.8900
# Epoch 18/25
#  - 1s - loss: 0.2696 - accuracy: 0.8943
# Epoch 19/25
#  - 0s - loss: 0.2745 - accuracy: 0.8986
# Epoch 20/25
#  - 1s - loss: 0.2924 - accuracy: 0.9000
# Epoch 21/25
#  - 1s - loss: 0.2942 - accuracy: 0.8986
# Epoch 22/25
#  - 1s - loss: 0.2526 - accuracy: 0.8957
# Epoch 23/25
#  - 1s - loss: 0.2962 - accuracy: 0.8914
# Epoch 24/25
#  - 0s - loss: 0.2643 - accuracy: 0.9057
# Epoch 25/25
#  - 1s - loss: 0.2691 - accuracy: 0.8943
# 175/175 [==============================] - 0s 302us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 0s - loss: 0.6028 - accuracy: 0.7129
# Epoch 2/25
#  - 1s - loss: 0.4836 - accuracy: 0.7943
# Epoch 3/25
#  - 0s - loss: 0.4530 - accuracy: 0.8043
# Epoch 4/25
#  - 1s - loss: 0.4157 - accuracy: 0.8286
# Epoch 5/25
#  - 1s - loss: 0.3916 - accuracy: 0.8443
# Epoch 6/25
#  - 0s - loss: 0.3828 - accuracy: 0.8429
# Epoch 7/25
#  - 1s - loss: 0.3615 - accuracy: 0.8671
# Epoch 8/25
#  - 0s - loss: 0.4025 - accuracy: 0.8286
# Epoch 9/25
#  - 1s - loss: 0.3390 - accuracy: 0.8643
# Epoch 10/25
#  - 1s - loss: 0.3380 - accuracy: 0.8714
# Epoch 11/25
#  - 1s - loss: 0.3172 - accuracy: 0.8743
# Epoch 12/25
#  - 1s - loss: 0.3178 - accuracy: 0.8743
# Epoch 13/25
#  - 1s - loss: 0.3141 - accuracy: 0.8786
# Epoch 14/25
#  - 1s - loss: 0.3149 - accuracy: 0.8786
# Epoch 15/25
#  - 1s - loss: 0.2949 - accuracy: 0.8871
# Epoch 16/25
#  - 0s - loss: 0.3116 - accuracy: 0.8771
# Epoch 17/25
#  - 1s - loss: 0.3190 - accuracy: 0.8857
# Epoch 18/25
#  - 0s - loss: 0.2804 - accuracy: 0.8843
# Epoch 19/25
#  - 1s - loss: 0.2919 - accuracy: 0.8843
# Epoch 20/25
#  - 0s - loss: 0.2790 - accuracy: 0.8900
# Epoch 21/25
#  - 1s - loss: 0.2650 - accuracy: 0.9000
# Epoch 22/25
#  - 0s - loss: 0.2866 - accuracy: 0.8886
# Epoch 23/25
#  - 1s - loss: 0.2721 - accuracy: 0.9000
# Epoch 24/25
#  - 1s - loss: 0.2673 - accuracy: 0.8957
# Epoch 25/25
#  - 0s - loss: 0.2700 - accuracy: 0.8971
# 175/175 [==============================] - 0s 348us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6274 - accuracy: 0.6971
# Epoch 2/25
#  - 0s - loss: 0.4800 - accuracy: 0.7914
# Epoch 3/25
#  - 1s - loss: 0.4496 - accuracy: 0.8200
# Epoch 4/25
#  - 0s - loss: 0.4600 - accuracy: 0.8143
# Epoch 5/25
#  - 1s - loss: 0.4114 - accuracy: 0.8371
# Epoch 6/25
#  - 1s - loss: 0.3772 - accuracy: 0.8443
# Epoch 7/25
#  - 0s - loss: 0.3624 - accuracy: 0.8514
# Epoch 8/25
#  - 1s - loss: 0.3537 - accuracy: 0.8643
# Epoch 9/25
#  - 1s - loss: 0.3082 - accuracy: 0.8800
# Epoch 10/25
#  - 0s - loss: 0.3132 - accuracy: 0.8829
# Epoch 11/25
#  - 1s - loss: 0.3508 - accuracy: 0.8614
# Epoch 12/25
#  - 0s - loss: 0.2995 - accuracy: 0.8857
# Epoch 13/25
#  - 1s - loss: 0.2880 - accuracy: 0.8786
# Epoch 14/25
#  - 1s - loss: 0.2935 - accuracy: 0.8814
# Epoch 15/25
#  - 1s - loss: 0.2883 - accuracy: 0.8929
# Epoch 16/25
#  - 1s - loss: 0.3242 - accuracy: 0.8771
# Epoch 17/25
#  - 1s - loss: 0.3042 - accuracy: 0.8700
# Epoch 18/25
#  - 1s - loss: 0.2833 - accuracy: 0.9071
# Epoch 19/25
#  - 0s - loss: 0.2818 - accuracy: 0.8957
# Epoch 20/25
#  - 1s - loss: 0.2880 - accuracy: 0.8857
# Epoch 21/25
#  - 0s - loss: 0.2717 - accuracy: 0.8971
# Epoch 22/25
#  - 1s - loss: 0.2598 - accuracy: 0.9000
# Epoch 23/25
#  - 1s - loss: 0.2634 - accuracy: 0.9086
# Epoch 24/25
#  - 0s - loss: 0.2727 - accuracy: 0.9014
# Epoch 25/25
#  - 1s - loss: 0.2878 - accuracy: 0.9000
# 175/175 [==============================] - 0s 353us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6401 - accuracy: 0.6929
# Epoch 2/25
#  - 1s - loss: 0.5142 - accuracy: 0.7743
# Epoch 3/25
#  - 1s - loss: 0.4651 - accuracy: 0.8057
# Epoch 4/25
#  - 0s - loss: 0.4426 - accuracy: 0.8286
# Epoch 5/25
#  - 1s - loss: 0.4171 - accuracy: 0.8329
# Epoch 6/25
#  - 1s - loss: 0.4063 - accuracy: 0.8357
# Epoch 7/25
#  - 0s - loss: 0.3988 - accuracy: 0.8357
# Epoch 8/25
#  - 0s - loss: 0.3487 - accuracy: 0.8657
# Epoch 9/25
#  - 1s - loss: 0.3727 - accuracy: 0.8557
# Epoch 10/25
#  - 0s - loss: 0.3444 - accuracy: 0.8686
# Epoch 11/25
#  - 1s - loss: 0.3301 - accuracy: 0.8714
# Epoch 12/25
#  - 0s - loss: 0.3188 - accuracy: 0.8700
# Epoch 13/25
#  - 1s - loss: 0.2888 - accuracy: 0.8843
# Epoch 14/25
#  - 1s - loss: 0.3145 - accuracy: 0.8857
# Epoch 15/25
#  - 0s - loss: 0.3270 - accuracy: 0.8757
# Epoch 16/25
#  - 1s - loss: 0.3409 - accuracy: 0.8714
# Epoch 17/25
#  - 1s - loss: 0.3079 - accuracy: 0.8914
# Epoch 18/25
#  - 0s - loss: 0.3154 - accuracy: 0.8757
# Epoch 19/25
#  - 1s - loss: 0.3145 - accuracy: 0.8686
# Epoch 20/25
#  - 1s - loss: 0.2944 - accuracy: 0.8886
# Epoch 21/25
#  - 1s - loss: 0.3072 - accuracy: 0.8771
# Epoch 22/25
#  - 1s - loss: 0.3153 - accuracy: 0.8757
# Epoch 23/25
#  - 1s - loss: 0.2854 - accuracy: 0.8800
# Epoch 24/25
#  - 1s - loss: 0.3084 - accuracy: 0.8843
# Epoch 25/25
#  - 1s - loss: 0.2809 - accuracy: 0.8957
# 175/175 [==============================] - 0s 239us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6175 - accuracy: 0.7314
# Epoch 2/25
#  - 1s - loss: 0.5743 - accuracy: 0.7857
# Epoch 3/25
#  - 1s - loss: 0.4882 - accuracy: 0.8114
# Epoch 4/25
#  - 1s - loss: 0.3875 - accuracy: 0.8514
# Epoch 5/25
#  - 1s - loss: 0.4204 - accuracy: 0.8286
# Epoch 6/25
#  - 1s - loss: 0.4128 - accuracy: 0.8429
# Epoch 7/25
#  - 1s - loss: 0.3639 - accuracy: 0.8586
# Epoch 8/25
#  - 1s - loss: 0.3324 - accuracy: 0.8743
# Epoch 9/25
#  - 1s - loss: 0.3110 - accuracy: 0.8843
# Epoch 10/25
#  - 1s - loss: 0.3178 - accuracy: 0.8743
# Epoch 11/25
#  - 1s - loss: 0.3378 - accuracy: 0.8829
# Epoch 12/25
#  - 1s - loss: 0.3204 - accuracy: 0.8729
# Epoch 13/25
#  - 1s - loss: 0.3228 - accuracy: 0.8757
# Epoch 14/25
#  - 1s - loss: 0.3045 - accuracy: 0.8786
# Epoch 15/25
#  - 1s - loss: 0.3130 - accuracy: 0.8886
# Epoch 16/25
#  - 1s - loss: 0.3026 - accuracy: 0.8800
# Epoch 17/25
#  - 1s - loss: 0.2933 - accuracy: 0.8886
# Epoch 18/25
#  - 1s - loss: 0.2802 - accuracy: 0.8843
# Epoch 19/25
#  - 1s - loss: 0.2948 - accuracy: 0.8914
# Epoch 20/25
#  - 1s - loss: 0.2879 - accuracy: 0.8971
# Epoch 21/25
#  - 1s - loss: 0.2550 - accuracy: 0.8943
# Epoch 22/25
#  - 1s - loss: 0.2701 - accuracy: 0.8900
# Epoch 23/25
#  - 1s - loss: 0.3110 - accuracy: 0.8829
# Epoch 24/25
#  - 1s - loss: 0.2746 - accuracy: 0.8914
# Epoch 25/25
#  - 1s - loss: 0.2664 - accuracy: 0.8943
# 175/175 [==============================] - 0s 473us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5928 - accuracy: 0.7400
# Epoch 2/25
#  - 1s - loss: 0.5164 - accuracy: 0.7943
# Epoch 3/25
#  - 1s - loss: 0.4698 - accuracy: 0.8057
# Epoch 4/25
#  - 1s - loss: 0.4192 - accuracy: 0.8343
# Epoch 5/25
#  - 1s - loss: 0.3769 - accuracy: 0.8557
# Epoch 6/25
#  - 1s - loss: 0.3858 - accuracy: 0.8571
# Epoch 7/25
#  - 1s - loss: 0.3132 - accuracy: 0.8743
# Epoch 8/25
#  - 1s - loss: 0.3178 - accuracy: 0.8871
# Epoch 9/25
#  - 1s - loss: 0.3165 - accuracy: 0.8814
# Epoch 10/25
#  - 1s - loss: 0.3256 - accuracy: 0.8900
# Epoch 11/25
#  - 1s - loss: 0.3104 - accuracy: 0.8814
# Epoch 12/25
#  - 1s - loss: 0.2901 - accuracy: 0.8886
# Epoch 13/25
#  - 1s - loss: 0.2742 - accuracy: 0.9043
# Epoch 14/25
#  - 1s - loss: 0.2885 - accuracy: 0.8943
# Epoch 15/25
#  - 1s - loss: 0.3032 - accuracy: 0.8914
# Epoch 16/25
#  - 1s - loss: 0.2804 - accuracy: 0.9071
# Epoch 17/25
#  - 1s - loss: 0.2461 - accuracy: 0.8986
# Epoch 18/25
#  - 1s - loss: 0.3060 - accuracy: 0.8843
# Epoch 19/25
#  - 1s - loss: 0.2684 - accuracy: 0.8929
# Epoch 20/25
#  - 1s - loss: 0.2570 - accuracy: 0.8957
# Epoch 21/25
#  - 1s - loss: 0.2722 - accuracy: 0.8986
# Epoch 22/25
#  - 1s - loss: 0.2693 - accuracy: 0.9014
# Epoch 23/25
#  - 1s - loss: 0.2456 - accuracy: 0.9000
# Epoch 24/25
#  - 1s - loss: 0.2442 - accuracy: 0.9129
# Epoch 25/25
#  - 1s - loss: 0.2365 - accuracy: 0.9043
# 175/175 [==============================] - 0s 400us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6611 - accuracy: 0.7086
# Epoch 2/25
#  - 1s - loss: 0.5638 - accuracy: 0.7643
# Epoch 3/25
#  - 1s - loss: 0.4760 - accuracy: 0.8100
# Epoch 4/25
#  - 1s - loss: 0.4773 - accuracy: 0.8143
# Epoch 5/25
#  - 1s - loss: 0.4046 - accuracy: 0.8429
# Epoch 6/25
#  - 1s - loss: 0.3855 - accuracy: 0.8586
# Epoch 7/25
#  - 1s - loss: 0.3554 - accuracy: 0.8657
# Epoch 8/25
#  - 1s - loss: 0.3729 - accuracy: 0.8486
# Epoch 9/25
#  - 1s - loss: 0.3201 - accuracy: 0.8786
# Epoch 10/25
#  - 1s - loss: 0.3271 - accuracy: 0.8771
# Epoch 11/25
#  - 1s - loss: 0.2855 - accuracy: 0.8929
# Epoch 12/25
#  - 1s - loss: 0.3285 - accuracy: 0.8786
# Epoch 13/25
#  - 1s - loss: 0.3122 - accuracy: 0.8786
# Epoch 14/25
#  - 1s - loss: 0.3183 - accuracy: 0.8743
# Epoch 15/25
#  - 1s - loss: 0.3005 - accuracy: 0.8857
# Epoch 16/25
#  - 1s - loss: 0.3254 - accuracy: 0.8743
# Epoch 17/25
#  - 1s - loss: 0.2984 - accuracy: 0.8886
# Epoch 18/25
#  - 1s - loss: 0.3143 - accuracy: 0.8743
# Epoch 19/25
#  - 1s - loss: 0.2857 - accuracy: 0.8943
# Epoch 20/25
#  - 1s - loss: 0.2629 - accuracy: 0.8986
# Epoch 21/25
#  - 1s - loss: 0.2753 - accuracy: 0.8857
# Epoch 22/25
#  - 1s - loss: 0.3033 - accuracy: 0.8829
# Epoch 23/25
#  - 1s - loss: 0.2615 - accuracy: 0.9029
# Epoch 24/25
#  - 1s - loss: 0.2565 - accuracy: 0.8943
# Epoch 25/25
#  - 1s - loss: 0.2830 - accuracy: 0.8886
# 175/175 [==============================] - 0s 524us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6709 - accuracy: 0.6929
# Epoch 2/25
#  - 1s - loss: 0.5653 - accuracy: 0.7714
# Epoch 3/25
#  - 1s - loss: 0.4551 - accuracy: 0.8257
# Epoch 4/25
#  - 1s - loss: 0.4197 - accuracy: 0.8414
# Epoch 5/25
#  - 1s - loss: 0.4008 - accuracy: 0.8414
# Epoch 6/25
#  - 1s - loss: 0.3727 - accuracy: 0.8614
# Epoch 7/25
#  - 1s - loss: 0.3493 - accuracy: 0.8700
# Epoch 8/25
#  - 1s - loss: 0.3401 - accuracy: 0.8686
# Epoch 9/25
#  - 1s - loss: 0.3311 - accuracy: 0.8757
# Epoch 10/25
#  - 1s - loss: 0.3434 - accuracy: 0.8757
# Epoch 11/25
#  - 1s - loss: 0.3144 - accuracy: 0.8857
# Epoch 12/25
#  - 1s - loss: 0.2924 - accuracy: 0.8957
# Epoch 13/25
#  - 1s - loss: 0.3233 - accuracy: 0.8657
# Epoch 14/25
#  - 1s - loss: 0.3229 - accuracy: 0.8657
# Epoch 15/25
#  - 1s - loss: 0.2999 - accuracy: 0.8914
# Epoch 16/25
#  - 1s - loss: 0.2809 - accuracy: 0.8929
# Epoch 17/25
#  - 1s - loss: 0.2940 - accuracy: 0.8871
# Epoch 18/25
#  - 1s - loss: 0.2655 - accuracy: 0.9086
# Epoch 19/25
#  - 1s - loss: 0.2873 - accuracy: 0.8871
# Epoch 20/25
#  - 1s - loss: 0.3028 - accuracy: 0.8886
# Epoch 21/25
#  - 1s - loss: 0.2688 - accuracy: 0.8943
# Epoch 22/25
#  - 1s - loss: 0.2747 - accuracy: 0.8929
# Epoch 23/25
#  - 1s - loss: 0.2758 - accuracy: 0.8957
# Epoch 24/25
#  - 1s - loss: 0.2736 - accuracy: 0.8957
# Epoch 25/25
#  - 1s - loss: 0.2573 - accuracy: 0.8986
# 175/175 [==============================] - 0s 358us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6485 - accuracy: 0.7143
# Epoch 2/25
#  - 1s - loss: 0.5471 - accuracy: 0.7671
# Epoch 3/25
#  - 1s - loss: 0.5055 - accuracy: 0.7943
# Epoch 4/25
#  - 1s - loss: 0.4157 - accuracy: 0.8214
# Epoch 5/25
#  - 1s - loss: 0.4007 - accuracy: 0.8329
# Epoch 6/25
#  - 1s - loss: 0.3801 - accuracy: 0.8471
# Epoch 7/25
#  - 1s - loss: 0.3641 - accuracy: 0.8714
# Epoch 8/25
#  - 1s - loss: 0.3751 - accuracy: 0.8600
# Epoch 9/25
#  - 1s - loss: 0.3693 - accuracy: 0.8629
# Epoch 10/25
#  - 1s - loss: 0.3288 - accuracy: 0.8786
# Epoch 11/25
#  - 1s - loss: 0.3305 - accuracy: 0.8743
# Epoch 12/25
#  - 1s - loss: 0.2933 - accuracy: 0.8857
# Epoch 13/25
#  - 1s - loss: 0.3352 - accuracy: 0.8643
# Epoch 14/25
#  - 1s - loss: 0.3327 - accuracy: 0.8786
# Epoch 15/25
#  - 1s - loss: 0.3171 - accuracy: 0.8786
# Epoch 16/25
#  - 1s - loss: 0.3220 - accuracy: 0.8714
# Epoch 17/25
#  - 1s - loss: 0.2907 - accuracy: 0.8757
# Epoch 18/25
#  - 1s - loss: 0.2953 - accuracy: 0.8886
# Epoch 19/25
#  - 1s - loss: 0.2856 - accuracy: 0.8871
# Epoch 20/25
#  - 1s - loss: 0.2807 - accuracy: 0.8886
# Epoch 21/25
#  - 1s - loss: 0.2839 - accuracy: 0.8871
# Epoch 22/25
#  - 1s - loss: 0.2902 - accuracy: 0.8843
# Epoch 23/25
#  - 1s - loss: 0.2830 - accuracy: 0.8757
# Epoch 24/25
#  - 1s - loss: 0.2729 - accuracy: 0.8929
# Epoch 25/25
#  - 1s - loss: 0.2735 - accuracy: 0.8871
# 175/175 [==============================] - 0s 427us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 2s - loss: 0.7002 - accuracy: 0.7057
# Epoch 2/25
#  - 2s - loss: 0.5533 - accuracy: 0.7843
# Epoch 3/25
#  - 2s - loss: 0.4564 - accuracy: 0.8257
# Epoch 4/25
#  - 2s - loss: 0.4669 - accuracy: 0.8171
# Epoch 5/25
#  - 2s - loss: 0.4067 - accuracy: 0.8443
# Epoch 6/25
#  - 2s - loss: 0.4285 - accuracy: 0.8343
# Epoch 7/25
#  - 2s - loss: 0.3596 - accuracy: 0.8529
# Epoch 8/25
#  - 2s - loss: 0.3054 - accuracy: 0.8971
# Epoch 9/25
#  - 2s - loss: 0.3277 - accuracy: 0.8786
# Epoch 10/25
#  - 2s - loss: 0.3051 - accuracy: 0.8771
# Epoch 11/25
#  - 2s - loss: 0.3407 - accuracy: 0.8800
# Epoch 12/25
#  - 2s - loss: 0.3202 - accuracy: 0.8843
# Epoch 13/25
#  - 2s - loss: 0.2888 - accuracy: 0.8829
# Epoch 14/25
#  - 2s - loss: 0.3251 - accuracy: 0.8671
# Epoch 15/25
#  - 2s - loss: 0.3332 - accuracy: 0.8700
# Epoch 16/25
#  - 2s - loss: 0.3341 - accuracy: 0.8943
# Epoch 17/25
#  - 2s - loss: 0.2689 - accuracy: 0.8971
# Epoch 18/25
#  - 2s - loss: 0.2884 - accuracy: 0.8957
# Epoch 19/25
#  - 2s - loss: 0.2845 - accuracy: 0.8929
# Epoch 20/25
#  - 2s - loss: 0.2810 - accuracy: 0.8843
# Epoch 21/25
#  - 2s - loss: 0.2799 - accuracy: 0.8943
# Epoch 22/25
#  - 2s - loss: 0.3075 - accuracy: 0.8914
# Epoch 23/25
#  - 2s - loss: 0.2821 - accuracy: 0.8857
# Epoch 24/25
#  - 2s - loss: 0.2581 - accuracy: 0.8943
# Epoch 25/25
#  - 2s - loss: 0.2822 - accuracy: 0.8929
# 175/175 [==============================] - 0s 456us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 2s - loss: 0.7187 - accuracy: 0.6914
# Epoch 2/25
#  - 2s - loss: 0.4890 - accuracy: 0.8100
# Epoch 3/25
#  - 2s - loss: 0.4522 - accuracy: 0.8214
# Epoch 4/25
#  - 2s - loss: 0.3757 - accuracy: 0.8529
# Epoch 5/25
#  - 2s - loss: 0.4164 - accuracy: 0.8471
# Epoch 6/25
#  - 2s - loss: 0.3464 - accuracy: 0.8657
# Epoch 7/25
#  - 2s - loss: 0.3490 - accuracy: 0.8814
# Epoch 8/25
#  - 2s - loss: 0.3411 - accuracy: 0.8586
# Epoch 9/25
#  - 2s - loss: 0.3021 - accuracy: 0.8800
# Epoch 10/25
#  - 2s - loss: 0.3283 - accuracy: 0.8786
# Epoch 11/25
#  - 2s - loss: 0.3085 - accuracy: 0.8771
# Epoch 12/25
#  - 2s - loss: 0.2671 - accuracy: 0.8971
# Epoch 13/25
#  - 2s - loss: 0.2569 - accuracy: 0.9057
# Epoch 14/25
#  - 2s - loss: 0.2980 - accuracy: 0.8957
# Epoch 15/25
#  - 2s - loss: 0.3100 - accuracy: 0.8771
# Epoch 16/25
#  - 2s - loss: 0.3184 - accuracy: 0.8857
# Epoch 17/25
#  - 2s - loss: 0.2781 - accuracy: 0.8971
# Epoch 18/25
#  - 2s - loss: 0.2926 - accuracy: 0.8886
# Epoch 19/25
#  - 2s - loss: 0.2598 - accuracy: 0.9071
# Epoch 20/25
#  - 2s - loss: 0.2777 - accuracy: 0.8957
# Epoch 21/25
#  - 2s - loss: 0.2469 - accuracy: 0.9129
# Epoch 22/25
#  - 2s - loss: 0.2714 - accuracy: 0.8943
# Epoch 23/25
#  - 2s - loss: 0.2491 - accuracy: 0.9071
# Epoch 24/25
#  - 2s - loss: 0.2551 - accuracy: 0.9000
# Epoch 25/25
#  - 2s - loss: 0.2770 - accuracy: 0.8957
# 175/175 [==============================] - 0s 627us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 2s - loss: 0.7211 - accuracy: 0.7171
# Epoch 2/25
#  - 2s - loss: 0.5467 - accuracy: 0.7857
# Epoch 3/25
#  - 2s - loss: 0.4869 - accuracy: 0.8029
# Epoch 4/25
#  - 2s - loss: 0.4798 - accuracy: 0.8214
# Epoch 5/25
#  - 2s - loss: 0.3932 - accuracy: 0.8557
# Epoch 6/25
#  - 2s - loss: 0.3699 - accuracy: 0.8614
# Epoch 7/25
#  - 2s - loss: 0.3477 - accuracy: 0.8700
# Epoch 8/25
#  - 2s - loss: 0.3418 - accuracy: 0.8743
# Epoch 9/25
#  - 2s - loss: 0.3526 - accuracy: 0.8729
# Epoch 10/25
#  - 2s - loss: 0.3510 - accuracy: 0.8671
# Epoch 11/25
#  - 2s - loss: 0.3282 - accuracy: 0.8671
# Epoch 12/25
#  - 2s - loss: 0.2808 - accuracy: 0.8957
# Epoch 13/25
#  - 2s - loss: 0.3189 - accuracy: 0.8900
# Epoch 14/25
#  - 2s - loss: 0.2973 - accuracy: 0.8814
# Epoch 15/25
#  - 2s - loss: 0.2731 - accuracy: 0.8943
# Epoch 16/25
#  - 2s - loss: 0.2670 - accuracy: 0.8943
# Epoch 17/25
#  - 2s - loss: 0.2815 - accuracy: 0.8971
# Epoch 18/25
#  - 2s - loss: 0.3229 - accuracy: 0.8643
# Epoch 19/25
#  - 2s - loss: 0.2689 - accuracy: 0.8986
# Epoch 20/25
#  - 2s - loss: 0.3088 - accuracy: 0.8814
# Epoch 21/25
#  - 2s - loss: 0.2670 - accuracy: 0.9014
# Epoch 22/25
#  - 2s - loss: 0.2776 - accuracy: 0.8957
# Epoch 23/25
#  - 2s - loss: 0.2610 - accuracy: 0.8971
# Epoch 24/25
#  - 2s - loss: 0.2681 - accuracy: 0.8943
# Epoch 25/25
#  - 2s - loss: 0.2791 - accuracy: 0.8957
# 175/175 [==============================] - 0s 570us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 2s - loss: 0.6643 - accuracy: 0.7386
# Epoch 2/25
#  - 2s - loss: 0.5350 - accuracy: 0.7843
# Epoch 3/25
#  - 2s - loss: 0.4599 - accuracy: 0.8286
# Epoch 4/25
#  - 2s - loss: 0.3972 - accuracy: 0.8443
# Epoch 5/25
#  - 2s - loss: 0.4111 - accuracy: 0.8343
# Epoch 6/25
#  - 2s - loss: 0.3456 - accuracy: 0.8643
# Epoch 7/25
#  - 2s - loss: 0.3596 - accuracy: 0.8486
# Epoch 8/25
#  - 2s - loss: 0.3328 - accuracy: 0.8786
# Epoch 9/25
#  - 2s - loss: 0.3264 - accuracy: 0.8757
# Epoch 10/25
#  - 2s - loss: 0.3144 - accuracy: 0.8800
# Epoch 11/25
#  - 1s - loss: 0.3013 - accuracy: 0.8900
# Epoch 12/25
#  - 2s - loss: 0.3025 - accuracy: 0.8929
# Epoch 13/25
#  - 2s - loss: 0.3072 - accuracy: 0.8871
# Epoch 14/25
#  - 2s - loss: 0.3003 - accuracy: 0.8900
# Epoch 15/25
#  - 2s - loss: 0.2894 - accuracy: 0.8886
# Epoch 16/25
#  - 2s - loss: 0.3045 - accuracy: 0.8857
# Epoch 17/25
#  - 2s - loss: 0.2931 - accuracy: 0.8900
# Epoch 18/25
#  - 2s - loss: 0.2806 - accuracy: 0.8843
# Epoch 19/25
#  - 2s - loss: 0.2651 - accuracy: 0.8986
# Epoch 20/25
#  - 2s - loss: 0.2964 - accuracy: 0.8971
# Epoch 21/25
#  - 2s - loss: 0.3014 - accuracy: 0.8914
# Epoch 22/25
#  - 2s - loss: 0.2751 - accuracy: 0.8900
# Epoch 23/25
#  - 2s - loss: 0.3124 - accuracy: 0.8843
# Epoch 24/25
#  - 2s - loss: 0.2695 - accuracy: 0.8971
# Epoch 25/25
#  - 2s - loss: 0.2490 - accuracy: 0.9014
# 175/175 [==============================] - 0s 433us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 2s - loss: 0.7252 - accuracy: 0.6900
# Epoch 2/25
#  - 2s - loss: 0.5861 - accuracy: 0.7771
# Epoch 3/25
#  - 2s - loss: 0.4894 - accuracy: 0.7914
# Epoch 4/25
#  - 2s - loss: 0.4183 - accuracy: 0.8286
# Epoch 5/25
#  - 2s - loss: 0.4337 - accuracy: 0.8229
# Epoch 6/25
#  - 2s - loss: 0.3606 - accuracy: 0.8586
# Epoch 7/25
#  - 2s - loss: 0.3718 - accuracy: 0.8543
# Epoch 8/25
#  - 2s - loss: 0.3508 - accuracy: 0.8657
# Epoch 9/25
#  - 2s - loss: 0.3417 - accuracy: 0.8700
# Epoch 10/25
#  - 2s - loss: 0.3745 - accuracy: 0.8486
# Epoch 11/25
#  - 2s - loss: 0.3249 - accuracy: 0.8771
# Epoch 12/25
#  - 2s - loss: 0.2922 - accuracy: 0.8843
# Epoch 13/25
#  - 2s - loss: 0.3118 - accuracy: 0.8857
# Epoch 14/25
#  - 2s - loss: 0.3320 - accuracy: 0.8600
# Epoch 15/25
#  - 2s - loss: 0.3018 - accuracy: 0.8814
# Epoch 16/25
#  - 2s - loss: 0.3073 - accuracy: 0.8929
# Epoch 17/25
#  - 2s - loss: 0.2781 - accuracy: 0.8900
# Epoch 18/25
#  - 2s - loss: 0.2931 - accuracy: 0.8843
# Epoch 19/25
#  - 2s - loss: 0.3303 - accuracy: 0.8686
# Epoch 20/25
#  - 2s - loss: 0.2871 - accuracy: 0.8914
# Epoch 21/25
#  - 2s - loss: 0.2794 - accuracy: 0.8871
# Epoch 22/25
#  - 2s - loss: 0.3061 - accuracy: 0.8714
# Epoch 23/25
#  - 2s - loss: 0.2763 - accuracy: 0.8829
# Epoch 24/25
#  - 2s - loss: 0.2682 - accuracy: 0.8943
# Epoch 25/25
#  - 2s - loss: 0.2789 - accuracy: 0.8843
# 175/175 [==============================] - 0s 462us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 0s - loss: 0.6458 - accuracy: 0.7357
# Epoch 2/25
#  - 1s - loss: 0.4699 - accuracy: 0.7800
# Epoch 3/25
#  - 0s - loss: 0.4261 - accuracy: 0.8271
# Epoch 4/25
#  - 1s - loss: 0.3895 - accuracy: 0.8329
# Epoch 5/25
#  - 0s - loss: 0.3665 - accuracy: 0.8600
# Epoch 6/25
#  - 0s - loss: 0.3891 - accuracy: 0.8371
# Epoch 7/25
#  - 0s - loss: 0.3441 - accuracy: 0.8543
# Epoch 8/25
#  - 1s - loss: 0.3506 - accuracy: 0.8600
# Epoch 9/25
#  - 0s - loss: 0.3276 - accuracy: 0.8843
# Epoch 10/25
#  - 1s - loss: 0.3217 - accuracy: 0.8700
# Epoch 11/25
#  - 1s - loss: 0.3198 - accuracy: 0.8729
# Epoch 12/25
#  - 0s - loss: 0.3431 - accuracy: 0.8686
# Epoch 13/25
#  - 0s - loss: 0.2634 - accuracy: 0.9071
# Epoch 14/25
#  - 1s - loss: 0.3207 - accuracy: 0.8800
# Epoch 15/25
#  - 0s - loss: 0.2839 - accuracy: 0.8914
# Epoch 16/25
#  - 1s - loss: 0.2548 - accuracy: 0.8971
# Epoch 17/25
#  - 1s - loss: 0.3190 - accuracy: 0.8871
# Epoch 18/25
#  - 1s - loss: 0.2847 - accuracy: 0.8929
# Epoch 19/25
#  - 0s - loss: 0.2737 - accuracy: 0.8743
# Epoch 20/25
#  - 1s - loss: 0.2737 - accuracy: 0.8900
# Epoch 21/25
#  - 0s - loss: 0.3064 - accuracy: 0.8657
# Epoch 22/25
#  - 1s - loss: 0.2775 - accuracy: 0.8957
# Epoch 23/25
#  - 1s - loss: 0.2949 - accuracy: 0.8829
# Epoch 24/25
#  - 0s - loss: 0.2832 - accuracy: 0.8929
# Epoch 25/25
#  - 0s - loss: 0.2498 - accuracy: 0.9057
# 175/175 [==============================] - 0s 390us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 0s - loss: 0.6100 - accuracy: 0.7443
# Epoch 2/25
#  - 1s - loss: 0.4310 - accuracy: 0.8157
# Epoch 3/25
#  - 0s - loss: 0.3882 - accuracy: 0.8514
# Epoch 4/25
#  - 0s - loss: 0.4000 - accuracy: 0.8500
# Epoch 5/25
#  - 0s - loss: 0.3457 - accuracy: 0.8700
# Epoch 6/25
#  - 1s - loss: 0.3337 - accuracy: 0.8714
# Epoch 7/25
#  - 0s - loss: 0.3389 - accuracy: 0.8700
# Epoch 8/25
#  - 1s - loss: 0.3228 - accuracy: 0.8586
# Epoch 9/25
#  - 0s - loss: 0.2829 - accuracy: 0.8957
# Epoch 10/25
#  - 0s - loss: 0.3112 - accuracy: 0.8843
# Epoch 11/25
#  - 0s - loss: 0.3006 - accuracy: 0.8914
# Epoch 12/25
#  - 1s - loss: 0.3076 - accuracy: 0.8843
# Epoch 13/25
#  - 0s - loss: 0.2736 - accuracy: 0.9057
# Epoch 14/25
#  - 1s - loss: 0.2833 - accuracy: 0.9029
# Epoch 15/25
#  - 0s - loss: 0.2656 - accuracy: 0.8986
# Epoch 16/25
#  - 0s - loss: 0.2716 - accuracy: 0.8957
# Epoch 17/25
#  - 1s - loss: 0.2643 - accuracy: 0.9000
# Epoch 18/25
#  - 1s - loss: 0.2330 - accuracy: 0.9200
# Epoch 19/25
#  - 0s - loss: 0.2479 - accuracy: 0.9129
# Epoch 20/25
#  - 1s - loss: 0.2662 - accuracy: 0.9029
# Epoch 21/25
#  - 1s - loss: 0.3092 - accuracy: 0.8886
# Epoch 22/25
#  - 0s - loss: 0.2639 - accuracy: 0.8929
# Epoch 23/25
#  - 1s - loss: 0.2319 - accuracy: 0.9029
# Epoch 24/25
#  - 1s - loss: 0.2500 - accuracy: 0.9029
# Epoch 25/25
#  - 0s - loss: 0.3033 - accuracy: 0.8929
# 175/175 [==============================] - 0s 211us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.6645 - accuracy: 0.7314
# Epoch 2/25
#  - 0s - loss: 0.4723 - accuracy: 0.7971
# Epoch 3/25
#  - 0s - loss: 0.4170 - accuracy: 0.8229
# Epoch 4/25
#  - 0s - loss: 0.3815 - accuracy: 0.8471
# Epoch 5/25
#  - 1s - loss: 0.3769 - accuracy: 0.8586
# Epoch 6/25
#  - 0s - loss: 0.3299 - accuracy: 0.8657
# Epoch 7/25
#  - 1s - loss: 0.3292 - accuracy: 0.8757
# Epoch 8/25
#  - 0s - loss: 0.3238 - accuracy: 0.8700
# Epoch 9/25
#  - 1s - loss: 0.3194 - accuracy: 0.8743
# Epoch 10/25
#  - 0s - loss: 0.3062 - accuracy: 0.9029
# Epoch 11/25
#  - 1s - loss: 0.3024 - accuracy: 0.8914
# Epoch 12/25
#  - 0s - loss: 0.3094 - accuracy: 0.8943
# Epoch 13/25
#  - 1s - loss: 0.2801 - accuracy: 0.8871
# Epoch 14/25
#  - 0s - loss: 0.3024 - accuracy: 0.8929
# Epoch 15/25
#  - 0s - loss: 0.2943 - accuracy: 0.8929
# Epoch 16/25
#  - 0s - loss: 0.2931 - accuracy: 0.8914
# Epoch 17/25
#  - 1s - loss: 0.2951 - accuracy: 0.8729
# Epoch 18/25
#  - 0s - loss: 0.2602 - accuracy: 0.9043
# Epoch 19/25
#  - 1s - loss: 0.2643 - accuracy: 0.8971
# Epoch 20/25
#  - 0s - loss: 0.2640 - accuracy: 0.9029
# Epoch 21/25
#  - 0s - loss: 0.2693 - accuracy: 0.9000
# Epoch 22/25
#  - 0s - loss: 0.2614 - accuracy: 0.8929
# Epoch 23/25
#  - 1s - loss: 0.2568 - accuracy: 0.9057
# Epoch 24/25
#  - 0s - loss: 0.2486 - accuracy: 0.9014
# Epoch 25/25
#  - 1s - loss: 0.2574 - accuracy: 0.9057
# 175/175 [==============================] - 0s 325us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.6939 - accuracy: 0.7014
# Epoch 2/25
#  - 1s - loss: 0.4559 - accuracy: 0.8100
# Epoch 3/25
#  - 1s - loss: 0.4372 - accuracy: 0.8186
# Epoch 4/25
#  - 0s - loss: 0.4029 - accuracy: 0.8271
# Epoch 5/25
#  - 0s - loss: 0.3815 - accuracy: 0.8471
# Epoch 6/25
#  - 0s - loss: 0.3384 - accuracy: 0.8700
# Epoch 7/25
#  - 1s - loss: 0.3139 - accuracy: 0.8814
# Epoch 8/25
#  - 0s - loss: 0.3056 - accuracy: 0.8800
# Epoch 9/25
#  - 1s - loss: 0.2932 - accuracy: 0.8843
# Epoch 10/25
#  - 0s - loss: 0.3121 - accuracy: 0.8914
# Epoch 11/25
#  - 0s - loss: 0.3113 - accuracy: 0.8771
# Epoch 12/25
#  - 0s - loss: 0.2922 - accuracy: 0.8943
# Epoch 13/25
#  - 0s - loss: 0.2924 - accuracy: 0.8900
# Epoch 14/25
#  - 0s - loss: 0.2769 - accuracy: 0.8971
# Epoch 15/25
#  - 1s - loss: 0.3025 - accuracy: 0.8857
# Epoch 16/25
#  - 0s - loss: 0.2903 - accuracy: 0.8971
# Epoch 17/25
#  - 0s - loss: 0.2746 - accuracy: 0.8929
# Epoch 18/25
#  - 0s - loss: 0.2712 - accuracy: 0.8957
# Epoch 19/25
#  - 1s - loss: 0.2887 - accuracy: 0.8871
# Epoch 20/25
#  - 1s - loss: 0.2683 - accuracy: 0.8886
# Epoch 21/25
#  - 1s - loss: 0.2679 - accuracy: 0.8986
# Epoch 22/25
#  - 0s - loss: 0.2723 - accuracy: 0.9000
# Epoch 23/25
#  - 1s - loss: 0.2717 - accuracy: 0.8971
# Epoch 24/25
#  - 0s - loss: 0.2646 - accuracy: 0.9057
# Epoch 25/25
#  - 1s - loss: 0.2632 - accuracy: 0.8971
# 175/175 [==============================] - 0s 376us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.7006 - accuracy: 0.7129
# Epoch 2/25
#  - 1s - loss: 0.5010 - accuracy: 0.8043
# Epoch 3/25
#  - 0s - loss: 0.4555 - accuracy: 0.8043
# Epoch 4/25
#  - 0s - loss: 0.4024 - accuracy: 0.8286
# Epoch 5/25
#  - 1s - loss: 0.3929 - accuracy: 0.8429
# Epoch 6/25
#  - 0s - loss: 0.3687 - accuracy: 0.8514
# Epoch 7/25
#  - 0s - loss: 0.3481 - accuracy: 0.8629
# Epoch 8/25
#  - 1s - loss: 0.3428 - accuracy: 0.8714
# Epoch 9/25
#  - 1s - loss: 0.3173 - accuracy: 0.8757
# Epoch 10/25
#  - 1s - loss: 0.3697 - accuracy: 0.8557
# Epoch 11/25
#  - 0s - loss: 0.3353 - accuracy: 0.8643
# Epoch 12/25
#  - 1s - loss: 0.3051 - accuracy: 0.8686
# Epoch 13/25
#  - 1s - loss: 0.2982 - accuracy: 0.8829
# Epoch 14/25
#  - 1s - loss: 0.3118 - accuracy: 0.8843
# Epoch 15/25
#  - 0s - loss: 0.3269 - accuracy: 0.8700
# Epoch 16/25
#  - 0s - loss: 0.2811 - accuracy: 0.8900
# Epoch 17/25
#  - 0s - loss: 0.3124 - accuracy: 0.8686
# Epoch 18/25
#  - 1s - loss: 0.2997 - accuracy: 0.8886
# Epoch 19/25
#  - 0s - loss: 0.2929 - accuracy: 0.8843
# Epoch 20/25
#  - 1s - loss: 0.2703 - accuracy: 0.9086
# Epoch 21/25
#  - 0s - loss: 0.2761 - accuracy: 0.8943
# Epoch 22/25
#  - 0s - loss: 0.2868 - accuracy: 0.8914
# Epoch 23/25
#  - 0s - loss: 0.2701 - accuracy: 0.8914
# Epoch 24/25
#  - 1s - loss: 0.2854 - accuracy: 0.8829
# Epoch 25/25
#  - 0s - loss: 0.2993 - accuracy: 0.8800
# 175/175 [==============================] - 0s 456us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.7469 - accuracy: 0.7329
# Epoch 2/25
#  - 1s - loss: 0.4982 - accuracy: 0.8014
# Epoch 3/25
#  - 1s - loss: 0.4396 - accuracy: 0.8171
# Epoch 4/25
#  - 1s - loss: 0.3993 - accuracy: 0.8371
# Epoch 5/25
#  - 1s - loss: 0.3490 - accuracy: 0.8614
# Epoch 6/25
#  - 1s - loss: 0.3354 - accuracy: 0.8786
# Epoch 7/25
#  - 1s - loss: 0.3400 - accuracy: 0.8771
# Epoch 8/25
#  - 1s - loss: 0.3341 - accuracy: 0.8671
# Epoch 9/25
#  - 1s - loss: 0.3007 - accuracy: 0.8757
# Epoch 10/25
#  - 1s - loss: 0.3183 - accuracy: 0.8657
# Epoch 11/25
#  - 1s - loss: 0.3053 - accuracy: 0.8829
# Epoch 12/25
#  - 1s - loss: 0.2953 - accuracy: 0.8914
# Epoch 13/25
#  - 1s - loss: 0.3003 - accuracy: 0.8771
# Epoch 14/25
#  - 1s - loss: 0.2918 - accuracy: 0.8886
# Epoch 15/25
#  - 1s - loss: 0.2864 - accuracy: 0.8900
# Epoch 16/25
#  - 1s - loss: 0.3312 - accuracy: 0.8786
# Epoch 17/25
#  - 1s - loss: 0.2665 - accuracy: 0.8843
# Epoch 18/25
#  - 1s - loss: 0.2865 - accuracy: 0.8886
# Epoch 19/25
#  - 1s - loss: 0.2974 - accuracy: 0.8871
# Epoch 20/25
#  - 1s - loss: 0.2769 - accuracy: 0.8943
# Epoch 21/25
#  - 1s - loss: 0.2386 - accuracy: 0.8943
# Epoch 22/25
#  - 1s - loss: 0.3090 - accuracy: 0.8829
# Epoch 23/25
#  - 1s - loss: 0.2613 - accuracy: 0.9014
# Epoch 24/25
#  - 1s - loss: 0.2765 - accuracy: 0.8900
# Epoch 25/25
#  - 1s - loss: 0.2821 - accuracy: 0.8986
# 175/175 [==============================] - 0s 348us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.7414 - accuracy: 0.7286
# Epoch 2/25
#  - 1s - loss: 0.4316 - accuracy: 0.8129
# Epoch 3/25
#  - 1s - loss: 0.3867 - accuracy: 0.8457
# Epoch 4/25
#  - 1s - loss: 0.3503 - accuracy: 0.8600
# Epoch 5/25
#  - 1s - loss: 0.3351 - accuracy: 0.8729
# Epoch 6/25
#  - 1s - loss: 0.3044 - accuracy: 0.8871
# Epoch 7/25
#  - 1s - loss: 0.2777 - accuracy: 0.8943
# Epoch 8/25
#  - 1s - loss: 0.3099 - accuracy: 0.8886
# Epoch 9/25
#  - 1s - loss: 0.2789 - accuracy: 0.9029
# Epoch 10/25
#  - 1s - loss: 0.2598 - accuracy: 0.9029
# Epoch 11/25
#  - 1s - loss: 0.3037 - accuracy: 0.8871
# Epoch 12/25
#  - 1s - loss: 0.2713 - accuracy: 0.9071
# Epoch 13/25
#  - 1s - loss: 0.2854 - accuracy: 0.9000
# Epoch 14/25
#  - 1s - loss: 0.2538 - accuracy: 0.9014
# Epoch 15/25
#  - 1s - loss: 0.2578 - accuracy: 0.9114
# Epoch 16/25
#  - 1s - loss: 0.2724 - accuracy: 0.8871
# Epoch 17/25
#  - 1s - loss: 0.2442 - accuracy: 0.9029
# Epoch 18/25
#  - 1s - loss: 0.2421 - accuracy: 0.9086
# Epoch 19/25
#  - 1s - loss: 0.2408 - accuracy: 0.9143
# Epoch 20/25
#  - 1s - loss: 0.2384 - accuracy: 0.9157
# Epoch 21/25
#  - 1s - loss: 0.2551 - accuracy: 0.8971
# Epoch 22/25
#  - 1s - loss: 0.2633 - accuracy: 0.9057
# Epoch 23/25
#  - 1s - loss: 0.2523 - accuracy: 0.9086
# Epoch 24/25
#  - 1s - loss: 0.2551 - accuracy: 0.8986
# Epoch 25/25
#  - 1s - loss: 0.2359 - accuracy: 0.9114
# 175/175 [==============================] - 0s 547us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.7664 - accuracy: 0.7157
# Epoch 2/25
#  - 1s - loss: 0.4622 - accuracy: 0.8000
# Epoch 3/25
#  - 1s - loss: 0.4300 - accuracy: 0.8314
# Epoch 4/25
#  - 1s - loss: 0.3645 - accuracy: 0.8557
# Epoch 5/25
#  - 1s - loss: 0.3729 - accuracy: 0.8614
# Epoch 6/25
#  - 1s - loss: 0.3188 - accuracy: 0.8771
# Epoch 7/25
#  - 1s - loss: 0.3316 - accuracy: 0.8843
# Epoch 8/25
#  - 1s - loss: 0.3024 - accuracy: 0.8857
# Epoch 9/25
#  - 1s - loss: 0.3208 - accuracy: 0.8829
# Epoch 10/25
#  - 1s - loss: 0.2890 - accuracy: 0.8929
# Epoch 11/25
#  - 1s - loss: 0.3064 - accuracy: 0.8857
# Epoch 12/25
#  - 1s - loss: 0.2754 - accuracy: 0.8814
# Epoch 13/25
#  - 1s - loss: 0.2780 - accuracy: 0.9014
# Epoch 14/25
#  - 1s - loss: 0.2866 - accuracy: 0.8914
# Epoch 15/25
#  - 1s - loss: 0.2992 - accuracy: 0.8829
# Epoch 16/25
#  - 1s - loss: 0.2508 - accuracy: 0.8986
# Epoch 17/25
#  - 1s - loss: 0.2885 - accuracy: 0.8843
# Epoch 18/25
#  - 1s - loss: 0.2637 - accuracy: 0.9000
# Epoch 19/25
#  - 1s - loss: 0.2869 - accuracy: 0.8886
# Epoch 20/25
#  - 1s - loss: 0.2613 - accuracy: 0.8886
# Epoch 21/25
#  - 1s - loss: 0.2632 - accuracy: 0.8986
# Epoch 22/25
#  - 1s - loss: 0.2590 - accuracy: 0.8971
# Epoch 23/25
#  - 1s - loss: 0.2400 - accuracy: 0.9014
# Epoch 24/25
#  - 1s - loss: 0.2573 - accuracy: 0.8943
# Epoch 25/25
#  - 1s - loss: 0.2781 - accuracy: 0.9043
# 175/175 [==============================] - 0s 549us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.7436 - accuracy: 0.7286
# Epoch 2/25
#  - 1s - loss: 0.4471 - accuracy: 0.8257
# Epoch 3/25
#  - 1s - loss: 0.3800 - accuracy: 0.8443
# Epoch 4/25
#  - 1s - loss: 0.3539 - accuracy: 0.8514
# Epoch 5/25
#  - 1s - loss: 0.3441 - accuracy: 0.8743
# Epoch 6/25
#  - 1s - loss: 0.3462 - accuracy: 0.8671
# Epoch 7/25
#  - 1s - loss: 0.2907 - accuracy: 0.8929
# Epoch 8/25
#  - 1s - loss: 0.3377 - accuracy: 0.8686
# Epoch 9/25
#  - 1s - loss: 0.2895 - accuracy: 0.8986
# Epoch 10/25
#  - 1s - loss: 0.2769 - accuracy: 0.8900
# Epoch 11/25
#  - 1s - loss: 0.2661 - accuracy: 0.8929
# Epoch 12/25
#  - 1s - loss: 0.2998 - accuracy: 0.8943
# Epoch 13/25
#  - 1s - loss: 0.3055 - accuracy: 0.8800
# Epoch 14/25
#  - 1s - loss: 0.2822 - accuracy: 0.8971
# Epoch 15/25
#  - 1s - loss: 0.3108 - accuracy: 0.8843
# Epoch 16/25
#  - 1s - loss: 0.2903 - accuracy: 0.8857
# Epoch 17/25
#  - 1s - loss: 0.2876 - accuracy: 0.8986
# Epoch 18/25
#  - 1s - loss: 0.2526 - accuracy: 0.9100
# Epoch 19/25
#  - 1s - loss: 0.2691 - accuracy: 0.9029
# Epoch 20/25
#  - 1s - loss: 0.2456 - accuracy: 0.9043
# Epoch 21/25
#  - 1s - loss: 0.2806 - accuracy: 0.9029
# Epoch 22/25
#  - 1s - loss: 0.2692 - accuracy: 0.8914
# Epoch 23/25
#  - 1s - loss: 0.2506 - accuracy: 0.9057
# Epoch 24/25
#  - 1s - loss: 0.2631 - accuracy: 0.9000
# Epoch 25/25
#  - 1s - loss: 0.2805 - accuracy: 0.8857
# 175/175 [==============================] - 0s 342us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 1s - loss: 0.7802 - accuracy: 0.7243
# Epoch 2/25
#  - 1s - loss: 0.4828 - accuracy: 0.7914
# Epoch 3/25
#  - 1s - loss: 0.4540 - accuracy: 0.8086
# Epoch 4/25
#  - 1s - loss: 0.3770 - accuracy: 0.8529
# Epoch 5/25
#  - 1s - loss: 0.3751 - accuracy: 0.8671
# Epoch 6/25
#  - 1s - loss: 0.3702 - accuracy: 0.8586
# Epoch 7/25
#  - 1s - loss: 0.3323 - accuracy: 0.8814
# Epoch 8/25
#  - 1s - loss: 0.3200 - accuracy: 0.8871
# Epoch 9/25
#  - 1s - loss: 0.3181 - accuracy: 0.8771
# Epoch 10/25
#  - 1s - loss: 0.3229 - accuracy: 0.8671
# Epoch 11/25
#  - 1s - loss: 0.3232 - accuracy: 0.8857
# Epoch 12/25
#  - 1s - loss: 0.3174 - accuracy: 0.8771
# Epoch 13/25
#  - 1s - loss: 0.3141 - accuracy: 0.8786
# Epoch 14/25
#  - 1s - loss: 0.2862 - accuracy: 0.8843
# Epoch 15/25
#  - 1s - loss: 0.2900 - accuracy: 0.8829
# Epoch 16/25
#  - 1s - loss: 0.2893 - accuracy: 0.8857
# Epoch 17/25
#  - 1s - loss: 0.2921 - accuracy: 0.8986
# Epoch 18/25
#  - 1s - loss: 0.2796 - accuracy: 0.8929
# Epoch 19/25
#  - 1s - loss: 0.2934 - accuracy: 0.8829
# Epoch 20/25
#  - 1s - loss: 0.2727 - accuracy: 0.8929
# Epoch 21/25
#  - 1s - loss: 0.2573 - accuracy: 0.8986
# Epoch 22/25
#  - 1s - loss: 0.2830 - accuracy: 0.8986
# Epoch 23/25
#  - 1s - loss: 0.2823 - accuracy: 0.8814
# Epoch 24/25
#  - 1s - loss: 0.2909 - accuracy: 0.8886
# Epoch 25/25
#  - 1s - loss: 0.2745 - accuracy: 0.8886
# 175/175 [==============================] - 0s 445us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 2s - loss: 0.7765 - accuracy: 0.7200
# Epoch 2/25
#  - 1s - loss: 0.4930 - accuracy: 0.7871
# Epoch 3/25
#  - 2s - loss: 0.4189 - accuracy: 0.8229
# Epoch 4/25
#  - 2s - loss: 0.3834 - accuracy: 0.8457
# Epoch 5/25
#  - 2s - loss: 0.3577 - accuracy: 0.8514
# Epoch 6/25
#  - 1s - loss: 0.3336 - accuracy: 0.8671
# Epoch 7/25
#  - 1s - loss: 0.3117 - accuracy: 0.8729
# Epoch 8/25
#  - 1s - loss: 0.3257 - accuracy: 0.8743
# Epoch 9/25
#  - 2s - loss: 0.2834 - accuracy: 0.8843
# Epoch 10/25
#  - 2s - loss: 0.2653 - accuracy: 0.9014
# Epoch 11/25
#  - 2s - loss: 0.2956 - accuracy: 0.8700
# Epoch 12/25
#  - 1s - loss: 0.3165 - accuracy: 0.8843
# Epoch 13/25
#  - 2s - loss: 0.3177 - accuracy: 0.8757
# Epoch 14/25
#  - 2s - loss: 0.2805 - accuracy: 0.8829
# Epoch 15/25
#  - 1s - loss: 0.3010 - accuracy: 0.8843
# Epoch 16/25
#  - 2s - loss: 0.2793 - accuracy: 0.8886
# Epoch 17/25
#  - 1s - loss: 0.2830 - accuracy: 0.8829
# Epoch 18/25
#  - 2s - loss: 0.2679 - accuracy: 0.8986
# Epoch 19/25
#  - 1s - loss: 0.2555 - accuracy: 0.8943
# Epoch 20/25
#  - 2s - loss: 0.2777 - accuracy: 0.8957
# Epoch 21/25
#  - 1s - loss: 0.2568 - accuracy: 0.8943
# Epoch 22/25
#  - 2s - loss: 0.2422 - accuracy: 0.9029
# Epoch 23/25
#  - 1s - loss: 0.2526 - accuracy: 0.8986
# Epoch 24/25
#  - 2s - loss: 0.2603 - accuracy: 0.8957
# Epoch 25/25
#  - 2s - loss: 0.2662 - accuracy: 0.8971
# 175/175 [==============================] - 0s 723us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 2s - loss: 0.8513 - accuracy: 0.7214
# Epoch 2/25
#  - 2s - loss: 0.4296 - accuracy: 0.8229
# Epoch 3/25
#  - 1s - loss: 0.3901 - accuracy: 0.8571
# Epoch 4/25
#  - 2s - loss: 0.4047 - accuracy: 0.8543
# Epoch 5/25
#  - 1s - loss: 0.3477 - accuracy: 0.8586
# Epoch 6/25
#  - 2s - loss: 0.3544 - accuracy: 0.8657
# Epoch 7/25
#  - 2s - loss: 0.3199 - accuracy: 0.8900
# Epoch 8/25
#  - 2s - loss: 0.3134 - accuracy: 0.8729
# Epoch 9/25
#  - 2s - loss: 0.2985 - accuracy: 0.8900
# Epoch 10/25
#  - 2s - loss: 0.3080 - accuracy: 0.8800
# Epoch 11/25
#  - 2s - loss: 0.2825 - accuracy: 0.9000
# Epoch 12/25
#  - 2s - loss: 0.3241 - accuracy: 0.8800
# Epoch 13/25
#  - 2s - loss: 0.2647 - accuracy: 0.9000
# Epoch 14/25
#  - 1s - loss: 0.2510 - accuracy: 0.9000
# Epoch 15/25
#  - 2s - loss: 0.2802 - accuracy: 0.8986
# Epoch 16/25
#  - 1s - loss: 0.2444 - accuracy: 0.9029
# Epoch 17/25
#  - 2s - loss: 0.2766 - accuracy: 0.9014
# Epoch 18/25
#  - 2s - loss: 0.2684 - accuracy: 0.9057
# Epoch 19/25
#  - 2s - loss: 0.2550 - accuracy: 0.9071
# Epoch 20/25
#  - 2s - loss: 0.2749 - accuracy: 0.8986
# Epoch 21/25
#  - 2s - loss: 0.2653 - accuracy: 0.8914
# Epoch 22/25
#  - 2s - loss: 0.2483 - accuracy: 0.9100
# Epoch 23/25
#  - 2s - loss: 0.2466 - accuracy: 0.8957
# Epoch 24/25
#  - 2s - loss: 0.2706 - accuracy: 0.8929
# Epoch 25/25
#  - 2s - loss: 0.2530 - accuracy: 0.9000
# 175/175 [==============================] - 0s 661us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 2s - loss: 0.8380 - accuracy: 0.7157
# Epoch 2/25
#  - 2s - loss: 0.4923 - accuracy: 0.7886
# Epoch 3/25
#  - 2s - loss: 0.4147 - accuracy: 0.8329
# Epoch 4/25
#  - 2s - loss: 0.3845 - accuracy: 0.8557
# Epoch 5/25
#  - 2s - loss: 0.3633 - accuracy: 0.8700
# Epoch 6/25
#  - 2s - loss: 0.3269 - accuracy: 0.8714
# Epoch 7/25
#  - 2s - loss: 0.3226 - accuracy: 0.8886
# Epoch 8/25
#  - 2s - loss: 0.3089 - accuracy: 0.8871
# Epoch 9/25
#  - 2s - loss: 0.2928 - accuracy: 0.8971
# Epoch 10/25
#  - 2s - loss: 0.2984 - accuracy: 0.8786
# Epoch 11/25
#  - 2s - loss: 0.3057 - accuracy: 0.8886
# Epoch 12/25
#  - 2s - loss: 0.2916 - accuracy: 0.8857
# Epoch 13/25
#  - 2s - loss: 0.2656 - accuracy: 0.9000
# Epoch 14/25
#  - 2s - loss: 0.2660 - accuracy: 0.9029
# Epoch 15/25
#  - 2s - loss: 0.2712 - accuracy: 0.8871
# Epoch 16/25
#  - 2s - loss: 0.2682 - accuracy: 0.8986
# Epoch 17/25
#  - 2s - loss: 0.2501 - accuracy: 0.9029
# Epoch 18/25
#  - 2s - loss: 0.2844 - accuracy: 0.8771
# Epoch 19/25
#  - 2s - loss: 0.2609 - accuracy: 0.9014
# Epoch 20/25
#  - 2s - loss: 0.2720 - accuracy: 0.8943
# Epoch 21/25
#  - 2s - loss: 0.2781 - accuracy: 0.9029
# Epoch 22/25
#  - 2s - loss: 0.2662 - accuracy: 0.9014
# Epoch 23/25
#  - 2s - loss: 0.2259 - accuracy: 0.9114
# Epoch 24/25
#  - 2s - loss: 0.2407 - accuracy: 0.9029
# Epoch 25/25
#  - 2s - loss: 0.2822 - accuracy: 0.8886
# 175/175 [==============================] - 0s 763us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 2s - loss: 0.8362 - accuracy: 0.7186
# Epoch 2/25
#  - 2s - loss: 0.4425 - accuracy: 0.8129
# Epoch 3/25
#  - 2s - loss: 0.4172 - accuracy: 0.8400
# Epoch 4/25
#  - 2s - loss: 0.3635 - accuracy: 0.8557
# Epoch 5/25
#  - 1s - loss: 0.3571 - accuracy: 0.8600
# Epoch 6/25
#  - 2s - loss: 0.3197 - accuracy: 0.8814
# Epoch 7/25
#  - 2s - loss: 0.3488 - accuracy: 0.8743
# Epoch 8/25
#  - 2s - loss: 0.3086 - accuracy: 0.8800
# Epoch 9/25
#  - 1s - loss: 0.3235 - accuracy: 0.8814
# Epoch 10/25
#  - 2s - loss: 0.2887 - accuracy: 0.8814
# Epoch 11/25
#  - 2s - loss: 0.2955 - accuracy: 0.8871
# Epoch 12/25
#  - 2s - loss: 0.2882 - accuracy: 0.8857
# Epoch 13/25
#  - 2s - loss: 0.2732 - accuracy: 0.9014
# Epoch 14/25
#  - 2s - loss: 0.2722 - accuracy: 0.9014
# Epoch 15/25
#  - 2s - loss: 0.2692 - accuracy: 0.8929
# Epoch 16/25
#  - 1s - loss: 0.2663 - accuracy: 0.9000
# Epoch 17/25
#  - 1s - loss: 0.2725 - accuracy: 0.9014
# Epoch 18/25
#  - 2s - loss: 0.2641 - accuracy: 0.8929
# Epoch 19/25
#  - 2s - loss: 0.2525 - accuracy: 0.8986
# Epoch 20/25
#  - 2s - loss: 0.2724 - accuracy: 0.8929
# Epoch 21/25
#  - 2s - loss: 0.2559 - accuracy: 0.8971
# Epoch 22/25
#  - 2s - loss: 0.2510 - accuracy: 0.9114
# Epoch 23/25
#  - 2s - loss: 0.2693 - accuracy: 0.9000
# Epoch 24/25
#  - 1s - loss: 0.2543 - accuracy: 0.9043
# Epoch 25/25
#  - 2s - loss: 0.2359 - accuracy: 0.9100
# 175/175 [==============================] - 0s 627us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 2s - loss: 0.8268 - accuracy: 0.7129
# Epoch 2/25
#  - 1s - loss: 0.4446 - accuracy: 0.8000
# Epoch 3/25
#  - 1s - loss: 0.4123 - accuracy: 0.8271
# Epoch 4/25
#  - 2s - loss: 0.3845 - accuracy: 0.8614
# Epoch 5/25
#  - 2s - loss: 0.3668 - accuracy: 0.8571
# Epoch 6/25
#  - 2s - loss: 0.3534 - accuracy: 0.8600
# Epoch 7/25
#  - 2s - loss: 0.3478 - accuracy: 0.8629
# Epoch 8/25
#  - 2s - loss: 0.3339 - accuracy: 0.8757
# Epoch 9/25
#  - 2s - loss: 0.2914 - accuracy: 0.8914
# Epoch 10/25
#  - 2s - loss: 0.2982 - accuracy: 0.8914
# Epoch 11/25
#  - 1s - loss: 0.3065 - accuracy: 0.8814
# Epoch 12/25
#  - 1s - loss: 0.3136 - accuracy: 0.8729
# Epoch 13/25
#  - 2s - loss: 0.2742 - accuracy: 0.8957
# Epoch 14/25
#  - 2s - loss: 0.3067 - accuracy: 0.8886
# Epoch 15/25
#  - 1s - loss: 0.2976 - accuracy: 0.8871
# Epoch 16/25
#  - 2s - loss: 0.2797 - accuracy: 0.9071
# Epoch 17/25
#  - 2s - loss: 0.2719 - accuracy: 0.8943
# Epoch 18/25
#  - 2s - loss: 0.2999 - accuracy: 0.8714
# Epoch 19/25
#  - 2s - loss: 0.2794 - accuracy: 0.8914
# Epoch 20/25
#  - 2s - loss: 0.3037 - accuracy: 0.8800
# Epoch 21/25
#  - 2s - loss: 0.3100 - accuracy: 0.8943
# Epoch 22/25
#  - 1s - loss: 0.2750 - accuracy: 0.8857
# Epoch 23/25
#  - 2s - loss: 0.2546 - accuracy: 0.8929
# Epoch 24/25
#  - 2s - loss: 0.2903 - accuracy: 0.8857
# Epoch 25/25
#  - 2s - loss: 0.2767 - accuracy: 0.9057
# 175/175 [==============================] - 0s 678us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.7217 - accuracy: 0.6329
# Epoch 2/25
#  - 1s - loss: 0.6511 - accuracy: 0.7086
# Epoch 3/25
#  - 1s - loss: 0.5738 - accuracy: 0.7471
# Epoch 4/25
#  - 1s - loss: 0.5168 - accuracy: 0.7686
# Epoch 5/25
#  - 0s - loss: 0.5803 - accuracy: 0.7629
# Epoch 6/25
#  - 1s - loss: 0.5275 - accuracy: 0.7557
# Epoch 7/25
#  - 1s - loss: 0.5209 - accuracy: 0.7814
# Epoch 8/25
#  - 0s - loss: 0.4557 - accuracy: 0.8000
# Epoch 9/25
#  - 1s - loss: 0.4210 - accuracy: 0.8371
# Epoch 10/25
#  - 1s - loss: 0.4587 - accuracy: 0.8286
# Epoch 11/25
#  - 0s - loss: 0.4783 - accuracy: 0.8071
# Epoch 12/25
#  - 1s - loss: 0.3913 - accuracy: 0.8371
# Epoch 13/25
#  - 1s - loss: 0.4220 - accuracy: 0.8457
# Epoch 14/25
#  - 1s - loss: 0.4090 - accuracy: 0.8229
# Epoch 15/25
#  - 1s - loss: 0.3956 - accuracy: 0.8514
# Epoch 16/25
#  - 1s - loss: 0.3937 - accuracy: 0.8471
# Epoch 17/25
#  - 0s - loss: 0.3932 - accuracy: 0.8400
# Epoch 18/25
#  - 1s - loss: 0.3853 - accuracy: 0.8543
# Epoch 19/25
#  - 0s - loss: 0.3617 - accuracy: 0.8529
# Epoch 20/25
#  - 1s - loss: 0.3480 - accuracy: 0.8643
# Epoch 21/25
#  - 1s - loss: 0.3728 - accuracy: 0.8600
# Epoch 22/25
#  - 1s - loss: 0.3525 - accuracy: 0.8629
# Epoch 23/25
#  - 0s - loss: 0.3463 - accuracy: 0.8686
# Epoch 24/25
#  - 1s - loss: 0.3429 - accuracy: 0.8671
# Epoch 25/25
#  - 0s - loss: 0.3579 - accuracy: 0.8429
# 175/175 [==============================] - 0s 313us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 0s - loss: 0.7270 - accuracy: 0.6286
# Epoch 2/25
#  - 1s - loss: 0.6341 - accuracy: 0.7271
# Epoch 3/25
#  - 0s - loss: 0.5540 - accuracy: 0.7514
# Epoch 4/25
#  - 1s - loss: 0.5625 - accuracy: 0.7700
# Epoch 5/25
#  - 0s - loss: 0.5383 - accuracy: 0.7800
# Epoch 6/25
#  - 1s - loss: 0.4875 - accuracy: 0.7871
# Epoch 7/25
#  - 0s - loss: 0.4763 - accuracy: 0.7914
# Epoch 8/25
#  - 1s - loss: 0.4494 - accuracy: 0.8229
# Epoch 9/25
#  - 0s - loss: 0.4976 - accuracy: 0.7929
# Epoch 10/25
#  - 1s - loss: 0.4153 - accuracy: 0.8329
# Epoch 11/25
#  - 0s - loss: 0.4046 - accuracy: 0.8443
# Epoch 12/25
#  - 1s - loss: 0.4059 - accuracy: 0.8343
# Epoch 13/25
#  - 0s - loss: 0.3868 - accuracy: 0.8514
# Epoch 14/25
#  - 1s - loss: 0.3867 - accuracy: 0.8500
# Epoch 15/25
#  - 0s - loss: 0.3541 - accuracy: 0.8700
# Epoch 16/25
#  - 1s - loss: 0.3550 - accuracy: 0.8700
# Epoch 17/25
#  - 1s - loss: 0.3824 - accuracy: 0.8314
# Epoch 18/25
#  - 1s - loss: 0.3359 - accuracy: 0.8771
# Epoch 19/25
#  - 1s - loss: 0.3200 - accuracy: 0.8771
# Epoch 20/25
#  - 1s - loss: 0.3624 - accuracy: 0.8757
# Epoch 21/25
#  - 0s - loss: 0.3316 - accuracy: 0.8743
# Epoch 22/25
#  - 1s - loss: 0.3057 - accuracy: 0.8914
# Epoch 23/25
#  - 1s - loss: 0.3158 - accuracy: 0.8786
# Epoch 24/25
#  - 0s - loss: 0.3329 - accuracy: 0.8657
# Epoch 25/25
#  - 1s - loss: 0.2847 - accuracy: 0.8857
# 175/175 [==============================] - 0s 250us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.7465 - accuracy: 0.6157
# Epoch 2/25
#  - 1s - loss: 0.6362 - accuracy: 0.6757
# Epoch 3/25
#  - 0s - loss: 0.6769 - accuracy: 0.6986
# Epoch 4/25
#  - 0s - loss: 0.5341 - accuracy: 0.7471
# Epoch 5/25
#  - 1s - loss: 0.5789 - accuracy: 0.7329
# Epoch 6/25
#  - 1s - loss: 0.5425 - accuracy: 0.7643
# Epoch 7/25
#  - 1s - loss: 0.5182 - accuracy: 0.7800
# Epoch 8/25
#  - 1s - loss: 0.5008 - accuracy: 0.7971
# Epoch 9/25
#  - 0s - loss: 0.4826 - accuracy: 0.8071
# Epoch 10/25
#  - 0s - loss: 0.4410 - accuracy: 0.8157
# Epoch 11/25
#  - 1s - loss: 0.4663 - accuracy: 0.8129
# Epoch 12/25
#  - 1s - loss: 0.4393 - accuracy: 0.8114
# Epoch 13/25
#  - 0s - loss: 0.4361 - accuracy: 0.8186
# Epoch 14/25
#  - 1s - loss: 0.3776 - accuracy: 0.8443
# Epoch 15/25
#  - 0s - loss: 0.3749 - accuracy: 0.8543
# Epoch 16/25
#  - 0s - loss: 0.4023 - accuracy: 0.8429
# Epoch 17/25
#  - 1s - loss: 0.3796 - accuracy: 0.8543
# Epoch 18/25
#  - 1s - loss: 0.3997 - accuracy: 0.8529
# Epoch 19/25
#  - 0s - loss: 0.3607 - accuracy: 0.8629
# Epoch 20/25
#  - 0s - loss: 0.3742 - accuracy: 0.8571
# Epoch 21/25
#  - 0s - loss: 0.3495 - accuracy: 0.8557
# Epoch 22/25
#  - 0s - loss: 0.3236 - accuracy: 0.8743
# Epoch 23/25
#  - 1s - loss: 0.3580 - accuracy: 0.8729
# Epoch 24/25
#  - 1s - loss: 0.3260 - accuracy: 0.8900
# Epoch 25/25
#  - 0s - loss: 0.3427 - accuracy: 0.8600
# 175/175 [==============================] - 0s 319us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.7569 - accuracy: 0.6214
# Epoch 2/25
#  - 0s - loss: 0.6683 - accuracy: 0.6771
# Epoch 3/25
#  - 1s - loss: 0.6260 - accuracy: 0.7186
# Epoch 4/25
#  - 1s - loss: 0.6195 - accuracy: 0.7271
# Epoch 5/25
#  - 0s - loss: 0.5160 - accuracy: 0.7743
# Epoch 6/25
#  - 1s - loss: 0.5090 - accuracy: 0.7829
# Epoch 7/25
#  - 1s - loss: 0.4853 - accuracy: 0.8086
# Epoch 8/25
#  - 0s - loss: 0.5032 - accuracy: 0.8043
# Epoch 9/25
#  - 0s - loss: 0.4856 - accuracy: 0.7971
# Epoch 10/25
#  - 1s - loss: 0.4300 - accuracy: 0.8400
# Epoch 11/25
#  - 0s - loss: 0.4060 - accuracy: 0.8386
# Epoch 12/25
#  - 1s - loss: 0.4172 - accuracy: 0.8414
# Epoch 13/25
#  - 0s - loss: 0.4246 - accuracy: 0.8286
# Epoch 14/25
#  - 0s - loss: 0.3812 - accuracy: 0.8414
# Epoch 15/25
#  - 1s - loss: 0.3508 - accuracy: 0.8586
# Epoch 16/25
#  - 1s - loss: 0.3814 - accuracy: 0.8571
# Epoch 17/25
#  - 0s - loss: 0.3366 - accuracy: 0.8629
# Epoch 18/25
#  - 1s - loss: 0.3518 - accuracy: 0.8743
# Epoch 19/25
#  - 1s - loss: 0.3425 - accuracy: 0.8629
# Epoch 20/25
#  - 1s - loss: 0.3325 - accuracy: 0.8714
# Epoch 21/25
#  - 1s - loss: 0.3451 - accuracy: 0.8757
# Epoch 22/25
#  - 1s - loss: 0.3036 - accuracy: 0.8843
# Epoch 23/25
#  - 0s - loss: 0.3437 - accuracy: 0.8714
# Epoch 24/25
#  - 1s - loss: 0.3234 - accuracy: 0.8786
# Epoch 25/25
#  - 1s - loss: 0.3733 - accuracy: 0.8729
# 175/175 [==============================] - 0s 353us/step
# activation: relu, optimizer=adam
# Epoch 1/25
#  - 0s - loss: 0.7478 - accuracy: 0.6086
# Epoch 2/25
#  - 1s - loss: 0.6840 - accuracy: 0.6729
# Epoch 3/25
#  - 1s - loss: 0.6544 - accuracy: 0.7057
# Epoch 4/25
#  - 0s - loss: 0.6012 - accuracy: 0.7386
# Epoch 5/25
#  - 1s - loss: 0.5871 - accuracy: 0.7429
# Epoch 6/25
#  - 1s - loss: 0.5076 - accuracy: 0.7671
# Epoch 7/25
#  - 0s - loss: 0.5107 - accuracy: 0.7714
# Epoch 8/25
#  - 1s - loss: 0.4938 - accuracy: 0.7857
# Epoch 9/25
#  - 1s - loss: 0.4819 - accuracy: 0.7971
# Epoch 10/25
#  - 0s - loss: 0.4684 - accuracy: 0.8129
# Epoch 11/25
#  - 1s - loss: 0.4206 - accuracy: 0.8329
# Epoch 12/25
#  - 1s - loss: 0.4659 - accuracy: 0.7843
# Epoch 13/25
#  - 1s - loss: 0.4194 - accuracy: 0.8314
# Epoch 14/25
#  - 1s - loss: 0.4514 - accuracy: 0.8157
# Epoch 15/25
#  - 1s - loss: 0.4124 - accuracy: 0.8343
# Epoch 16/25
#  - 0s - loss: 0.4003 - accuracy: 0.8529
# Epoch 17/25
#  - 1s - loss: 0.3958 - accuracy: 0.8400
# Epoch 18/25
#  - 0s - loss: 0.3222 - accuracy: 0.8757
# Epoch 19/25
# ...
#  - 2s - loss: 0.3565 - accuracy: 0.8643
# Epoch 12/25
#  - 2s - loss: 0.3414 - accuracy: 0.8700
# Epoch 13/25
#  - 2s - loss: 0.3284 - accuracy: 0.8771
# Epoch 14/25
#  - 2s - loss: 0.3496 - accuracy: 0.8786
# Epoch 15/25
#  - 2s - loss: 0.3173 - accuracy: 0.8714
# Epoch 16/25
#  - 2s - loss: 0.3299 - accuracy: 0.8857
# Epoch 17/25
#  - 2s - loss: 0.3130 - accuracy: 0.8771
# Epoch 18/25
#  - 2s - loss: 0.3304 - accuracy: 0.8743
# Epoch 19/25
#  - 2s - loss: 0.3085 - accuracy: 0.8829
# Epoch 20/25
#  - 2s - loss: 0.3113 - accuracy: 0.8771
# Epoch 21/25
#  - 2s - loss: 0.3287 - accuracy: 0.8914
# Epoch 22/25
#  - 2s - loss: 0.2836 - accuracy: 0.8857
# Epoch 23/25
#  - 2s - loss: 0.2943 - accuracy: 0.8986
# Epoch 24/25
#  - 2s - loss: 0.2947 - accuracy: 0.8871
# Epoch 25/25
#  - 2s - loss: 0.2812 - accuracy: 0.8914
# 175/175 [==============================] - 0s 661us/step
# activation: relu, optimizer=adagrad
# Epoch 1/25
#  - 2s - loss: 0.8753 - accuracy: 0.6929
# Epoch 2/25
#  - 2s - loss: 0.5779 - accuracy: 0.7500
# Epoch 3/25
#  - 2s - loss: 0.5363 - accuracy: 0.7843
# Epoch 4/25
#  - 2s - loss: 0.4880 - accuracy: 0.7900
# Epoch 5/25
#  - 2s - loss: 0.4652 - accuracy: 0.8257
# Epoch 6/25
#  - 2s - loss: 0.4661 - accuracy: 0.8057
# Epoch 7/25
#  - 2s - loss: 0.4329 - accuracy: 0.8129
# Epoch 8/25
#  - 2s - loss: 0.3983 - accuracy: 0.8343
# Epoch 9/25
#  - 2s - loss: 0.3888 - accuracy: 0.8600
# Epoch 10/25
#  - 2s - loss: 0.3917 - accuracy: 0.8529
# Epoch 11/25
#  - 2s - loss: 0.3782 - accuracy: 0.8557
# Epoch 12/25
#  - 2s - loss: 0.3452 - accuracy: 0.8643
# Epoch 13/25
#  - 2s - loss: 0.3826 - accuracy: 0.8457
# Epoch 14/25
#  - 2s - loss: 0.3593 - accuracy: 0.8729
# Epoch 15/25
#  - 2s - loss: 0.3605 - accuracy: 0.8586
# Epoch 16/25
#  - 2s - loss: 0.3575 - accuracy: 0.8657
# Epoch 17/25
#  - 2s - loss: 0.3507 - accuracy: 0.8700
# Epoch 18/25
#  - 2s - loss: 0.3407 - accuracy: 0.8786
# Epoch 19/25
#  - 2s - loss: 0.3300 - accuracy: 0.8657
# Epoch 20/25
#  - 2s - loss: 0.3020 - accuracy: 0.8829
# Epoch 21/25
#  - 2s - loss: 0.3560 - accuracy: 0.8671
# Epoch 22/25
#  - 2s - loss: 0.3187 - accuracy: 0.8786
# Epoch 23/25
#  - 2s - loss: 0.3213 - accuracy: 0.8714
# Epoch 24/25
#  - 2s - loss: 0.3486 - accuracy: 0.8686
# Epoch 25/25
#  - 2s - loss: 0.3124 - accuracy: 0.8829
# 175/175 [==============================] - 0s 650us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5755 - accuracy: 0.7186
# Epoch 2/25
#  - 1s - loss: 0.5275 - accuracy: 0.7600
# Epoch 3/25
#  - 1s - loss: 0.4683 - accuracy: 0.7829
# Epoch 4/25
#  - 1s - loss: 0.4723 - accuracy: 0.7986
# Epoch 5/25
#  - 1s - loss: 0.4450 - accuracy: 0.8229
# Epoch 6/25
#  - 1s - loss: 0.4199 - accuracy: 0.8257
# Epoch 7/25
#  - 1s - loss: 0.3897 - accuracy: 0.8414
# Epoch 8/25
#  - 1s - loss: 0.3751 - accuracy: 0.8486
# Epoch 9/25
#  - 1s - loss: 0.3752 - accuracy: 0.8600
# Epoch 10/25
#  - 1s - loss: 0.3662 - accuracy: 0.8729
# Epoch 11/25
#  - 1s - loss: 0.3309 - accuracy: 0.8743
# Epoch 12/25
#  - 1s - loss: 0.3575 - accuracy: 0.8743
# Epoch 13/25
#  - 1s - loss: 0.3392 - accuracy: 0.8657
# Epoch 14/25
#  - 1s - loss: 0.3514 - accuracy: 0.8671
# Epoch 15/25
#  - 1s - loss: 0.3693 - accuracy: 0.8700
# Epoch 16/25
#  - 1s - loss: 0.3293 - accuracy: 0.8786
# Epoch 17/25
#  - 1s - loss: 0.4003 - accuracy: 0.8514
# Epoch 18/25
#  - 1s - loss: 0.3196 - accuracy: 0.8871
# Epoch 19/25
#  - 1s - loss: 0.3611 - accuracy: 0.8586
# Epoch 20/25
#  - 1s - loss: 0.3564 - accuracy: 0.8586
# Epoch 21/25
#  - 1s - loss: 0.3455 - accuracy: 0.8643
# Epoch 22/25
#  - 1s - loss: 0.3276 - accuracy: 0.8729
# Epoch 23/25
#  - 1s - loss: 0.3356 - accuracy: 0.8800
# Epoch 24/25
#  - 1s - loss: 0.3239 - accuracy: 0.8729
# Epoch 25/25
#  - 1s - loss: 0.3349 - accuracy: 0.8786
# 175/175 [==============================] - 0s 330us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5884 - accuracy: 0.7014
# Epoch 2/25
#  - 1s - loss: 0.4757 - accuracy: 0.7900
# Epoch 3/25
#  - 1s - loss: 0.4565 - accuracy: 0.8171
# Epoch 4/25
#  - 1s - loss: 0.4251 - accuracy: 0.8343
# Epoch 5/25
#  - 1s - loss: 0.4037 - accuracy: 0.8343
# Epoch 6/25
#  - 1s - loss: 0.3829 - accuracy: 0.8629
# Epoch 7/25
#  - 1s - loss: 0.3949 - accuracy: 0.8643
# Epoch 8/25
#  - 1s - loss: 0.3774 - accuracy: 0.8486
# Epoch 9/25
#  - 1s - loss: 0.3256 - accuracy: 0.8857
# Epoch 10/25
#  - 1s - loss: 0.3443 - accuracy: 0.8729
# Epoch 11/25
#  - 1s - loss: 0.3476 - accuracy: 0.8671
# Epoch 12/25
#  - 1s - loss: 0.3584 - accuracy: 0.8671
# Epoch 13/25
#  - 1s - loss: 0.3426 - accuracy: 0.8657
# Epoch 14/25
#  - 1s - loss: 0.3338 - accuracy: 0.8943
# Epoch 15/25
#  - 1s - loss: 0.3335 - accuracy: 0.8800
# Epoch 16/25
#  - 1s - loss: 0.3472 - accuracy: 0.8729
# Epoch 17/25
#  - 1s - loss: 0.3498 - accuracy: 0.8629
# Epoch 18/25
#  - 1s - loss: 0.3232 - accuracy: 0.8829
# Epoch 19/25
#  - 1s - loss: 0.3087 - accuracy: 0.8886
# Epoch 20/25
#  - 1s - loss: 0.3474 - accuracy: 0.8857
# Epoch 21/25
#  - 1s - loss: 0.3258 - accuracy: 0.8786
# Epoch 22/25
#  - 1s - loss: 0.3349 - accuracy: 0.8829
# Epoch 23/25
#  - 1s - loss: 0.3252 - accuracy: 0.8743
# Epoch 24/25
#  - 1s - loss: 0.3321 - accuracy: 0.8843
# Epoch 25/25
#  - 1s - loss: 0.3001 - accuracy: 0.8929
# 175/175 [==============================] - 0s 413us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5477 - accuracy: 0.7429
# Epoch 2/25
#  - 1s - loss: 0.5124 - accuracy: 0.7800
# Epoch 3/25
#  - 1s - loss: 0.4562 - accuracy: 0.8043
# Epoch 4/25
#  - 1s - loss: 0.4587 - accuracy: 0.8129
# Epoch 5/25
#  - 1s - loss: 0.4352 - accuracy: 0.8243
# Epoch 6/25
#  - 1s - loss: 0.4327 - accuracy: 0.8386
# Epoch 7/25
#  - 1s - loss: 0.3689 - accuracy: 0.8600
# Epoch 8/25
#  - 1s - loss: 0.3628 - accuracy: 0.8586
# Epoch 9/25
#  - 1s - loss: 0.3727 - accuracy: 0.8571
# Epoch 10/25
#  - 1s - loss: 0.3546 - accuracy: 0.8529
# Epoch 11/25
#  - 1s - loss: 0.3575 - accuracy: 0.8600
# Epoch 12/25
#  - 1s - loss: 0.3283 - accuracy: 0.8829
# Epoch 13/25
#  - 1s - loss: 0.3774 - accuracy: 0.8443
# Epoch 14/25
#  - 1s - loss: 0.3359 - accuracy: 0.8786
# Epoch 15/25
#  - 1s - loss: 0.3458 - accuracy: 0.8743
# Epoch 16/25
#  - 1s - loss: 0.3540 - accuracy: 0.8714
# Epoch 17/25
#  - 1s - loss: 0.3711 - accuracy: 0.8714
# Epoch 18/25
#  - 1s - loss: 0.3320 - accuracy: 0.8771
# Epoch 19/25
#  - 1s - loss: 0.3360 - accuracy: 0.8686
# Epoch 20/25
#  - 1s - loss: 0.3315 - accuracy: 0.8729
# Epoch 21/25
#  - 1s - loss: 0.3117 - accuracy: 0.8814
# Epoch 22/25
#  - 1s - loss: 0.3308 - accuracy: 0.8743
# Epoch 23/25
#  - 1s - loss: 0.3447 - accuracy: 0.8714
# Epoch 24/25
#  - 1s - loss: 0.3133 - accuracy: 0.8814
# Epoch 25/25
#  - 1s - loss: 0.3378 - accuracy: 0.8843
# 175/175 [==============================] - 0s 359us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6271 - accuracy: 0.6786
# Epoch 2/25
#  - 1s - loss: 0.5285 - accuracy: 0.7571
# Epoch 3/25
#  - 1s - loss: 0.4625 - accuracy: 0.8143
# Epoch 4/25
#  - 1s - loss: 0.4658 - accuracy: 0.7986
# Epoch 5/25
#  - 1s - loss: 0.4466 - accuracy: 0.8100
# Epoch 6/25
#  - 1s - loss: 0.3932 - accuracy: 0.8571
# Epoch 7/25
#  - 1s - loss: 0.3908 - accuracy: 0.8357
# Epoch 8/25
#  - 1s - loss: 0.3860 - accuracy: 0.8457
# Epoch 9/25
#  - 1s - loss: 0.4034 - accuracy: 0.8371
# Epoch 10/25
#  - 1s - loss: 0.3555 - accuracy: 0.8786
# Epoch 11/25
#  - 1s - loss: 0.3751 - accuracy: 0.8443
# Epoch 12/25
#  - 1s - loss: 0.3589 - accuracy: 0.8700
# Epoch 13/25
#  - 1s - loss: 0.3840 - accuracy: 0.8557
# Epoch 14/25
#  - 1s - loss: 0.3457 - accuracy: 0.8700
# Epoch 15/25
#  - 1s - loss: 0.3331 - accuracy: 0.8771
# Epoch 16/25
#  - 1s - loss: 0.3464 - accuracy: 0.8757
# Epoch 17/25
#  - 1s - loss: 0.3518 - accuracy: 0.8600
# Epoch 18/25
#  - 1s - loss: 0.3666 - accuracy: 0.8557
# Epoch 19/25
#  - 1s - loss: 0.3316 - accuracy: 0.8586
# Epoch 20/25
#  - 1s - loss: 0.3306 - accuracy: 0.8843
# Epoch 21/25
#  - 1s - loss: 0.3583 - accuracy: 0.8686
# Epoch 22/25
#  - 1s - loss: 0.3217 - accuracy: 0.8800
# Epoch 23/25
#  - 1s - loss: 0.3191 - accuracy: 0.8800
# Epoch 24/25
#  - 1s - loss: 0.3256 - accuracy: 0.8900
# Epoch 25/25
#  - 1s - loss: 0.3398 - accuracy: 0.8671
# 175/175 [==============================] - 0s 462us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5751 - accuracy: 0.6986
# Epoch 2/25
#  - 1s - loss: 0.5153 - accuracy: 0.7700
# Epoch 3/25
#  - 1s - loss: 0.4992 - accuracy: 0.7671
# Epoch 4/25
#  - 1s - loss: 0.4757 - accuracy: 0.8200
# Epoch 5/25
#  - 1s - loss: 0.4443 - accuracy: 0.8286
# Epoch 6/25
#  - 1s - loss: 0.4037 - accuracy: 0.8586
# Epoch 7/25
#  - 1s - loss: 0.3899 - accuracy: 0.8486
# Epoch 8/25
#  - 1s - loss: 0.4054 - accuracy: 0.8443
# Epoch 9/25
#  - 1s - loss: 0.3931 - accuracy: 0.8486
# Epoch 10/25
#  - 1s - loss: 0.3646 - accuracy: 0.8614
# Epoch 11/25
#  - 1s - loss: 0.4016 - accuracy: 0.8543
# Epoch 12/25
#  - 1s - loss: 0.3680 - accuracy: 0.8586
# Epoch 13/25
#  - 1s - loss: 0.3568 - accuracy: 0.8657
# Epoch 14/25
#  - 1s - loss: 0.3682 - accuracy: 0.8557
# Epoch 15/25
#  - 1s - loss: 0.3891 - accuracy: 0.8686
# Epoch 16/25
#  - 1s - loss: 0.3609 - accuracy: 0.8771
# Epoch 17/25
#  - 1s - loss: 0.3587 - accuracy: 0.8729
# Epoch 18/25
#  - 1s - loss: 0.3355 - accuracy: 0.8714
# Epoch 19/25
#  - 1s - loss: 0.3576 - accuracy: 0.8729
# Epoch 20/25
#  - 1s - loss: 0.3573 - accuracy: 0.8629
# Epoch 21/25
#  - 1s - loss: 0.3275 - accuracy: 0.8629
# Epoch 22/25
#  - 1s - loss: 0.3420 - accuracy: 0.8814
# Epoch 23/25
#  - 1s - loss: 0.3459 - accuracy: 0.8800
# Epoch 24/25
#  - 1s - loss: 0.3260 - accuracy: 0.8886
# Epoch 25/25
#  - 1s - loss: 0.3253 - accuracy: 0.8829
# 175/175 [==============================] - 0s 473us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6009 - accuracy: 0.7129
# Epoch 2/25
#  - 1s - loss: 0.5584 - accuracy: 0.7686
# Epoch 3/25
#  - 1s - loss: 0.4803 - accuracy: 0.7829
# Epoch 4/25
#  - 1s - loss: 0.4723 - accuracy: 0.7957
# Epoch 5/25
#  - 1s - loss: 0.4112 - accuracy: 0.8471
# Epoch 6/25
#  - 1s - loss: 0.3955 - accuracy: 0.8500
# Epoch 7/25
#  - 1s - loss: 0.3805 - accuracy: 0.8529
# Epoch 8/25
#  - 1s - loss: 0.3811 - accuracy: 0.8529
# Epoch 9/25
#  - 1s - loss: 0.3886 - accuracy: 0.8557
# Epoch 10/25
#  - 1s - loss: 0.3467 - accuracy: 0.8643
# Epoch 11/25
#  - 1s - loss: 0.3729 - accuracy: 0.8571
# Epoch 12/25
#  - 1s - loss: 0.3794 - accuracy: 0.8657
# Epoch 13/25
#  - 1s - loss: 0.3617 - accuracy: 0.8714
# Epoch 14/25
#  - 1s - loss: 0.3348 - accuracy: 0.8786
# Epoch 15/25
#  - 1s - loss: 0.3106 - accuracy: 0.8771
# Epoch 16/25
#  - 1s - loss: 0.3246 - accuracy: 0.8771
# Epoch 17/25
#  - 1s - loss: 0.3644 - accuracy: 0.8629
# Epoch 18/25
#  - 1s - loss: 0.3356 - accuracy: 0.8771
# Epoch 19/25
#  - 372s - loss: 0.3550 - accuracy: 0.8714
# Epoch 20/25
#  - 1s - loss: 0.3745 - accuracy: 0.8600
# Epoch 21/25
#  - 4s - loss: 0.3204 - accuracy: 0.8800
# Epoch 22/25
#  - 1s - loss: 0.3266 - accuracy: 0.8629
# Epoch 23/25
#  - 1s - loss: 0.3400 - accuracy: 0.8700
# Epoch 24/25
#  - 1s - loss: 0.3259 - accuracy: 0.8729
# Epoch 25/25
#  - 1s - loss: 0.3169 - accuracy: 0.8914
# 175/175 [==============================] - 0s 524us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6008 - accuracy: 0.7086
# Epoch 2/25
#  - 1s - loss: 0.5572 - accuracy: 0.7500
# Epoch 3/25
#  - 1s - loss: 0.4763 - accuracy: 0.8043
# Epoch 4/25
#  - 1s - loss: 0.4273 - accuracy: 0.8157
# Epoch 5/25
#  - 1s - loss: 0.3494 - accuracy: 0.8543
# Epoch 6/25
#  - 1s - loss: 0.3925 - accuracy: 0.8400
# Epoch 7/25
#  - 1s - loss: 0.3924 - accuracy: 0.8500
# Epoch 8/25
#  - 1s - loss: 0.3901 - accuracy: 0.8614
# Epoch 9/25
#  - 1s - loss: 0.3419 - accuracy: 0.8786
# Epoch 10/25
#  - 1s - loss: 0.3727 - accuracy: 0.8557
# Epoch 11/25
#  - 1s - loss: 0.3510 - accuracy: 0.8686
# Epoch 12/25
#  - 1s - loss: 0.3250 - accuracy: 0.8700
# Epoch 13/25
#  - 1s - loss: 0.3382 - accuracy: 0.8686
# Epoch 14/25
#  - 1s - loss: 0.3263 - accuracy: 0.8786
# Epoch 15/25
#  - 1s - loss: 0.3576 - accuracy: 0.8643
# Epoch 16/25
#  - 1s - loss: 0.3489 - accuracy: 0.8686
# Epoch 17/25
#  - 1s - loss: 0.3296 - accuracy: 0.8671
# Epoch 18/25
#  - 1s - loss: 0.3010 - accuracy: 0.8871
# Epoch 19/25
#  - 1s - loss: 0.3503 - accuracy: 0.8757
# Epoch 20/25
#  - 1s - loss: 0.3369 - accuracy: 0.8843
# Epoch 21/25
#  - 1s - loss: 0.2909 - accuracy: 0.8943
# Epoch 22/25
#  - 1s - loss: 0.3166 - accuracy: 0.8743
# Epoch 23/25
#  - 1s - loss: 0.3227 - accuracy: 0.8800
# Epoch 24/25
#  - 1s - loss: 0.3009 - accuracy: 0.8943
# Epoch 25/25
#  - 1s - loss: 0.3014 - accuracy: 0.8886
# 175/175 [==============================] - 0s 410us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.6066 - accuracy: 0.7129
# Epoch 2/25
#  - 1s - loss: 0.5086 - accuracy: 0.7800
# Epoch 3/25
#  - 1s - loss: 0.4546 - accuracy: 0.8171
# Epoch 4/25
#  - 1s - loss: 0.4567 - accuracy: 0.8129
# Epoch 5/25
#  - 1s - loss: 0.3829 - accuracy: 0.8414
# Epoch 6/25
#  - 1s - loss: 0.4138 - accuracy: 0.8257
# Epoch 7/25
#  - 1s - loss: 0.3876 - accuracy: 0.8371
# Epoch 8/25
#  - 1s - loss: 0.3802 - accuracy: 0.8600
# Epoch 9/25
#  - 1s - loss: 0.3634 - accuracy: 0.8614
# Epoch 10/25
#  - 1s - loss: 0.3461 - accuracy: 0.8800
# Epoch 11/25
#  - 1s - loss: 0.3859 - accuracy: 0.8571
# Epoch 12/25
#  - 1s - loss: 0.3396 - accuracy: 0.8657
# Epoch 13/25
#  - 1s - loss: 0.3442 - accuracy: 0.8643
# Epoch 14/25
#  - 1s - loss: 0.3348 - accuracy: 0.8729
# Epoch 15/25
#  - 1s - loss: 0.3331 - accuracy: 0.8843
# Epoch 16/25
#  - 1s - loss: 0.3555 - accuracy: 0.8671
# Epoch 17/25
#  - 1s - loss: 0.3432 - accuracy: 0.8729
# Epoch 18/25
#  - 1s - loss: 0.3392 - accuracy: 0.8914
# Epoch 19/25
#  - 1s - loss: 0.3358 - accuracy: 0.8886
# Epoch 20/25
#  - 1s - loss: 0.3443 - accuracy: 0.8657
# Epoch 21/25
#  - 1s - loss: 0.3407 - accuracy: 0.8786
# Epoch 22/25
#  - 1s - loss: 0.3321 - accuracy: 0.8857
# Epoch 23/25
#  - 1s - loss: 0.3239 - accuracy: 0.8771
# Epoch 24/25
#  - 1s - loss: 0.3369 - accuracy: 0.8843
# Epoch 25/25
#  - 1s - loss: 0.3636 - accuracy: 0.8600
# 175/175 [==============================] - 0s 530us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5756 - accuracy: 0.7100
# Epoch 2/25
#  - 1s - loss: 0.5239 - accuracy: 0.7686
# Epoch 3/25
#  - 1s - loss: 0.5025 - accuracy: 0.8100
# Epoch 4/25
#  - 1s - loss: 0.4278 - accuracy: 0.8386
# Epoch 5/25
#  - 1s - loss: 0.4391 - accuracy: 0.8229
# Epoch 6/25
#  - 1s - loss: 0.4129 - accuracy: 0.8429
# Epoch 7/25
#  - 1s - loss: 0.3869 - accuracy: 0.8600
# Epoch 8/25
#  - 1s - loss: 0.4003 - accuracy: 0.8514
# Epoch 9/25
#  - 1s - loss: 0.3767 - accuracy: 0.8600
# Epoch 10/25
#  - 1s - loss: 0.3950 - accuracy: 0.8629
# Epoch 11/25
#  - 1s - loss: 0.3801 - accuracy: 0.8657
# Epoch 12/25
#  - 1s - loss: 0.3690 - accuracy: 0.8571
# Epoch 13/25
#  - 1s - loss: 0.3501 - accuracy: 0.8729
# Epoch 14/25
#  - 1s - loss: 0.3325 - accuracy: 0.8657
# Epoch 15/25
#  - 1s - loss: 0.3560 - accuracy: 0.8571
# Epoch 16/25
#  - 1s - loss: 0.3472 - accuracy: 0.8771
# Epoch 17/25
#  - 1s - loss: 0.3458 - accuracy: 0.8786
# Epoch 18/25
#  - 1s - loss: 0.3248 - accuracy: 0.8857
# Epoch 19/25
#  - 1s - loss: 0.3585 - accuracy: 0.8657
# Epoch 20/25
#  - 1s - loss: 0.3395 - accuracy: 0.8771
# Epoch 21/25
#  - 1s - loss: 0.3540 - accuracy: 0.8629
# Epoch 22/25
#  - 1s - loss: 0.3174 - accuracy: 0.8871
# Epoch 23/25
#  - 1s - loss: 0.3485 - accuracy: 0.8729
# Epoch 24/25
#  - 1s - loss: 0.3168 - accuracy: 0.8900
# Epoch 25/25
#  - 1s - loss: 0.3062 - accuracy: 0.8829
# 175/175 [==============================] - 0s 792us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/25
#  - 1s - loss: 0.5937 - accuracy: 0.7086
# Epoch 2/25
#  - 1s - loss: 0.5431 - accuracy: 0.7571
# Epoch 3/25
#  - 1s - loss: 0.4867 - accuracy: 0.7900
# Epoch 4/25
#  - 1s - loss: 0.4448 - accuracy: 0.8143
# Epoch 5/25
#  - 1s - loss: 0.4020 - accuracy: 0.8357
# Epoch 6/25
#  - 1s - loss: 0.3859 - accuracy: 0.8500
# Epoch 7/25
#  - 1s - loss: 0.4063 - accuracy: 0.8314
# Epoch 8/25
#  - 1s - loss: 0.3662 - accuracy: 0.8629
# Epoch 9/25
#  - 1s - loss: 0.3996 - accuracy: 0.8343
# Epoch 10/25
#  - 1s - loss: 0.3578 - accuracy: 0.8586
# Epoch 11/25
#  - 1s - loss: 0.3752 - accuracy: 0.8529
# Epoch 12/25
#  - 1s - loss: 0.3557 - accuracy: 0.8714
# Epoch 13/25
#  - 1s - loss: 0.3499 - accuracy: 0.8686
# Epoch 14/25
#  - 1s - loss: 0.3745 - accuracy: 0.8600
# Epoch 15/25
#  - 1s - loss: 0.3915 - accuracy: 0.8429
# Epoch 16/25
#  - 1s - loss: 0.3312 - accuracy: 0.8929
# Epoch 17/25
#  - 1s - loss: 0.3576 - accuracy: 0.8700
# Epoch 18/25
#  - 1s - loss: 0.3389 - accuracy: 0.8600
# Epoch 19/25
#  - 1s - loss: 0.3242 - accuracy: 0.8857
# Epoch 20/25
#  - 1s - loss: 0.3411 - accuracy: 0.8700
# Epoch 21/25
#  - 1s - loss: 0.3324 - accuracy: 0.8743
# Epoch 22/25
#  - 1s - loss: 0.3402 - accuracy: 0.8729
# Epoch 23/25
#  - 1s - loss: 0.3396 - accuracy: 0.8843
# Epoch 24/25
#  - 1s - loss: 0.3306 - accuracy: 0.8771
# Epoch 25/25
#  - 1s - loss: 0.3595 - accuracy: 0.8629

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8502857208251953
# {'activation': 'relu', 'dropout': 0.5, 'input_dim': 316, 'optimizer': 'adagrad', 'out_dim': 500}

# %% [markdown]
# best_params_로 하니깐 결과가 0.87이 나옴

# %%
model_1 = create_model_5dim_layer_perceptron(len(x_train.columns), \
                                           activation=grid.best_params_['activation'], \
                                           optimizer=grid.best_params_['optimizer'], \
                                           out_dim=grid.best_params_['out_dim'], \
                                           dropout=grid.best_params_['dropout'])
fit = model.fit(x_train, y_train, epochs=28, batch_size=16, verbose=2)
# Out:
# activation: relu, optimizer=adagrad
# Epoch 1/28
#  - 0s - loss: 0.2741 - accuracy: 0.8994
# Epoch 2/28
#  - 0s - loss: 0.2471 - accuracy: 0.8983
# Epoch 3/28
#  - 0s - loss: 0.2533 - accuracy: 0.8971
# Epoch 4/28
#  - 0s - loss: 0.2589 - accuracy: 0.8903
# Epoch 5/28
#  - 0s - loss: 0.2659 - accuracy: 0.9006
# Epoch 6/28
#  - 0s - loss: 0.2621 - accuracy: 0.9017
# Epoch 7/28
#  - 0s - loss: 0.2443 - accuracy: 0.9029
# Epoch 8/28
#  - 0s - loss: 0.2516 - accuracy: 0.8994
# Epoch 9/28
#  - 0s - loss: 0.2540 - accuracy: 0.8949
# Epoch 10/28
#  - 0s - loss: 0.2509 - accuracy: 0.8960
# Epoch 11/28
#  - 0s - loss: 0.2313 - accuracy: 0.9097
# Epoch 12/28
#  - 0s - loss: 0.2602 - accuracy: 0.8994
# Epoch 13/28
#  - 0s - loss: 0.2415 - accuracy: 0.9074
# Epoch 14/28
#  - 0s - loss: 0.2534 - accuracy: 0.8994
# Epoch 15/28
#  - 0s - loss: 0.2495 - accuracy: 0.8960
# Epoch 16/28
#  - 0s - loss: 0.2619 - accuracy: 0.9063
# Epoch 17/28
#  - 0s - loss: 0.2458 - accuracy: 0.8994
# Epoch 18/28
#  - 0s - loss: 0.2531 - accuracy: 0.8971
# Epoch 19/28
#  - 0s - loss: 0.2361 - accuracy: 0.9051
# Epoch 20/28
#  - 0s - loss: 0.2536 - accuracy: 0.9006
# Epoch 21/28
#  - 0s - loss: 0.2398 - accuracy: 0.9063
# Epoch 22/28
#  - 0s - loss: 0.2597 - accuracy: 0.8949
# Epoch 23/28
#  - 0s - loss: 0.2604 - accuracy: 0.9017
# Epoch 24/28
#  - 0s - loss: 0.2405 - accuracy: 0.9143
# Epoch 25/28
#  - 0s - loss: 0.2444 - accuracy: 0.9006
# Epoch 26/28
#  - 0s - loss: 0.2586 - accuracy: 0.8949
# Epoch 27/28
#  - 0s - loss: 0.2509 - accuracy: 0.9017
# Epoch 28/28
#  - 0s - loss: 0.2485 - accuracy: 0.9097

# %%
# Predict
y_test_proba = model_1.predict(x_test)
# y_test_proba = grid.predict(x_test)
y_test = numpy.round(y_test_proba).astype(int)

# Combine the data frame of PassengerId and the result
df_output = pandas.concat([y_test_index, pandas.DataFrame(y_test, columns=['Survived'])], axis=1)

# Write result.csv to the current directory
df_output.to_csv('result.csv', index=False)

# Training
# model = create_model_5dim_layer_perceptron(grid.best_params_)

# %%
loss, acc=model.evaluate(x_test,y_test)
print(loss, acc)
# Out:
# 418/418 [==============================] - 0s 68us/step
# 1.104421151311774 0.6866028904914856

# %%
model_2 = create_model_5dim_layer_perceptron(len(x_train.columns), \
                                           activation=grid.best_params_['activation'], \
                                           optimizer=grid.best_params_['optimizer'], \
                                           out_dim=grid.best_params_['out_dim'], \
                                           dropout=grid.best_params_['dropout'])
fit = model.fit(x_train, y_train, epochs=28, batch_size=16, verbose=2)
# Out:
# activation: relu, optimizer=adagrad
# Epoch 1/28
#  - 0s - loss: 0.2465 - accuracy: 0.9051
# Epoch 2/28
#  - 0s - loss: 0.2572 - accuracy: 0.8983
# Epoch 3/28
#  - 0s - loss: 0.2606 - accuracy: 0.9040
# Epoch 4/28
#  - 0s - loss: 0.2501 - accuracy: 0.8949
# Epoch 5/28
#  - 0s - loss: 0.2496 - accuracy: 0.8994
# Epoch 6/28
#  - 0s - loss: 0.2530 - accuracy: 0.8983
# Epoch 7/28
#  - 0s - loss: 0.2378 - accuracy: 0.9074
# Epoch 8/28
#  - 0s - loss: 0.2455 - accuracy: 0.8994
# Epoch 9/28
#  - 0s - loss: 0.2433 - accuracy: 0.9097
# Epoch 10/28
#  - 0s - loss: 0.2321 - accuracy: 0.9074
# Epoch 11/28
#  - 0s - loss: 0.2447 - accuracy: 0.9086
# Epoch 12/28
#  - 0s - loss: 0.2431 - accuracy: 0.8926
# Epoch 13/28
#  - 0s - loss: 0.2625 - accuracy: 0.8960
# Epoch 14/28
#  - 0s - loss: 0.2529 - accuracy: 0.9051
# Epoch 15/28
#  - 0s - loss: 0.2343 - accuracy: 0.9097
# Epoch 16/28
#  - 0s - loss: 0.2559 - accuracy: 0.9006
# Epoch 17/28
#  - 0s - loss: 0.2520 - accuracy: 0.8994
# Epoch 18/28
#  - 0s - loss: 0.2591 - accuracy: 0.8960
# Epoch 19/28
#  - 0s - loss: 0.2338 - accuracy: 0.9029
# Epoch 20/28
#  - 0s - loss: 0.2510 - accuracy: 0.9131
# Epoch 21/28
#  - 0s - loss: 0.2308 - accuracy: 0.9109
# Epoch 22/28
#  - 0s - loss: 0.2428 - accuracy: 0.9074
# Epoch 23/28
#  - 0s - loss: 0.2394 - accuracy: 0.9040
# Epoch 24/28
#  - 0s - loss: 0.2416 - accuracy: 0.9040
# Epoch 25/28
#  - 0s - loss: 0.2458 - accuracy: 0.8971
# Epoch 26/28
#  - 0s - loss: 0.2582 - accuracy: 0.9097
# Epoch 27/28
#  - 0s - loss: 0.2437 - accuracy: 0.9063
# Epoch 28/28
#  - 0s - loss: 0.2406 - accuracy: 0.9029

# %%
# Predict
y_test_proba = model_2.predict(x_test)
# y_test_proba = grid.predict(x_test)
y_test = numpy.round(y_test_proba).astype(int)

# Combine the data frame of PassengerId and the result
df_output = pandas.concat([y_test_index, pandas.DataFrame(y_test, columns=['Survived'])], axis=1)

# Write result.csv to the current directory
df_output.to_csv('result2.csv', index=False)

loss, acc=model.evaluate(x_test,y_test)
print(loss, acc)
# Out:
# 418/418 [==============================] - 0s 73us/step
# 1.6045313497479452 0.3349282443523407
