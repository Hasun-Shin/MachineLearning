# %%
import numpy
import pandas
import datetime

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers.core import Dropout
from keras.layers.normalization import BatchNormalization

from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
############################################################
# SibSp　-> one hot enconding
# One hot encoding SibSp
############################################################
def get_dummies_sibSp(df_all, df, df_test) :

    categories = set(df_all['SibSp'].unique())
    df['SibSp'] = pandas.Categorical(df['SibSp'], categories=categories)
    df_test['SibSp'] = pandas.Categorical(df_test['SibSp'], categories=categories)

    df = pandas.get_dummies(df, columns=['SibSp'])
    df_test = pandas.get_dummies(df_test, columns=['SibSp'])

    return df, df_test

############################################################
# Parch　-> one hot enconding
# One hot encoding SibSp
############################################################
def get_dummies_parch(df_all, df, df_test) :

    categories = set(df_all['Parch'].unique())
    df['Parch'] = pandas.Categorical(df['Parch'], categories=categories)
    df_test['Parch'] = pandas.Categorical(df_test['Parch'], categories=categories)

    df = pandas.get_dummies(df, columns=['Parch'])
    df_test = pandas.get_dummies(df_test, columns=['Parch'])

    return df, df_test

############################################################
# Ticket　-> one hot enconding
# One hot encoding Ticket
############################################################
def get_dummies_ticket(df_all, df, df_test) :

    ticket_values = df_all['Ticket'].value_counts()
    ticket_values = ticket_values[ticket_values > 1]
    ticket_values = pandas.Series(ticket_values.index, name='Ticket')
    categories = set(ticket_values.tolist())
    df['Ticket'] = pandas.Categorical(df['Ticket'], categories=categories)
    df_test['Ticket'] = pandas.Categorical(df_test['Ticket'], categories=categories)

    df = pandas.get_dummies(df, columns=['Ticket'])
    df_test = pandas.get_dummies(df_test, columns=['Ticket'])

    return df, df_test

############################################################
# Cabin 
## 객실 위치. 2개 이상 있는 value 찾아서 one- hot- encoding
############################################################
def get_dummies_Cabin(df_all, df, df_test) :

    Cabin_values = df_all['Cabin'].value_counts()
    Cabin_values = Cabin_values[Cabin_values > 1]
    Cabin_values = pandas.Series(Cabin_values.index, name='Cabin')
    categories = set(Cabin_values.tolist())
    df['Cabin'] = pandas.Categorical(df['Cabin'], categories=categories)
    df_test['Cabin'] = pandas.Categorical(df_test['Cabin'], categories=categories)

    df = pandas.get_dummies(df, columns=['Cabin'])
    df_test = pandas.get_dummies(df_test, columns=['Cabin'])

    return df, df_test


############################################################
# Standardization
############################################################
def standardization(df, df_test) :

    standard = StandardScaler()
    df_std = pandas.DataFrame(standard.fit_transform(df[['Pclass', 'Fare']].values), columns=['Pclass', 'Fare'])
    df.loc[:,'Pclass'] = df_std['Pclass']
    df.loc[:,'Fare'] = df_std['Fare']

    df_test_std = pandas.DataFrame(standard.transform(df_test[['Pclass', 'Fare']].values), columns=['Pclass', 'Fare'])
    df_test.loc[:,'Pclass'] = df_test_std['Pclass']
    df_test.loc[:,'Fare'] = df_test_std['Fare']

    return df, df_test

############################################################
# prepare Data
############################################################
def prepareData() :

    ##############################
    # Data preprocessing
    # Extract necessary items
    ##############################
    # Load gender_submission.csv
    df = pandas.read_csv('train.csv')
    df_test = pandas.read_csv('test.csv')

    df_all = pandas.concat([df, df_test], sort=False)

    df_test_index = df_test[['PassengerId']]

    df = df[['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Fare', 'Age', 'Name']]
    df_test = df_test[['Pclass', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Fare', 'Age', 'Name']]

    ##############################
    # Data preprocessing
    # Fill or remove missing values
    ##############################
    df = df[df['Fare'] != 5].reset_index(drop=True)
    df = df[df['Fare'] != 0].reset_index(drop=True)

    ##############################
    # Data preprocessing
    # Digitize labels
    ##############################
    # Gender
    ##############################
    encoder_sex = LabelEncoder()
    df['Sex'] = encoder_sex.fit_transform(df['Sex'].values)
    df_test['Sex'] = encoder_sex.transform(df_test['Sex'].values)

    ##############################
    # Data preprocessing
    # One-Hot Encoding
    ##############################
    ##############################
    # SibSp
    ##############################
    df, df_test = get_dummies_sibSp(df_all, df, df_test)

    ##############################
    # Parch
    ##############################
    df, df_test = get_dummies_parch(df_all, df, df_test)

    ##############################
    # Ticket
    ##############################
    df, df_test = get_dummies_ticket(df_all, df, df_test)

    ##############################
    # Cabin
    ##############################
    df, df_test = get_dummies_Cabin(df_all, df, df_test)
    
    ##############################
    df, df_test = standardization(df, df_test)

    ##############################
    # Data preprocessing
    # Fill or remove missing values
    ##############################
    df.fillna({'Fare':0}, inplace=True)
    df_test.fillna({'Fare':0}, inplace=True)
    df.fillna({'Cabin':0}, inplace=True)
    df_test.fillna({'Cabin':0}, inplace=True) 
    ##############################
    # Age
    ## class 별로 Fare 를 가지고 나이를 추정한 다음, 추정 그룹의 평균으로 결측치를 채움 
    ##############################
    chlid_Age_mean = df[(df["Age"] < 16)]["Age"].mean()
    class3_Age_mean = df[(df["Pclass"]==3)]["Age"].mean()
    class2_Age_mean = df[(df["Pclass"]==2)]["Age"].mean()
    class1_Age_mean = df[(df["Pclass"]==1)]["Age"].mean()

    df.loc[df["Age"].isna() & (df["Pclass"]==3) & (df["Fare"] > 10)]["Age"] = class3_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==3) & (df["Fare"] < 10)]["Age"] = chlid_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==2) & (df["Fare"] == 0)]["Age"] = chlid_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==2) & (df["Fare"] != 0)]["Age"] = class2_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==1) & (df["Fare"] == 0)]["Age"] = chlid_Age_mean
    df.loc[df["Age"].isna() & (df["Pclass"]==1) & (df["Fare"] != 0)]["Age"] = class1_Age_mean
    
    df["Age_Category"] = df["Age"].apply(lambda x: 1 if (x >= 16) & (x < 32)\
                                        else 2 if (x >= 32) & (x < 48)\
                                        else 3 if (x >= 48) & (x < 64)\
                                        else 4 if (x >= 64)\
                                        else 0 if (x < 16)\
                                        else -1)
    
    df["Age"] = df["Age_Category"]
    df.drop(["Age_Category"], axis=1)
    
    chlid_Age_mean = df_test[(df_test["Age"] < 16)]["Age"].mean()
    class3_Age_mean = df_test[(df_test["Pclass"]==3)]["Age"].mean()
    class2_Age_mean = df_test[(df_test["Pclass"]==2)]["Age"].mean()
    class1_Age_mean = df_test[(df_test["Pclass"]==1)]["Age"].mean()

    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==3) & (df_test["Fare"] > 10)]["Age"] = class3_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==3) & (df_test["Fare"] < 10)]["Age"] = chlid_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==2) & (df_test["Fare"] == 0)]["Age"] = chlid_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==2) & (df_test["Fare"] != 0)]["Age"] = class2_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==1) & (df_test["Fare"] == 0)]["Age"] = chlid_Age_mean
    df_test.loc[df_test["Age"].isna() & (df_test["Pclass"]==1) & (df_test["Fare"] != 0)]["Age"] = class1_Age_mean
    
    df_test["Age_Category"] = df_test["Age"].apply(lambda x: 1 if (x >= 16) & (x < 32)\
                                        else 2 if (x >= 32) & (x < 48)\
                                        else 3 if (x >= 48) & (x < 64)\
                                        else 4 if (x >= 64)\
                                        else 0 if (x < 16)\
                                        else -1)
    
    df_test["Age"] = df_test["Age_Category"]
    df_test.drop(["Age_Category"], axis=1)
    
    ##############################
    # Title
    ## 예) Mr, Mrs 등의 용어가 들어간 이름은 귀족 계급이라 추정, 해당 용어가 들어간 귀족들의 이름 대상자들의
    ## 생존율이 높았음을 확인, 따라서 Name 변수에서 귀족들의 특성을 뽑은 Title 변수를 추가함. 
    ##############################
    df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

    df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don',\
                                             'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],\
                                             'Rare')
    df['Title'] = df['Title'].replace('Mlle', 'Miss')
    df['Title'] = df['Title'].replace('Ms', 'Miss')
    df['Title'] = df['Title'].replace('Mme', 'Mrs')
    
    _, df['Title'] = numpy.unique(df['Title'], return_inverse=True)
    
    df_test['Title'] = df_test.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

    df_test['Title'] = df_test['Title'].replace(['Lady', 'Countess','Capt', 'Col', 'Don',\
                                             'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],\
                                             'Rare')
    df_test['Title'] = df_test['Title'].replace('Mlle', 'Miss')
    df_test['Title'] = df_test['Title'].replace('Ms', 'Miss')
    df_test['Title'] = df_test['Title'].replace('Mme', 'Mrs')
    
    _, df_test['Title'] = numpy.unique(df_test['Title'], return_inverse=True)
    
    ##############################
    # Split training data and test data
    ##############################
    x = df.drop(columns='Survived')
    x = x.drop(columns='Name')
    df_test = df_test.drop(columns = "Name")
    y = df[['Survived']]

    return x, y, df_test, df_test_index

##############################
# Model -> 5perceptron
##############################
def create_model_5dim_layer_perceptron(input_dim, \
                                       activation="relu", \
                                       optimizer="adam", \
                                       out_dim=100, \
                                       dropout=0.5):

    model = Sequential()

    # Input - Hidden1
    model.add(Dense(input_dim=input_dim, units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))

    # Hidden1 - Hidden2
    model.add(Dense(units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))

    # Hidden2 - Hidden3
    model.add(Dense(units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))
    
    model.add(Dense(units=out_dim))
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dropout(dropout))

    # Hidden3 - Output
    model.add(Dense(units=1))
    model.add(Activation("sigmoid"))

    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    print(f"activation: {activation}, optimizer={optimizer}")
    return model

# %% [markdown]
# ## GridSearch를 사용하여 최고의 Parameter 찾기

# %%
x_train, y_train, x_test, y_test_index = prepareData()

model = KerasClassifier(build_fn=create_model_5dim_layer_perceptron, verbose=1)
param_grid ={
    'input_dim':[len(x_train.columns)],
    # 'activation': ["relu"],
    # 'optimizer' :["adam"],
    # 'out_dim':[300],
    'activation': ["relu", "sigmoid", "tanh"],
    'optimizer' :["adam", 'adagrad'],
    'out_dim':[500,700],
    'dropout':[0.2, 0.5],
    
}
grid= GridSearchCV(estimator=model,
                   param_grid=param_grid,cv=3)

# %%
# Training
# fit = model.fit(x_train, y_train, epochs=40, batch_size=16, verbose=2)
fit = grid.fit(x_train, y_train, epochs=40, batch_size=16, verbose=2)
print("="*30)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 3/40
#  - 0s - loss: 0.6183 - accuracy: 0.7273
# Epoch 4/40
#  - 0s - loss: 0.5556 - accuracy: 0.7461
# Epoch 5/40
#  - 0s - loss: 0.5009 - accuracy: 0.7736
# Epoch 6/40
#  - 0s - loss: 0.4601 - accuracy: 0.8079
# Epoch 7/40
#  - 0s - loss: 0.4559 - accuracy: 0.8199
# Epoch 8/40
#  - 0s - loss: 0.4291 - accuracy: 0.8302
# Epoch 9/40
#  - 0s - loss: 0.4113 - accuracy: 0.8508
# Epoch 10/40
#  - 0s - loss: 0.4723 - accuracy: 0.8182
# Epoch 11/40
#  - 0s - loss: 0.4250 - accuracy: 0.8302
# Epoch 12/40
#  - 0s - loss: 0.3544 - accuracy: 0.8714
# Epoch 13/40
#  - 0s - loss: 0.3847 - accuracy: 0.8611
# Epoch 14/40
#  - 0s - loss: 0.3886 - accuracy: 0.8559
# Epoch 15/40
#  - 0s - loss: 0.3749 - accuracy: 0.8611
# Epoch 16/40
#  - 0s - loss: 0.3578 - accuracy: 0.8559
# Epoch 17/40
#  - 0s - loss: 0.3446 - accuracy: 0.8799
# Epoch 18/40
#  - 0s - loss: 0.3167 - accuracy: 0.8782
# Epoch 19/40
#  - 0s - loss: 0.3225 - accuracy: 0.8782
# Epoch 20/40
#  - 0s - loss: 0.2950 - accuracy: 0.8851
# Epoch 21/40
#  - 0s - loss: 0.3201 - accuracy: 0.8731
# Epoch 22/40
#  - 0s - loss: 0.3155 - accuracy: 0.8868
# Epoch 23/40
#  - 0s - loss: 0.3031 - accuracy: 0.8902
# Epoch 24/40
#  - 0s - loss: 0.3183 - accuracy: 0.8851
# Epoch 25/40
#  - 0s - loss: 0.3185 - accuracy: 0.8765
# Epoch 26/40
#  - 0s - loss: 0.3467 - accuracy: 0.8611
# Epoch 27/40
#  - 0s - loss: 0.3324 - accuracy: 0.8731
# Epoch 28/40
#  - 0s - loss: 0.3016 - accuracy: 0.8902
# Epoch 29/40
#  - 0s - loss: 0.3098 - accuracy: 0.8851
# Epoch 30/40
#  - 0s - loss: 0.2758 - accuracy: 0.8971
# Epoch 31/40
#  - 0s - loss: 0.2823 - accuracy: 0.8902
# Epoch 32/40
#  - 0s - loss: 0.2667 - accuracy: 0.8988
# Epoch 33/40
#  - 0s - loss: 0.2649 - accuracy: 0.8971
# Epoch 34/40
#  - 0s - loss: 0.2724 - accuracy: 0.8937
# Epoch 35/40
#  - 0s - loss: 0.2637 - accuracy: 0.9057
# Epoch 36/40
#  - 0s - loss: 0.3032 - accuracy: 0.8902
# Epoch 37/40
#  - 0s - loss: 0.2737 - accuracy: 0.9074
# Epoch 38/40
#  - 0s - loss: 0.2822 - accuracy: 0.9074
# Epoch 39/40
#  - 0s - loss: 0.2708 - accuracy: 0.9005
# Epoch 40/40
#  - 0s - loss: 0.2733 - accuracy: 0.8902
# 292/292 [==============================] - 0s 454us/step
# activation: relu, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.7648 - accuracy: 0.6192
# Epoch 2/40
#  - 0s - loss: 0.6801 - accuracy: 0.7067
# Epoch 3/40
#  - 0s - loss: 0.6040 - accuracy: 0.7461
# Epoch 4/40
#  - 0s - loss: 0.5700 - accuracy: 0.7633
# Epoch 5/40
#  - 0s - loss: 0.5711 - accuracy: 0.7358
# Epoch 6/40
#  - 0s - loss: 0.5499 - accuracy: 0.7736
# Epoch 7/40
#  - 0s - loss: 0.5104 - accuracy: 0.7925
# Epoch 8/40
#  - 0s - loss: 0.4531 - accuracy: 0.7993
# Epoch 9/40
#  - 0s - loss: 0.3900 - accuracy: 0.8336
# Epoch 10/40
#  - 0s - loss: 0.4311 - accuracy: 0.8233
# Epoch 11/40
#  - 0s - loss: 0.4283 - accuracy: 0.8370
# Epoch 12/40
#  - 0s - loss: 0.3927 - accuracy: 0.8491
# Epoch 13/40
#  - 0s - loss: 0.3756 - accuracy: 0.8508
# Epoch 14/40
#  - 0s - loss: 0.4033 - accuracy: 0.8576
# Epoch 15/40
#  - 0s - loss: 0.3615 - accuracy: 0.8508
# Epoch 16/40
#  - 0s - loss: 0.3497 - accuracy: 0.8508
# Epoch 17/40
#  - 0s - loss: 0.3374 - accuracy: 0.8731
# Epoch 18/40
#  - 0s - loss: 0.3485 - accuracy: 0.8611
# Epoch 19/40
#  - 0s - loss: 0.3260 - accuracy: 0.8782
# Epoch 20/40
#  - 0s - loss: 0.3280 - accuracy: 0.8816
# Epoch 21/40
#  - 0s - loss: 0.3146 - accuracy: 0.8765
# Epoch 22/40
#  - 0s - loss: 0.3007 - accuracy: 0.8816
# Epoch 23/40
#  - 0s - loss: 0.2874 - accuracy: 0.8799
# Epoch 24/40
#  - 0s - loss: 0.3564 - accuracy: 0.8593
# Epoch 25/40
#  - 0s - loss: 0.2786 - accuracy: 0.8988
# Epoch 26/40
#  - 0s - loss: 0.3139 - accuracy: 0.8748
# Epoch 27/40
#  - 0s - loss: 0.3102 - accuracy: 0.8851
# Epoch 28/40
#  - 0s - loss: 0.2908 - accuracy: 0.8868
# Epoch 29/40
#  - 0s - loss: 0.2988 - accuracy: 0.8851
# Epoch 30/40
#  - 0s - loss: 0.3073 - accuracy: 0.8851
# Epoch 31/40
#  - 0s - loss: 0.3057 - accuracy: 0.8851
# Epoch 32/40
#  - 0s - loss: 0.2810 - accuracy: 0.9057
# Epoch 33/40
#  - 0s - loss: 0.2935 - accuracy: 0.8954
# Epoch 34/40
#  - 0s - loss: 0.2786 - accuracy: 0.8902
# Epoch 35/40
#  - 0s - loss: 0.2848 - accuracy: 0.8971
# Epoch 36/40
#  - 0s - loss: 0.3371 - accuracy: 0.8714
# Epoch 37/40
#  - 0s - loss: 0.2834 - accuracy: 0.8988
# Epoch 38/40
#  - 0s - loss: 0.3030 - accuracy: 0.8765
# Epoch 39/40
#  - 0s - loss: 0.2688 - accuracy: 0.8919
# Epoch 40/40
#  - 0s - loss: 0.3298 - accuracy: 0.8714
# 292/292 [==============================] - 0s 526us/step
# activation: relu, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.7469 - accuracy: 0.5993
# Epoch 2/40
#  - 0s - loss: 0.6068 - accuracy: 0.7517
# Epoch 3/40
#  - 0s - loss: 0.5957 - accuracy: 0.7329
# Epoch 4/40
#  - 0s - loss: 0.6171 - accuracy: 0.7414
# Epoch 5/40
#  - 0s - loss: 0.5707 - accuracy: 0.7723
# Epoch 6/40
#  - 0s - loss: 0.5064 - accuracy: 0.7928
# Epoch 7/40
#  - 0s - loss: 0.5023 - accuracy: 0.7928
# Epoch 8/40
#  - 0s - loss: 0.5079 - accuracy: 0.7945
# Epoch 9/40
#  - 0s - loss: 0.4831 - accuracy: 0.8099
# Epoch 10/40
#  - 0s - loss: 0.4566 - accuracy: 0.8236
# Epoch 11/40
#  - 0s - loss: 0.4203 - accuracy: 0.8219
# Epoch 12/40
#  - 0s - loss: 0.4484 - accuracy: 0.8288
# Epoch 13/40
#  - 0s - loss: 0.3890 - accuracy: 0.8425
# Epoch 14/40
#  - 0s - loss: 0.3850 - accuracy: 0.8408
# Epoch 15/40
#  - 0s - loss: 0.4212 - accuracy: 0.8562
# Epoch 16/40
#  - 0s - loss: 0.3597 - accuracy: 0.8562
# Epoch 17/40
#  - 0s - loss: 0.3977 - accuracy: 0.8390
# Epoch 18/40
#  - 0s - loss: 0.3705 - accuracy: 0.8596
# Epoch 19/40
#  - 0s - loss: 0.3756 - accuracy: 0.8545
# Epoch 20/40
#  - 0s - loss: 0.3317 - accuracy: 0.8767
# Epoch 21/40
#  - 0s - loss: 0.3502 - accuracy: 0.8613
# Epoch 22/40
#  - 0s - loss: 0.3618 - accuracy: 0.8630
# Epoch 23/40
#  - 0s - loss: 0.3192 - accuracy: 0.8836
# Epoch 24/40
#  - 0s - loss: 0.3422 - accuracy: 0.8682
# Epoch 25/40
#  - 0s - loss: 0.3143 - accuracy: 0.8699
# Epoch 26/40
#  - 0s - loss: 0.3299 - accuracy: 0.8699
# Epoch 27/40
#  - 0s - loss: 0.3256 - accuracy: 0.8784
# Epoch 28/40
#  - 0s - loss: 0.3317 - accuracy: 0.8664
# Epoch 29/40
#  - 0s - loss: 0.3103 - accuracy: 0.8784
# Epoch 30/40
#  - 0s - loss: 0.3638 - accuracy: 0.8750
# Epoch 31/40
#  - 0s - loss: 0.3388 - accuracy: 0.8664
# Epoch 32/40
#  - 0s - loss: 0.3227 - accuracy: 0.8870
# Epoch 33/40
#  - 0s - loss: 0.3076 - accuracy: 0.8801
# Epoch 34/40
#  - 0s - loss: 0.3252 - accuracy: 0.8767
# Epoch 35/40
#  - 0s - loss: 0.3117 - accuracy: 0.8904
# Epoch 36/40
#  - 0s - loss: 0.2885 - accuracy: 0.8767
# Epoch 37/40
#  - 0s - loss: 0.2958 - accuracy: 0.8836
# Epoch 38/40
#  - 0s - loss: 0.2921 - accuracy: 0.8750
# Epoch 39/40
#  - 0s - loss: 0.3431 - accuracy: 0.8784
# Epoch 40/40
#  - 0s - loss: 0.2734 - accuracy: 0.8938
# 291/291 [==============================] - 0s 455us/step
# activation: relu, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.7409 - accuracy: 0.6741
# Epoch 2/40
#  - 0s - loss: 0.6527 - accuracy: 0.7273
# Epoch 3/40
#  - 0s - loss: 0.5949 - accuracy: 0.7547
# Epoch 4/40
#  - 0s - loss: 0.5029 - accuracy: 0.8027
# Epoch 5/40
#  - 0s - loss: 0.4746 - accuracy: 0.8130
# Epoch 6/40
#  - 0s - loss: 0.4190 - accuracy: 0.8370
# Epoch 7/40
#  - 0s - loss: 0.4463 - accuracy: 0.8353
# Epoch 8/40
#  - 0s - loss: 0.4615 - accuracy: 0.8079
# Epoch 9/40
#  - 0s - loss: 0.4035 - accuracy: 0.8508
# Epoch 10/40
#  - 0s - loss: 0.3623 - accuracy: 0.8559
# Epoch 11/40
#  - 0s - loss: 0.3451 - accuracy: 0.8611
# Epoch 12/40
#  - 0s - loss: 0.3541 - accuracy: 0.8731
# Epoch 13/40
#  - 0s - loss: 0.3725 - accuracy: 0.8628
# Epoch 14/40
#  - 0s - loss: 0.3292 - accuracy: 0.8662
# Epoch 15/40
#  - 0s - loss: 0.3256 - accuracy: 0.8748
# Epoch 16/40
#  - 0s - loss: 0.3197 - accuracy: 0.8679
# Epoch 17/40
#  - 0s - loss: 0.3004 - accuracy: 0.8937
# Epoch 18/40
#  - 0s - loss: 0.2939 - accuracy: 0.8937
# Epoch 19/40
#  - 0s - loss: 0.3098 - accuracy: 0.8902
# Epoch 20/40
#  - 0s - loss: 0.2686 - accuracy: 0.9022
# Epoch 21/40
#  - 0s - loss: 0.2839 - accuracy: 0.9005
# Epoch 22/40
#  - 0s - loss: 0.2782 - accuracy: 0.8988
# Epoch 23/40
#  - 0s - loss: 0.3258 - accuracy: 0.8799
# Epoch 24/40
#  - 0s - loss: 0.2967 - accuracy: 0.8816
# Epoch 25/40
#  - 0s - loss: 0.2755 - accuracy: 0.8954
# Epoch 26/40
#  - 0s - loss: 0.2777 - accuracy: 0.9057
# Epoch 27/40
#  - 0s - loss: 0.2821 - accuracy: 0.9074
# Epoch 28/40
#  - 0s - loss: 0.2822 - accuracy: 0.8834
# Epoch 29/40
#  - 0s - loss: 0.2782 - accuracy: 0.8868
# Epoch 30/40
#  - 0s - loss: 0.2914 - accuracy: 0.8885
# Epoch 31/40
#  - 0s - loss: 0.2944 - accuracy: 0.8868
# Epoch 32/40
#  - 0s - loss: 0.2732 - accuracy: 0.8919
# Epoch 33/40
#  - 0s - loss: 0.2612 - accuracy: 0.8919
# Epoch 34/40
#  - 0s - loss: 0.2540 - accuracy: 0.9091
# Epoch 35/40
#  - 0s - loss: 0.2609 - accuracy: 0.9125
# Epoch 36/40
#  - 0s - loss: 0.2919 - accuracy: 0.8919
# Epoch 37/40
#  - 0s - loss: 0.2929 - accuracy: 0.8851
# Epoch 38/40
#  - 0s - loss: 0.2829 - accuracy: 0.9108
# Epoch 39/40
#  - 0s - loss: 0.2946 - accuracy: 0.8885
# Epoch 40/40
#  - 0s - loss: 0.2420 - accuracy: 0.9125
# 292/292 [==============================] - 0s 417us/step
# activation: relu, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.7798 - accuracy: 0.6501
# Epoch 2/40
#  - 0s - loss: 0.6435 - accuracy: 0.7513
# Epoch 3/40
#  - 0s - loss: 0.6143 - accuracy: 0.7667
# Epoch 4/40
#  - 0s - loss: 0.5333 - accuracy: 0.7907
# Epoch 5/40
#  - 0s - loss: 0.5400 - accuracy: 0.7684
# Epoch 6/40
#  - 0s - loss: 0.4846 - accuracy: 0.8027
# Epoch 7/40
#  - 0s - loss: 0.5094 - accuracy: 0.8148
# Epoch 8/40
#  - 0s - loss: 0.4562 - accuracy: 0.8250
# Epoch 9/40
#  - 0s - loss: 0.4218 - accuracy: 0.8370
# Epoch 10/40
#  - 0s - loss: 0.4523 - accuracy: 0.8096
# Epoch 11/40
#  - 0s - loss: 0.3808 - accuracy: 0.8388
# Epoch 12/40
#  - 0s - loss: 0.4076 - accuracy: 0.8388
# Epoch 13/40
#  - 0s - loss: 0.3482 - accuracy: 0.8679
# Epoch 14/40
#  - 0s - loss: 0.3585 - accuracy: 0.8576
# Epoch 15/40
#  - 0s - loss: 0.3803 - accuracy: 0.8542
# Epoch 16/40
#  - 0s - loss: 0.3306 - accuracy: 0.8679
# Epoch 17/40
#  - 0s - loss: 0.3685 - accuracy: 0.8714
# Epoch 18/40
#  - 0s - loss: 0.3074 - accuracy: 0.8765
# Epoch 19/40
#  - 0s - loss: 0.3378 - accuracy: 0.8696
# Epoch 20/40
#  - 0s - loss: 0.2968 - accuracy: 0.8782
# Epoch 21/40
#  - 0s - loss: 0.3270 - accuracy: 0.8868
# Epoch 22/40
#  - 0s - loss: 0.3213 - accuracy: 0.8628
# Epoch 23/40
#  - 0s - loss: 0.3129 - accuracy: 0.8714
# Epoch 24/40
#  - 0s - loss: 0.3107 - accuracy: 0.8919
# Epoch 25/40
#  - 0s - loss: 0.2981 - accuracy: 0.8937
# Epoch 26/40
#  - 0s - loss: 0.3168 - accuracy: 0.8971
# Epoch 27/40
#  - 0s - loss: 0.3091 - accuracy: 0.8851
# Epoch 28/40
#  - 0s - loss: 0.2723 - accuracy: 0.8919
# Epoch 29/40
#  - 0s - loss: 0.3152 - accuracy: 0.8868
# Epoch 30/40
#  - 0s - loss: 0.2889 - accuracy: 0.8902
# Epoch 31/40
#  - 0s - loss: 0.2766 - accuracy: 0.8902
# Epoch 32/40
#  - 0s - loss: 0.3061 - accuracy: 0.8816
# Epoch 33/40
#  - 0s - loss: 0.2743 - accuracy: 0.9057
# Epoch 34/40
#  - 0s - loss: 0.2817 - accuracy: 0.8868
# Epoch 35/40
#  - 0s - loss: 0.2862 - accuracy: 0.8919
# Epoch 36/40
#  - 0s - loss: 0.2915 - accuracy: 0.8851
# Epoch 37/40
#  - 0s - loss: 0.3109 - accuracy: 0.8919
# Epoch 38/40
#  - 0s - loss: 0.2844 - accuracy: 0.9039
# Epoch 39/40
#  - 0s - loss: 0.3024 - accuracy: 0.8799
# Epoch 40/40
#  - 0s - loss: 0.2927 - accuracy: 0.8954
# 292/292 [==============================] - 0s 482us/step
# activation: relu, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.7477 - accuracy: 0.6558
# Epoch 2/40
#  - 0s - loss: 0.7063 - accuracy: 0.7038
# Epoch 3/40
#  - 0s - loss: 0.6543 - accuracy: 0.7397
# Epoch 4/40
#  - 0s - loss: 0.6308 - accuracy: 0.7500
# Epoch 5/40
#  - 0s - loss: 0.5514 - accuracy: 0.7877
# Epoch 6/40
#  - 0s - loss: 0.4958 - accuracy: 0.8151
# Epoch 7/40
#  - 0s - loss: 0.5323 - accuracy: 0.7997
# Epoch 8/40
#  - 0s - loss: 0.4624 - accuracy: 0.8134
# Epoch 9/40
#  - 0s - loss: 0.4360 - accuracy: 0.8219
# Epoch 10/40
#  - 0s - loss: 0.4046 - accuracy: 0.8459
# Epoch 11/40
#  - 0s - loss: 0.4211 - accuracy: 0.8236
# Epoch 12/40
#  - 0s - loss: 0.4618 - accuracy: 0.8168
# Epoch 13/40
#  - 0s - loss: 0.4085 - accuracy: 0.8339
# Epoch 14/40
#  - 0s - loss: 0.4052 - accuracy: 0.8408
# Epoch 15/40
#  - 0s - loss: 0.3560 - accuracy: 0.8716
# Epoch 16/40
#  - 0s - loss: 0.3757 - accuracy: 0.8510
# Epoch 17/40
#  - 0s - loss: 0.3733 - accuracy: 0.8510
# Epoch 18/40
#  - 0s - loss: 0.3128 - accuracy: 0.8836
# Epoch 19/40
#  - 0s - loss: 0.3628 - accuracy: 0.8682
# Epoch 20/40
#  - 0s - loss: 0.3664 - accuracy: 0.8545
# Epoch 21/40
#  - 0s - loss: 0.3222 - accuracy: 0.8733
# Epoch 22/40
#  - 0s - loss: 0.3118 - accuracy: 0.8801
# Epoch 23/40
#  - 0s - loss: 0.3413 - accuracy: 0.8682
# Epoch 24/40
#  - 0s - loss: 0.3121 - accuracy: 0.8870
# Epoch 25/40
#  - 0s - loss: 0.3135 - accuracy: 0.8784
# Epoch 26/40
#  - 0s - loss: 0.3155 - accuracy: 0.8733
# Epoch 27/40
#  - 0s - loss: 0.3523 - accuracy: 0.8664
# Epoch 28/40
#  - 0s - loss: 0.3381 - accuracy: 0.8733
# Epoch 29/40
#  - 0s - loss: 0.2833 - accuracy: 0.8904
# Epoch 30/40
#  - 0s - loss: 0.3196 - accuracy: 0.8887
# Epoch 31/40
#  - 0s - loss: 0.3263 - accuracy: 0.8716
# Epoch 32/40
#  - 0s - loss: 0.3279 - accuracy: 0.8784
# Epoch 33/40
#  - 0s - loss: 0.3400 - accuracy: 0.8699
# Epoch 34/40
#  - 0s - loss: 0.3430 - accuracy: 0.8510
# Epoch 35/40
#  - 0s - loss: 0.2834 - accuracy: 0.8921
# Epoch 36/40
#  - 0s - loss: 0.3193 - accuracy: 0.8767
# Epoch 37/40
#  - 0s - loss: 0.3003 - accuracy: 0.8716
# Epoch 38/40
#  - 0s - loss: 0.2967 - accuracy: 0.8870
# Epoch 39/40
#  - 0s - loss: 0.3049 - accuracy: 0.8767
# Epoch 40/40
#  - 0s - loss: 0.3181 - accuracy: 0.8750
# 291/291 [==============================] - 0s 496us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.8864 - accuracy: 0.6792
# Epoch 2/40
#  - 0s - loss: 0.6428 - accuracy: 0.7564
# Epoch 3/40
#  - 0s - loss: 0.4842 - accuracy: 0.7993
# Epoch 4/40
#  - 0s - loss: 0.4751 - accuracy: 0.8148
# Epoch 5/40
#  - 0s - loss: 0.4616 - accuracy: 0.8062
# Epoch 6/40
#  - 0s - loss: 0.4455 - accuracy: 0.8302
# Epoch 7/40
#  - 0s - loss: 0.3744 - accuracy: 0.8525
# Epoch 8/40
#  - 0s - loss: 0.3904 - accuracy: 0.8645
# Epoch 9/40
#  - 0s - loss: 0.3709 - accuracy: 0.8576
# Epoch 10/40
#  - 0s - loss: 0.4259 - accuracy: 0.8370
# Epoch 11/40
#  - 0s - loss: 0.3982 - accuracy: 0.8456
# Epoch 12/40
#  - 0s - loss: 0.3596 - accuracy: 0.8525
# Epoch 13/40
#  - 0s - loss: 0.3588 - accuracy: 0.8679
# Epoch 14/40
#  - 0s - loss: 0.3744 - accuracy: 0.8491
# Epoch 15/40
#  - 0s - loss: 0.3701 - accuracy: 0.8491
# Epoch 16/40
#  - 0s - loss: 0.3344 - accuracy: 0.8748
# Epoch 17/40
#  - 0s - loss: 0.3397 - accuracy: 0.8714
# Epoch 18/40
#  - 0s - loss: 0.3351 - accuracy: 0.8679
# Epoch 19/40
#  - 0s - loss: 0.3196 - accuracy: 0.8834
# Epoch 20/40
#  - 0s - loss: 0.3247 - accuracy: 0.8696
# Epoch 21/40
#  - 0s - loss: 0.3168 - accuracy: 0.8782
# Epoch 22/40
#  - 0s - loss: 0.2963 - accuracy: 0.8816
# Epoch 23/40
#  - 0s - loss: 0.3007 - accuracy: 0.8937
# Epoch 24/40
#  - 0s - loss: 0.3282 - accuracy: 0.8714
# Epoch 25/40
#  - 0s - loss: 0.3278 - accuracy: 0.8782
# Epoch 26/40
#  - 0s - loss: 0.3135 - accuracy: 0.8919
# Epoch 27/40
#  - 0s - loss: 0.2833 - accuracy: 0.9057
# Epoch 28/40
#  - 0s - loss: 0.2911 - accuracy: 0.9005
# Epoch 29/40
#  - 0s - loss: 0.3086 - accuracy: 0.8799
# Epoch 30/40
#  - 0s - loss: 0.2845 - accuracy: 0.9039
# Epoch 31/40
#  - 0s - loss: 0.2831 - accuracy: 0.8954
# Epoch 32/40
#  - 0s - loss: 0.2855 - accuracy: 0.8851
# Epoch 33/40
#  - 0s - loss: 0.2729 - accuracy: 0.8954
# Epoch 34/40
#  - 0s - loss: 0.2793 - accuracy: 0.9142
# Epoch 35/40
#  - 0s - loss: 0.2715 - accuracy: 0.8971
# Epoch 36/40
#  - 0s - loss: 0.2890 - accuracy: 0.8937
# Epoch 37/40
#  - 0s - loss: 0.3238 - accuracy: 0.8902
# Epoch 38/40
#  - 0s - loss: 0.2700 - accuracy: 0.8971
# Epoch 39/40
#  - 0s - loss: 0.2628 - accuracy: 0.9125
# Epoch 40/40
#  - 0s - loss: 0.2678 - accuracy: 0.9005
# 292/292 [==============================] - 0s 435us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.7927 - accuracy: 0.6930
# Epoch 2/40
#  - 0s - loss: 0.5610 - accuracy: 0.7496
# Epoch 3/40
#  - 0s - loss: 0.5602 - accuracy: 0.7599
# Epoch 4/40
#  - 0s - loss: 0.4644 - accuracy: 0.8165
# Epoch 5/40
#  - 0s - loss: 0.4644 - accuracy: 0.8130
# Epoch 6/40
#  - 0s - loss: 0.4280 - accuracy: 0.8268
# Epoch 7/40
#  - 0s - loss: 0.4690 - accuracy: 0.8079
# Epoch 8/40
#  - 0s - loss: 0.4364 - accuracy: 0.8302
# Epoch 9/40
#  - 0s - loss: 0.4104 - accuracy: 0.8353
# Epoch 10/40
#  - 0s - loss: 0.4025 - accuracy: 0.8405
# Epoch 11/40
#  - 0s - loss: 0.3914 - accuracy: 0.8542
# Epoch 12/40
#  - 0s - loss: 0.3729 - accuracy: 0.8508
# Epoch 13/40
#  - 0s - loss: 0.3620 - accuracy: 0.8576
# Epoch 14/40
#  - 0s - loss: 0.3735 - accuracy: 0.8525
# Epoch 15/40
#  - 0s - loss: 0.3354 - accuracy: 0.8782
# Epoch 16/40
#  - 0s - loss: 0.3301 - accuracy: 0.8816
# Epoch 17/40
#  - 0s - loss: 0.3289 - accuracy: 0.8799
# Epoch 18/40
#  - 0s - loss: 0.3523 - accuracy: 0.8662
# Epoch 19/40
#  - 0s - loss: 0.3546 - accuracy: 0.8662
# Epoch 20/40
#  - 0s - loss: 0.3537 - accuracy: 0.8696
# Epoch 21/40
#  - 0s - loss: 0.3339 - accuracy: 0.8816
# Epoch 22/40
#  - 0s - loss: 0.3761 - accuracy: 0.8611
# Epoch 23/40
#  - 0s - loss: 0.3635 - accuracy: 0.8542
# Epoch 24/40
#  - 0s - loss: 0.3014 - accuracy: 0.8765
# Epoch 25/40
#  - 0s - loss: 0.3192 - accuracy: 0.8816
# Epoch 26/40
#  - 0s - loss: 0.3359 - accuracy: 0.8714
# Epoch 27/40
#  - 0s - loss: 0.3217 - accuracy: 0.8696
# Epoch 28/40
#  - 0s - loss: 0.3130 - accuracy: 0.8748
# Epoch 29/40
#  - 0s - loss: 0.3206 - accuracy: 0.8748
# Epoch 30/40
#  - 0s - loss: 0.3350 - accuracy: 0.8679
# Epoch 31/40
#  - 0s - loss: 0.2890 - accuracy: 0.8954
# Epoch 32/40
#  - 0s - loss: 0.3068 - accuracy: 0.8799
# Epoch 33/40
#  - 0s - loss: 0.3297 - accuracy: 0.8816
# Epoch 34/40
#  - 0s - loss: 0.3193 - accuracy: 0.8576
# Epoch 35/40
#  - 0s - loss: 0.3176 - accuracy: 0.8851
# Epoch 36/40
#  - 0s - loss: 0.3161 - accuracy: 0.8748
# Epoch 37/40
#  - 0s - loss: 0.3172 - accuracy: 0.8885
# Epoch 38/40
#  - 0s - loss: 0.2894 - accuracy: 0.8868
# Epoch 39/40
#  - 0s - loss: 0.2836 - accuracy: 0.8885
# Epoch 40/40
#  - 0s - loss: 0.2936 - accuracy: 0.8919
# 292/292 [==============================] - 0s 428us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.8446 - accuracy: 0.6661
# Epoch 2/40
#  - 0s - loss: 0.6304 - accuracy: 0.7397
# Epoch 3/40
#  - 0s - loss: 0.5340 - accuracy: 0.7654
# Epoch 4/40
#  - 0s - loss: 0.5738 - accuracy: 0.7791
# Epoch 5/40
#  - 0s - loss: 0.4556 - accuracy: 0.8116
# Epoch 6/40
#  - 0s - loss: 0.4684 - accuracy: 0.8031
# Epoch 7/40
#  - 0s - loss: 0.4541 - accuracy: 0.8339
# Epoch 8/40
#  - 0s - loss: 0.4546 - accuracy: 0.8151
# Epoch 9/40
#  - 0s - loss: 0.4265 - accuracy: 0.8202
# Epoch 10/40
#  - 0s - loss: 0.3922 - accuracy: 0.8459
# Epoch 11/40
#  - 0s - loss: 0.4044 - accuracy: 0.8339
# Epoch 12/40
#  - 0s - loss: 0.4184 - accuracy: 0.8459
# Epoch 13/40
#  - 0s - loss: 0.4001 - accuracy: 0.8425
# Epoch 14/40
#  - 0s - loss: 0.3808 - accuracy: 0.8288
# Epoch 15/40
#  - 0s - loss: 0.4086 - accuracy: 0.8373
# Epoch 16/40
#  - 0s - loss: 0.3766 - accuracy: 0.8493
# Epoch 17/40
#  - 0s - loss: 0.3510 - accuracy: 0.8767
# Epoch 18/40
#  - 0s - loss: 0.3709 - accuracy: 0.8562
# Epoch 19/40
#  - 0s - loss: 0.3467 - accuracy: 0.8613
# Epoch 20/40
#  - 0s - loss: 0.3397 - accuracy: 0.8630
# Epoch 21/40
#  - 0s - loss: 0.3736 - accuracy: 0.8630
# Epoch 22/40
#  - 0s - loss: 0.3110 - accuracy: 0.8870
# Epoch 23/40
#  - 0s - loss: 0.3517 - accuracy: 0.8784
# Epoch 24/40
#  - 0s - loss: 0.3712 - accuracy: 0.8579
# Epoch 25/40
#  - 0s - loss: 0.3405 - accuracy: 0.8647
# Epoch 26/40
#  - 0s - loss: 0.3307 - accuracy: 0.8750
# Epoch 27/40
#  - 0s - loss: 0.3586 - accuracy: 0.8630
# Epoch 28/40
#  - 0s - loss: 0.3224 - accuracy: 0.8784
# Epoch 29/40
#  - 0s - loss: 0.3485 - accuracy: 0.8716
# Epoch 30/40
#  - 0s - loss: 0.3642 - accuracy: 0.8699
# Epoch 31/40
#  - 0s - loss: 0.3463 - accuracy: 0.8682
# Epoch 32/40
#  - 0s - loss: 0.3503 - accuracy: 0.8630
# Epoch 33/40
#  - 0s - loss: 0.3144 - accuracy: 0.8818
# Epoch 34/40
#  - 0s - loss: 0.3514 - accuracy: 0.8630
# Epoch 35/40
#  - 0s - loss: 0.3261 - accuracy: 0.8750
# Epoch 36/40
#  - 0s - loss: 0.3048 - accuracy: 0.8801
# Epoch 37/40
#  - 0s - loss: 0.3133 - accuracy: 0.8955
# Epoch 38/40
#  - 0s - loss: 0.3583 - accuracy: 0.8682
# Epoch 39/40
#  - 0s - loss: 0.3435 - accuracy: 0.8716
# Epoch 40/40
#  - 0s - loss: 0.3407 - accuracy: 0.8647
# 291/291 [==============================] - 0s 456us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.8375 - accuracy: 0.7153
# Epoch 2/40
#  - 0s - loss: 0.6171 - accuracy: 0.7496
# Epoch 3/40
#  - 0s - loss: 0.5543 - accuracy: 0.7873
# Epoch 4/40
#  - 0s - loss: 0.4574 - accuracy: 0.8010
# Epoch 5/40
#  - 0s - loss: 0.4684 - accuracy: 0.8062
# Epoch 6/40
#  - 0s - loss: 0.3965 - accuracy: 0.8473
# Epoch 7/40
#  - 0s - loss: 0.3989 - accuracy: 0.8439
# Epoch 8/40
#  - 0s - loss: 0.3628 - accuracy: 0.8645
# Epoch 9/40
#  - 0s - loss: 0.3900 - accuracy: 0.8628
# Epoch 10/40
#  - 0s - loss: 0.3530 - accuracy: 0.8765
# Epoch 11/40
#  - 0s - loss: 0.3447 - accuracy: 0.8816
# Epoch 12/40
#  - 0s - loss: 0.3278 - accuracy: 0.8679
# Epoch 13/40
#  - 0s - loss: 0.3147 - accuracy: 0.8731
# Epoch 14/40
#  - 0s - loss: 0.3128 - accuracy: 0.8765
# Epoch 15/40
#  - 0s - loss: 0.3018 - accuracy: 0.8885
# Epoch 16/40
#  - 0s - loss: 0.2970 - accuracy: 0.9005
# Epoch 17/40
#  - 0s - loss: 0.3419 - accuracy: 0.8748
# Epoch 18/40
#  - 0s - loss: 0.3151 - accuracy: 0.8971
# Epoch 19/40
#  - 0s - loss: 0.3438 - accuracy: 0.8799
# Epoch 20/40
#  - 0s - loss: 0.3064 - accuracy: 0.8868
# Epoch 21/40
#  - 0s - loss: 0.3098 - accuracy: 0.8799
# Epoch 22/40
#  - 0s - loss: 0.2977 - accuracy: 0.8885
# Epoch 23/40
#  - 0s - loss: 0.3820 - accuracy: 0.8731
# Epoch 24/40
#  - 0s - loss: 0.3026 - accuracy: 0.8816
# Epoch 25/40
#  - 0s - loss: 0.3042 - accuracy: 0.8868
# Epoch 26/40
#  - 0s - loss: 0.3116 - accuracy: 0.8782
# Epoch 27/40
#  - 0s - loss: 0.2756 - accuracy: 0.9108
# Epoch 28/40
#  - 0s - loss: 0.3363 - accuracy: 0.8834
# Epoch 29/40
#  - 0s - loss: 0.2946 - accuracy: 0.9005
# Epoch 30/40
#  - 0s - loss: 0.2526 - accuracy: 0.9177
# Epoch 31/40
#  - 0s - loss: 0.2471 - accuracy: 0.9108
# Epoch 32/40
#  - 0s - loss: 0.2589 - accuracy: 0.9057
# Epoch 33/40
#  - 0s - loss: 0.2871 - accuracy: 0.8988
# Epoch 34/40
#  - 0s - loss: 0.2561 - accuracy: 0.9091
# Epoch 35/40
#  - 0s - loss: 0.2568 - accuracy: 0.9022
# Epoch 36/40
#  - 0s - loss: 0.2393 - accuracy: 0.9108
# Epoch 37/40
#  - 0s - loss: 0.2713 - accuracy: 0.8954
# Epoch 38/40
#  - 0s - loss: 0.2929 - accuracy: 0.8919
# Epoch 39/40
#  - 0s - loss: 0.2579 - accuracy: 0.8937
# Epoch 40/40
#  - 0s - loss: 0.2509 - accuracy: 0.9125
# 292/292 [==============================] - 0s 489us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.8653 - accuracy: 0.6878
# Epoch 2/40
#  - 0s - loss: 0.5870 - accuracy: 0.7770
# Epoch 3/40
#  - 0s - loss: 0.5084 - accuracy: 0.7959
# Epoch 4/40
#  - 0s - loss: 0.5103 - accuracy: 0.7976
# Epoch 5/40
#  - 0s - loss: 0.4461 - accuracy: 0.8268
# Epoch 6/40
#  - 0s - loss: 0.4366 - accuracy: 0.8199
# Epoch 7/40
#  - 0s - loss: 0.3996 - accuracy: 0.8388
# Epoch 8/40
#  - 0s - loss: 0.4114 - accuracy: 0.8302
# Epoch 9/40
#  - 0s - loss: 0.4096 - accuracy: 0.8422
# Epoch 10/40
#  - 0s - loss: 0.3568 - accuracy: 0.8508
# Epoch 11/40
#  - 0s - loss: 0.3196 - accuracy: 0.8662
# Epoch 12/40
#  - 0s - loss: 0.3765 - accuracy: 0.8628
# Epoch 13/40
#  - 0s - loss: 0.3515 - accuracy: 0.8748
# Epoch 14/40
#  - 0s - loss: 0.3184 - accuracy: 0.8765
# Epoch 15/40
#  - 0s - loss: 0.3092 - accuracy: 0.8799
# Epoch 16/40
#  - 0s - loss: 0.3554 - accuracy: 0.8679
# Epoch 17/40
#  - 0s - loss: 0.2861 - accuracy: 0.8765
# Epoch 18/40
#  - 0s - loss: 0.3326 - accuracy: 0.8731
# Epoch 19/40
#  - 0s - loss: 0.3214 - accuracy: 0.8868
# Epoch 20/40
#  - 0s - loss: 0.3224 - accuracy: 0.8851
# Epoch 21/40
#  - 0s - loss: 0.3173 - accuracy: 0.8868
# Epoch 22/40
#  - 0s - loss: 0.3625 - accuracy: 0.8714
# Epoch 23/40
#  - 0s - loss: 0.3178 - accuracy: 0.8782
# Epoch 24/40
#  - 0s - loss: 0.2959 - accuracy: 0.8885
# Epoch 25/40
#  - 0s - loss: 0.2873 - accuracy: 0.8988
# Epoch 26/40
#  - 0s - loss: 0.2970 - accuracy: 0.8868
# Epoch 27/40
#  - 0s - loss: 0.2870 - accuracy: 0.8988
# Epoch 28/40
#  - 0s - loss: 0.3148 - accuracy: 0.8816
# Epoch 29/40
#  - 0s - loss: 0.2884 - accuracy: 0.8919
# Epoch 30/40
#  - 0s - loss: 0.2684 - accuracy: 0.8834
# Epoch 31/40
#  - 0s - loss: 0.2887 - accuracy: 0.8988
# Epoch 32/40
#  - 0s - loss: 0.3301 - accuracy: 0.8679
# Epoch 33/40
#  - 0s - loss: 0.2758 - accuracy: 0.8937
# Epoch 34/40
#  - 0s - loss: 0.2892 - accuracy: 0.8851
# Epoch 35/40
#  - 0s - loss: 0.2587 - accuracy: 0.9022
# Epoch 36/40
#  - 0s - loss: 0.2920 - accuracy: 0.8851
# Epoch 37/40
#  - 0s - loss: 0.3117 - accuracy: 0.8868
# Epoch 38/40
#  - 0s - loss: 0.2746 - accuracy: 0.8971
# Epoch 39/40
#  - 0s - loss: 0.3031 - accuracy: 0.8919
# Epoch 40/40
#  - 0s - loss: 0.2820 - accuracy: 0.8851
# 292/292 [==============================] - 0s 454us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.8793 - accuracy: 0.6952
# Epoch 2/40
#  - 0s - loss: 0.6915 - accuracy: 0.7226
# Epoch 3/40
#  - 0s - loss: 0.5226 - accuracy: 0.7688
# Epoch 4/40
#  - 0s - loss: 0.5019 - accuracy: 0.7791
# Epoch 5/40
#  - 0s - loss: 0.5153 - accuracy: 0.7842
# Epoch 6/40
#  - 0s - loss: 0.4393 - accuracy: 0.8202
# Epoch 7/40
#  - 0s - loss: 0.4895 - accuracy: 0.8185
# Epoch 8/40
#  - 0s - loss: 0.4269 - accuracy: 0.8322
# Epoch 9/40
#  - 0s - loss: 0.3824 - accuracy: 0.8356
# Epoch 10/40
#  - 0s - loss: 0.4023 - accuracy: 0.8408
# Epoch 11/40
#  - 0s - loss: 0.3944 - accuracy: 0.8442
# Epoch 12/40
#  - 0s - loss: 0.3912 - accuracy: 0.8527
# Epoch 13/40
#  - 0s - loss: 0.4614 - accuracy: 0.8322
# Epoch 14/40
#  - 0s - loss: 0.3523 - accuracy: 0.8613
# Epoch 15/40
#  - 0s - loss: 0.3550 - accuracy: 0.8664
# Epoch 16/40
#  - 0s - loss: 0.3494 - accuracy: 0.8750
# Epoch 17/40
#  - 0s - loss: 0.3612 - accuracy: 0.8647
# Epoch 18/40
#  - 0s - loss: 0.3504 - accuracy: 0.8562
# Epoch 19/40
#  - 0s - loss: 0.3143 - accuracy: 0.8630
# Epoch 20/40
#  - 0s - loss: 0.3159 - accuracy: 0.8699
# Epoch 21/40
#  - 0s - loss: 0.3514 - accuracy: 0.8630
# Epoch 22/40
#  - 0s - loss: 0.3652 - accuracy: 0.8647
# Epoch 23/40
#  - 0s - loss: 0.3347 - accuracy: 0.8630
# Epoch 24/40
#  - 0s - loss: 0.3193 - accuracy: 0.8767
# Epoch 25/40
#  - 0s - loss: 0.3113 - accuracy: 0.8801
# Epoch 26/40
#  - 0s - loss: 0.2915 - accuracy: 0.8870
# Epoch 27/40
#  - 0s - loss: 0.3112 - accuracy: 0.8682
# Epoch 28/40
#  - 0s - loss: 0.3514 - accuracy: 0.8562
# Epoch 29/40
#  - 0s - loss: 0.3039 - accuracy: 0.8853
# Epoch 30/40
#  - 0s - loss: 0.3184 - accuracy: 0.8818
# Epoch 31/40
#  - 0s - loss: 0.3277 - accuracy: 0.8733
# Epoch 32/40
#  - 0s - loss: 0.3305 - accuracy: 0.8664
# Epoch 33/40
#  - 0s - loss: 0.3219 - accuracy: 0.8750
# Epoch 34/40
#  - 0s - loss: 0.3273 - accuracy: 0.8887
# Epoch 35/40
#  - 0s - loss: 0.3123 - accuracy: 0.8853
# Epoch 36/40
#  - 0s - loss: 0.2890 - accuracy: 0.8887
# Epoch 37/40
#  - 0s - loss: 0.3278 - accuracy: 0.8784
# Epoch 38/40
#  - 0s - loss: 0.3098 - accuracy: 0.8767
# Epoch 39/40
#  - 0s - loss: 0.2863 - accuracy: 0.8870
# Epoch 40/40
#  - 0s - loss: 0.3014 - accuracy: 0.8870
# 291/291 [==============================] - 0s 488us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.5935 - accuracy: 0.7033
# Epoch 2/40
#  - 0s - loss: 0.5504 - accuracy: 0.7393
# Epoch 3/40
#  - 0s - loss: 0.5124 - accuracy: 0.7856
# Epoch 4/40
#  - 0s - loss: 0.4009 - accuracy: 0.8302
# Epoch 5/40
#  - 0s - loss: 0.3713 - accuracy: 0.8439
# Epoch 6/40
#  - 0s - loss: 0.3751 - accuracy: 0.8576
# Epoch 7/40
#  - 0s - loss: 0.3516 - accuracy: 0.8851
# Epoch 8/40
#  - 0s - loss: 0.3293 - accuracy: 0.8799
# Epoch 9/40
#  - 0s - loss: 0.3174 - accuracy: 0.8816
# Epoch 10/40
#  - 0s - loss: 0.3583 - accuracy: 0.8748
# Epoch 11/40
#  - 0s - loss: 0.3444 - accuracy: 0.8696
# Epoch 12/40
#  - 0s - loss: 0.3415 - accuracy: 0.8799
# Epoch 13/40
#  - 0s - loss: 0.3425 - accuracy: 0.8765
# Epoch 14/40
#  - 0s - loss: 0.3176 - accuracy: 0.8885
# Epoch 15/40
#  - 0s - loss: 0.3147 - accuracy: 0.8851
# Epoch 16/40
#  - 0s - loss: 0.3316 - accuracy: 0.8851
# Epoch 17/40
#  - 0s - loss: 0.3224 - accuracy: 0.8851
# Epoch 18/40
#  - 0s - loss: 0.3163 - accuracy: 0.8799
# Epoch 19/40
#  - 0s - loss: 0.3331 - accuracy: 0.8782
# Epoch 20/40
#  - 0s - loss: 0.3432 - accuracy: 0.8714
# Epoch 21/40
#  - 0s - loss: 0.3111 - accuracy: 0.8902
# Epoch 22/40
#  - 0s - loss: 0.3151 - accuracy: 0.8731
# Epoch 23/40
#  - 0s - loss: 0.3214 - accuracy: 0.8851
# Epoch 24/40
#  - 0s - loss: 0.3086 - accuracy: 0.8834
# Epoch 25/40
#  - 0s - loss: 0.2900 - accuracy: 0.8902
# Epoch 26/40
#  - 0s - loss: 0.2951 - accuracy: 0.8782
# Epoch 27/40
#  - 0s - loss: 0.2958 - accuracy: 0.8971
# Epoch 28/40
#  - 0s - loss: 0.3043 - accuracy: 0.8868
# Epoch 29/40
#  - 0s - loss: 0.3047 - accuracy: 0.8971
# Epoch 30/40
#  - 0s - loss: 0.3111 - accuracy: 0.8834
# Epoch 31/40
#  - 0s - loss: 0.3304 - accuracy: 0.8748
# Epoch 32/40
#  - 0s - loss: 0.2932 - accuracy: 0.9057
# Epoch 33/40
#  - 0s - loss: 0.2677 - accuracy: 0.8937
# Epoch 34/40
#  - 0s - loss: 0.3027 - accuracy: 0.8937
# Epoch 35/40
#  - 0s - loss: 0.3142 - accuracy: 0.8851
# Epoch 36/40
#  - 0s - loss: 0.2924 - accuracy: 0.8954
# Epoch 37/40
#  - 0s - loss: 0.2982 - accuracy: 0.8782
# Epoch 38/40
#  - 0s - loss: 0.3272 - accuracy: 0.8851
# Epoch 39/40
#  - 0s - loss: 0.3043 - accuracy: 0.8954
# Epoch 40/40
#  - 0s - loss: 0.2959 - accuracy: 0.8919
# 292/292 [==============================] - 0s 431us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.6671 - accuracy: 0.6569
# Epoch 2/40
#  - 0s - loss: 0.5267 - accuracy: 0.7547
# Epoch 3/40
#  - 0s - loss: 0.4774 - accuracy: 0.7993
# Epoch 4/40
#  - 0s - loss: 0.4450 - accuracy: 0.8182
# Epoch 5/40
#  - 0s - loss: 0.4335 - accuracy: 0.8353
# Epoch 6/40
#  - 0s - loss: 0.3827 - accuracy: 0.8456
# Epoch 7/40
#  - 0s - loss: 0.4066 - accuracy: 0.8353
# Epoch 8/40
#  - 0s - loss: 0.3758 - accuracy: 0.8748
# Epoch 9/40
#  - 0s - loss: 0.3471 - accuracy: 0.8748
# Epoch 10/40
#  - 0s - loss: 0.3816 - accuracy: 0.8422
# Epoch 11/40
#  - 0s - loss: 0.3684 - accuracy: 0.8679
# Epoch 12/40
#  - 0s - loss: 0.3382 - accuracy: 0.8765
# Epoch 13/40
#  - 0s - loss: 0.3557 - accuracy: 0.8679
# Epoch 14/40
#  - 0s - loss: 0.3173 - accuracy: 0.8885
# Epoch 15/40
#  - 0s - loss: 0.3539 - accuracy: 0.8662
# Epoch 16/40
#  - 0s - loss: 0.3432 - accuracy: 0.8696
# Epoch 17/40
#  - 0s - loss: 0.3258 - accuracy: 0.8834
# Epoch 18/40
#  - 0s - loss: 0.3628 - accuracy: 0.8748
# Epoch 19/40
#  - 0s - loss: 0.3173 - accuracy: 0.8851
# Epoch 20/40
#  - 0s - loss: 0.3142 - accuracy: 0.8799
# Epoch 21/40
#  - 0s - loss: 0.3351 - accuracy: 0.8731
# Epoch 22/40
#  - 0s - loss: 0.3062 - accuracy: 0.8851
# Epoch 23/40
#  - 0s - loss: 0.3408 - accuracy: 0.8765
# Epoch 24/40
#  - 0s - loss: 0.3129 - accuracy: 0.8782
# Epoch 25/40
#  - 0s - loss: 0.3250 - accuracy: 0.8937
# Epoch 26/40
#  - 0s - loss: 0.3442 - accuracy: 0.8851
# Epoch 27/40
#  - 0s - loss: 0.3246 - accuracy: 0.8714
# Epoch 28/40
#  - 0s - loss: 0.2974 - accuracy: 0.8937
# Epoch 29/40
#  - 0s - loss: 0.3084 - accuracy: 0.8834
# Epoch 30/40
#  - 0s - loss: 0.3730 - accuracy: 0.8439
# Epoch 31/40
#  - 0s - loss: 0.3368 - accuracy: 0.8851
# Epoch 32/40
#  - 0s - loss: 0.3242 - accuracy: 0.8816
# Epoch 33/40
#  - 0s - loss: 0.3233 - accuracy: 0.8799
# Epoch 34/40
#  - 0s - loss: 0.3540 - accuracy: 0.8834
# Epoch 35/40
#  - 0s - loss: 0.3341 - accuracy: 0.8851
# Epoch 36/40
#  - 0s - loss: 0.3254 - accuracy: 0.8834
# Epoch 37/40
#  - 0s - loss: 0.2956 - accuracy: 0.8885
# Epoch 38/40
#  - 0s - loss: 0.3266 - accuracy: 0.8782
# Epoch 39/40
#  - 0s - loss: 0.3326 - accuracy: 0.8799
# Epoch 40/40
#  - 0s - loss: 0.3389 - accuracy: 0.8748
# 292/292 [==============================] - 0s 448us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.6382 - accuracy: 0.6849
# Epoch 2/40
#  - 0s - loss: 0.5397 - accuracy: 0.7603
# Epoch 3/40
#  - 0s - loss: 0.5306 - accuracy: 0.7740
# Epoch 4/40
#  - 0s - loss: 0.4686 - accuracy: 0.8236
# Epoch 5/40
#  - 0s - loss: 0.4347 - accuracy: 0.8168
# Epoch 6/40
#  - 0s - loss: 0.4212 - accuracy: 0.8253
# Epoch 7/40
#  - 0s - loss: 0.3932 - accuracy: 0.8613
# Epoch 8/40
#  - 0s - loss: 0.3757 - accuracy: 0.8390
# Epoch 9/40
#  - 0s - loss: 0.4100 - accuracy: 0.8408
# Epoch 10/40
#  - 0s - loss: 0.3999 - accuracy: 0.8545
# Epoch 11/40
#  - 0s - loss: 0.3625 - accuracy: 0.8545
# Epoch 12/40
#  - 0s - loss: 0.3669 - accuracy: 0.8733
# Epoch 13/40
#  - 0s - loss: 0.3936 - accuracy: 0.8527
# Epoch 14/40
#  - 0s - loss: 0.3647 - accuracy: 0.8664
# Epoch 15/40
#  - 0s - loss: 0.4032 - accuracy: 0.8545
# Epoch 16/40
#  - 0s - loss: 0.3814 - accuracy: 0.8784
# Epoch 17/40
#  - 0s - loss: 0.3560 - accuracy: 0.8682
# Epoch 18/40
#  - 0s - loss: 0.3451 - accuracy: 0.8887
# Epoch 19/40
#  - 0s - loss: 0.3375 - accuracy: 0.8664
# Epoch 20/40
#  - 0s - loss: 0.3507 - accuracy: 0.8682
# Epoch 21/40
#  - 0s - loss: 0.3848 - accuracy: 0.8545
# Epoch 22/40
#  - 0s - loss: 0.3450 - accuracy: 0.8699
# Epoch 23/40
#  - 0s - loss: 0.3284 - accuracy: 0.8836
# Epoch 24/40
#  - 0s - loss: 0.3469 - accuracy: 0.8733
# Epoch 25/40
#  - 0s - loss: 0.3351 - accuracy: 0.8767
# Epoch 26/40
#  - 0s - loss: 0.3653 - accuracy: 0.8647
# Epoch 27/40
#  - 0s - loss: 0.3135 - accuracy: 0.8921
# Epoch 28/40
#  - 0s - loss: 0.3433 - accuracy: 0.8750
# Epoch 29/40
#  - 0s - loss: 0.3657 - accuracy: 0.8682
# Epoch 30/40
#  - 0s - loss: 0.3214 - accuracy: 0.8818
# Epoch 31/40
#  - 0s - loss: 0.3510 - accuracy: 0.8699
# Epoch 32/40
#  - 0s - loss: 0.3411 - accuracy: 0.8801
# Epoch 33/40
#  - 0s - loss: 0.3415 - accuracy: 0.8750
# Epoch 34/40
#  - 0s - loss: 0.3639 - accuracy: 0.8545
# Epoch 35/40
#  - 0s - loss: 0.3301 - accuracy: 0.8750
# Epoch 36/40
#  - 0s - loss: 0.3435 - accuracy: 0.8750
# Epoch 37/40
#  - 0s - loss: 0.3236 - accuracy: 0.8716
# Epoch 38/40
#  - 0s - loss: 0.3254 - accuracy: 0.8870
# Epoch 39/40
#  - 0s - loss: 0.3595 - accuracy: 0.8716
# Epoch 40/40
#  - 0s - loss: 0.3294 - accuracy: 0.8870
# 291/291 [==============================] - 0s 447us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.6130 - accuracy: 0.7170
# Epoch 2/40
#  - 0s - loss: 0.5591 - accuracy: 0.7667
# Epoch 3/40
#  - 0s - loss: 0.5007 - accuracy: 0.7942
# Epoch 4/40
#  - 0s - loss: 0.4177 - accuracy: 0.8285
# Epoch 5/40
#  - 0s - loss: 0.3964 - accuracy: 0.8525
# Epoch 6/40
#  - 0s - loss: 0.4031 - accuracy: 0.8405
# Epoch 7/40
#  - 0s - loss: 0.3695 - accuracy: 0.8405
# Epoch 8/40
#  - 0s - loss: 0.3555 - accuracy: 0.8679
# Epoch 9/40
#  - 0s - loss: 0.3232 - accuracy: 0.8731
# Epoch 10/40
#  - 0s - loss: 0.3620 - accuracy: 0.8576
# Epoch 11/40
#  - 0s - loss: 0.3269 - accuracy: 0.8851
# Epoch 12/40
#  - 0s - loss: 0.3365 - accuracy: 0.8765
# Epoch 13/40
#  - 0s - loss: 0.3493 - accuracy: 0.8542
# Epoch 14/40
#  - 0s - loss: 0.3102 - accuracy: 0.8919
# Epoch 15/40
#  - 0s - loss: 0.3137 - accuracy: 0.8988
# Epoch 16/40
#  - 0s - loss: 0.3370 - accuracy: 0.8765
# Epoch 17/40
#  - 0s - loss: 0.3093 - accuracy: 0.8954
# Epoch 18/40
#  - 0s - loss: 0.3226 - accuracy: 0.8834
# Epoch 19/40
#  - 0s - loss: 0.3389 - accuracy: 0.8851
# Epoch 20/40
#  - 0s - loss: 0.3026 - accuracy: 0.8919
# Epoch 21/40
#  - 0s - loss: 0.3362 - accuracy: 0.8851
# Epoch 22/40
#  - 0s - loss: 0.2905 - accuracy: 0.8988
# Epoch 23/40
#  - 0s - loss: 0.3125 - accuracy: 0.8799
# Epoch 24/40
#  - 0s - loss: 0.3228 - accuracy: 0.8851
# Epoch 25/40
#  - 0s - loss: 0.2967 - accuracy: 0.8816
# Epoch 26/40
#  - 0s - loss: 0.3020 - accuracy: 0.8937
# Epoch 27/40
#  - 0s - loss: 0.3265 - accuracy: 0.8714
# Epoch 28/40
#  - 0s - loss: 0.3151 - accuracy: 0.8765
# Epoch 29/40
#  - 0s - loss: 0.2777 - accuracy: 0.8885
# Epoch 30/40
#  - 0s - loss: 0.2775 - accuracy: 0.8902
# Epoch 31/40
#  - 0s - loss: 0.3259 - accuracy: 0.8834
# Epoch 32/40
#  - 0s - loss: 0.3166 - accuracy: 0.8851
# Epoch 33/40
#  - 0s - loss: 0.3331 - accuracy: 0.8714
# Epoch 34/40
#  - 0s - loss: 0.3146 - accuracy: 0.8816
# Epoch 35/40
#  - 0s - loss: 0.3009 - accuracy: 0.8971
# Epoch 36/40
#  - 0s - loss: 0.3250 - accuracy: 0.8731
# Epoch 37/40
#  - 0s - loss: 0.3183 - accuracy: 0.8782
# Epoch 38/40
#  - 0s - loss: 0.3068 - accuracy: 0.8954
# Epoch 39/40
#  - 0s - loss: 0.2976 - accuracy: 0.8902
# Epoch 40/40
#  - 0s - loss: 0.2591 - accuracy: 0.9125
# 292/292 [==============================] - 0s 459us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.6347 - accuracy: 0.6964
# Epoch 2/40
#  - 0s - loss: 0.5948 - accuracy: 0.7479
# Epoch 3/40
#  - 0s - loss: 0.5084 - accuracy: 0.7856
# Epoch 4/40
#  - 0s - loss: 0.5027 - accuracy: 0.7839
# Epoch 5/40
#  - 0s - loss: 0.4211 - accuracy: 0.8353
# Epoch 6/40
#  - 0s - loss: 0.3689 - accuracy: 0.8525
# Epoch 7/40
#  - 0s - loss: 0.3598 - accuracy: 0.8611
# Epoch 8/40
#  - 0s - loss: 0.3487 - accuracy: 0.8714
# Epoch 9/40
#  - 0s - loss: 0.3672 - accuracy: 0.8542
# Epoch 10/40
#  - 0s - loss: 0.3611 - accuracy: 0.8696
# Epoch 11/40
#  - 0s - loss: 0.3565 - accuracy: 0.8645
# Epoch 12/40
#  - 0s - loss: 0.3780 - accuracy: 0.8611
# Epoch 13/40
#  - 0s - loss: 0.3294 - accuracy: 0.8696
# Epoch 14/40
#  - 0s - loss: 0.3477 - accuracy: 0.8731
# Epoch 15/40
#  - 0s - loss: 0.3557 - accuracy: 0.8679
# Epoch 16/40
#  - 0s - loss: 0.3450 - accuracy: 0.8731
# Epoch 17/40
#  - 0s - loss: 0.3330 - accuracy: 0.8731
# Epoch 18/40
#  - 0s - loss: 0.3475 - accuracy: 0.8611
# Epoch 19/40
#  - 0s - loss: 0.3455 - accuracy: 0.8782
# Epoch 20/40
#  - 0s - loss: 0.3552 - accuracy: 0.8662
# Epoch 21/40
#  - 0s - loss: 0.3367 - accuracy: 0.8559
# Epoch 22/40
#  - 0s - loss: 0.3530 - accuracy: 0.8714
# Epoch 23/40
#  - 0s - loss: 0.3333 - accuracy: 0.8834
# Epoch 24/40
#  - 0s - loss: 0.3104 - accuracy: 0.8851
# Epoch 25/40
#  - 0s - loss: 0.3134 - accuracy: 0.8816
# Epoch 26/40
#  - 0s - loss: 0.3179 - accuracy: 0.8816
# Epoch 27/40
#  - 0s - loss: 0.2966 - accuracy: 0.8868
# Epoch 28/40
#  - 0s - loss: 0.3430 - accuracy: 0.8782
# Epoch 29/40
#  - 0s - loss: 0.3080 - accuracy: 0.8885
# Epoch 30/40
#  - 0s - loss: 0.3405 - accuracy: 0.8799
# Epoch 31/40
#  - 0s - loss: 0.3347 - accuracy: 0.8868
# Epoch 32/40
#  - 0s - loss: 0.3263 - accuracy: 0.8782
# Epoch 33/40
#  - 0s - loss: 0.3320 - accuracy: 0.8834
# Epoch 34/40
#  - 0s - loss: 0.3068 - accuracy: 0.8885
# Epoch 35/40
#  - 0s - loss: 0.3125 - accuracy: 0.8902
# Epoch 36/40
#  - 0s - loss: 0.3064 - accuracy: 0.8971
# Epoch 37/40
#  - 0s - loss: 0.3133 - accuracy: 0.8851
# Epoch 38/40
#  - 0s - loss: 0.3042 - accuracy: 0.8868
# Epoch 39/40
#  - 0s - loss: 0.3168 - accuracy: 0.8816
# Epoch 40/40
#  - 0s - loss: 0.3340 - accuracy: 0.8748
# 292/292 [==============================] - 0s 454us/step
# activation: sigmoid, optimizer=adam
# Epoch 1/40
#  - 1s - loss: 0.6098 - accuracy: 0.7192
# Epoch 2/40
#  - 0s - loss: 0.6257 - accuracy: 0.7500
# Epoch 3/40
#  - 0s - loss: 0.5008 - accuracy: 0.7945
# Epoch 4/40
#  - 0s - loss: 0.4169 - accuracy: 0.8219
# Epoch 5/40
#  - 0s - loss: 0.4447 - accuracy: 0.8408
# Epoch 6/40
#  - 0s - loss: 0.4252 - accuracy: 0.8373
# Epoch 7/40
#  - 0s - loss: 0.4201 - accuracy: 0.8442
# Epoch 8/40
#  - 0s - loss: 0.4014 - accuracy: 0.8425
# Epoch 9/40
#  - 0s - loss: 0.4070 - accuracy: 0.8356
# Epoch 10/40
#  - 0s - loss: 0.3844 - accuracy: 0.8527
# Epoch 11/40
#  - 0s - loss: 0.3639 - accuracy: 0.8493
# Epoch 12/40
#  - 0s - loss: 0.3396 - accuracy: 0.8716
# Epoch 13/40
#  - 0s - loss: 0.3682 - accuracy: 0.8647
# Epoch 14/40
#  - 0s - loss: 0.4021 - accuracy: 0.8613
# Epoch 15/40
#  - 0s - loss: 0.3768 - accuracy: 0.8750
# Epoch 16/40
#  - 0s - loss: 0.3652 - accuracy: 0.8596
# Epoch 17/40
#  - 0s - loss: 0.3414 - accuracy: 0.8716
# Epoch 18/40
#  - 0s - loss: 0.3868 - accuracy: 0.8613
# Epoch 19/40
#  - 0s - loss: 0.3469 - accuracy: 0.8801
# Epoch 20/40
#  - 0s - loss: 0.3417 - accuracy: 0.8836
# Epoch 21/40
#  - 0s - loss: 0.3550 - accuracy: 0.8596
# Epoch 22/40
#  - 0s - loss: 0.3530 - accuracy: 0.8767
# Epoch 23/40
#  - 0s - loss: 0.3597 - accuracy: 0.8750
# Epoch 24/40
#  - 0s - loss: 0.3717 - accuracy: 0.8630
# Epoch 25/40
#  - 0s - loss: 0.3311 - accuracy: 0.8699
# Epoch 26/40
#  - 0s - loss: 0.3485 - accuracy: 0.8767
# Epoch 27/40
#  - 0s - loss: 0.3368 - accuracy: 0.8750
# Epoch 28/40
#  - 0s - loss: 0.3339 - accuracy: 0.8784
# Epoch 29/40
#  - 0s - loss: 0.3665 - accuracy: 0.8613
# Epoch 30/40
#  - 0s - loss: 0.3482 - accuracy: 0.8664
# Epoch 31/40
#  - 0s - loss: 0.3552 - accuracy: 0.8801
# Epoch 32/40
#  - 0s - loss: 0.3438 - accuracy: 0.8699
# Epoch 33/40
#  - 0s - loss: 0.3301 - accuracy: 0.8699
# Epoch 34/40
#  - 0s - loss: 0.3319 - accuracy: 0.8716
# Epoch 35/40
#  - 0s - loss: 0.3438 - accuracy: 0.8750
# Epoch 36/40
#  - 0s - loss: 0.3411 - accuracy: 0.8699
# Epoch 37/40
#  - 0s - loss: 0.3324 - accuracy: 0.8904
# Epoch 38/40
#  - 0s - loss: 0.3402 - accuracy: 0.8870
# Epoch 39/40
#  - 0s - loss: 0.3610 - accuracy: 0.8647
# Epoch 40/40
#  - 0s - loss: 0.3238 - accuracy: 0.8836
# 291/291 [==============================] - 0s 504us/step
# activation: sigmoid, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.6790 - accuracy: 0.7050
# Epoch 2/40
#  - 0s - loss: 0.4713 - accuracy: 0.7907
# Epoch 3/40
#  - 0s - loss: 0.4223 - accuracy: 0.8250
# Epoch 4/40
#  - 0s - loss: 0.4209 - accuracy: 0.8302
# Epoch 5/40
#  - 0s - loss: 0.3955 - accuracy: 0.8336
# Epoch 6/40
#  - 0s - loss: 0.3605 - accuracy: 0.8542
# Epoch 7/40
#  - 0s - loss: 0.3424 - accuracy: 0.8765
# Epoch 8/40
#  - 0s - loss: 0.3733 - accuracy: 0.8439
# Epoch 9/40
#  - 0s - loss: 0.3841 - accuracy: 0.8422
# Epoch 10/40
#  - 0s - loss: 0.3289 - accuracy: 0.8834
# Epoch 11/40
#  - 0s - loss: 0.3339 - accuracy: 0.8782
# Epoch 12/40
#  - 0s - loss: 0.3229 - accuracy: 0.8731
# Epoch 13/40
#  - 0s - loss: 0.3298 - accuracy: 0.8714
# Epoch 14/40
#  - 0s - loss: 0.3031 - accuracy: 0.8851
# Epoch 15/40
#  - 0s - loss: 0.3139 - accuracy: 0.8765
# Epoch 16/40
#  - 0s - loss: 0.3225 - accuracy: 0.8748
# Epoch 17/40
#  - 0s - loss: 0.3160 - accuracy: 0.8885
# Epoch 18/40
#  - 0s - loss: 0.2970 - accuracy: 0.8885
# Epoch 19/40
#  - 0s - loss: 0.2850 - accuracy: 0.8902
# Epoch 20/40
#  - 0s - loss: 0.3053 - accuracy: 0.8937
# Epoch 21/40
#  - 0s - loss: 0.3055 - accuracy: 0.8748
# Epoch 22/40
#  - 0s - loss: 0.3128 - accuracy: 0.8816
# Epoch 23/40
#  - 0s - loss: 0.3019 - accuracy: 0.8799
# Epoch 24/40
#  - 0s - loss: 0.2864 - accuracy: 0.9022
# Epoch 25/40
#  - 0s - loss: 0.3037 - accuracy: 0.8816
# Epoch 26/40
#  - 0s - loss: 0.3094 - accuracy: 0.8885
# Epoch 27/40
#  - 0s - loss: 0.2847 - accuracy: 0.8885
# Epoch 28/40
#  - 0s - loss: 0.2985 - accuracy: 0.8954
# Epoch 29/40
#  - 0s - loss: 0.2992 - accuracy: 0.8954
# Epoch 30/40
#  - 0s - loss: 0.2826 - accuracy: 0.8868
# Epoch 31/40
#  - 0s - loss: 0.3155 - accuracy: 0.8816
# Epoch 32/40
#  - 0s - loss: 0.2775 - accuracy: 0.8885
# Epoch 33/40
#  - 0s - loss: 0.3023 - accuracy: 0.8902
# Epoch 34/40
#  - 0s - loss: 0.2830 - accuracy: 0.9005
# Epoch 35/40
#  - 0s - loss: 0.2879 - accuracy: 0.8919
# Epoch 36/40
#  - 0s - loss: 0.3029 - accuracy: 0.8885
# Epoch 37/40
#  - 0s - loss: 0.3026 - accuracy: 0.8765
# Epoch 38/40
#  - 0s - loss: 0.2876 - accuracy: 0.8816
# Epoch 39/40
#  - 0s - loss: 0.2764 - accuracy: 0.8937
# Epoch 40/40
#  - 0s - loss: 0.2776 - accuracy: 0.8988
# 292/292 [==============================] - 0s 462us/step
# activation: sigmoid, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.6997 - accuracy: 0.7238
# Epoch 2/40
#  - 0s - loss: 0.4884 - accuracy: 0.7736
# Epoch 3/40
#  - 0s - loss: 0.4694 - accuracy: 0.8010
# Epoch 4/40
#  - 0s - loss: 0.4062 - accuracy: 0.8422
# Epoch 5/40
#  - 0s - loss: 0.3741 - accuracy: 0.8508
# Epoch 6/40
#  - 0s - loss: 0.3837 - accuracy: 0.8679
# Epoch 7/40
#  - 0s - loss: 0.3556 - accuracy: 0.8645
# Epoch 8/40
#  - 0s - loss: 0.3526 - accuracy: 0.8696
# Epoch 9/40
#  - 0s - loss: 0.3275 - accuracy: 0.8851
# Epoch 10/40
#  - 0s - loss: 0.3735 - accuracy: 0.8508
# Epoch 11/40
#  - 0s - loss: 0.3441 - accuracy: 0.8645
# Epoch 12/40
#  - 0s - loss: 0.3564 - accuracy: 0.8662
# Epoch 13/40
#  - 0s - loss: 0.3200 - accuracy: 0.8765
# Epoch 14/40
#  - 0s - loss: 0.3626 - accuracy: 0.8576
# Epoch 15/40
#  - 0s - loss: 0.3336 - accuracy: 0.8731
# Epoch 16/40
#  - 0s - loss: 0.3670 - accuracy: 0.8628
# Epoch 17/40
#  - 0s - loss: 0.2995 - accuracy: 0.8902
# Epoch 18/40
#  - 0s - loss: 0.3216 - accuracy: 0.8765
# Epoch 19/40
#  - 0s - loss: 0.3082 - accuracy: 0.8902
# Epoch 20/40
#  - 0s - loss: 0.3517 - accuracy: 0.8799
# Epoch 21/40
#  - 0s - loss: 0.3376 - accuracy: 0.8679
# Epoch 22/40
#  - 0s - loss: 0.3176 - accuracy: 0.8868
# Epoch 23/40
#  - 0s - loss: 0.3425 - accuracy: 0.8611
# Epoch 24/40
#  - 0s - loss: 0.3095 - accuracy: 0.8782
# Epoch 25/40
#  - 0s - loss: 0.3359 - accuracy: 0.8782
# Epoch 26/40
#  - 0s - loss: 0.3011 - accuracy: 0.8851
# Epoch 27/40
#  - 0s - loss: 0.3036 - accuracy: 0.8937
# Epoch 28/40
#  - 0s - loss: 0.3111 - accuracy: 0.8834
# Epoch 29/40
#  - 0s - loss: 0.3290 - accuracy: 0.8868
# Epoch 30/40
#  - 0s - loss: 0.3181 - accuracy: 0.8714
# Epoch 31/40
#  - 0s - loss: 0.3186 - accuracy: 0.8885
# Epoch 32/40
#  - 0s - loss: 0.3175 - accuracy: 0.8799
# Epoch 33/40
#  - 0s - loss: 0.3204 - accuracy: 0.8782
# Epoch 34/40
#  - 0s - loss: 0.3237 - accuracy: 0.8645
# Epoch 35/40
#  - 0s - loss: 0.3325 - accuracy: 0.8696
# Epoch 36/40
#  - 0s - loss: 0.3332 - accuracy: 0.8765
# Epoch 37/40
#  - 0s - loss: 0.3278 - accuracy: 0.8748
# Epoch 38/40
#  - 0s - loss: 0.3022 - accuracy: 0.8851
# Epoch 39/40
#  - 0s - loss: 0.3103 - accuracy: 0.8782
# Epoch 40/40
#  - 0s - loss: 0.3217 - accuracy: 0.8765
# 292/292 [==============================] - 0s 403us/step
# activation: sigmoid, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.6970 - accuracy: 0.6986
# Epoch 2/40
#  - 0s - loss: 0.5125 - accuracy: 0.7860
# Epoch 3/40
#  - 0s - loss: 0.4648 - accuracy: 0.8031
# Epoch 4/40
#  - 0s - loss: 0.4478 - accuracy: 0.8116
# Epoch 5/40
#  - 0s - loss: 0.4229 - accuracy: 0.8339
# Epoch 6/40
#  - 0s - loss: 0.3924 - accuracy: 0.8459
# Epoch 7/40
#  - 0s - loss: 0.3818 - accuracy: 0.8562
# Epoch 8/40
#  - 0s - loss: 0.4007 - accuracy: 0.8339
# Epoch 9/40
#  - 0s - loss: 0.3778 - accuracy: 0.8562
# Epoch 10/40
#  - 0s - loss: 0.3653 - accuracy: 0.8664
# Epoch 11/40
#  - 0s - loss: 0.3753 - accuracy: 0.8664
# Epoch 12/40
#  - 0s - loss: 0.3458 - accuracy: 0.8801
# Epoch 13/40
#  - 0s - loss: 0.3839 - accuracy: 0.8545
# Epoch 14/40
#  - 0s - loss: 0.3620 - accuracy: 0.8647
# Epoch 15/40
#  - 0s - loss: 0.3519 - accuracy: 0.8784
# Epoch 16/40
#  - 0s - loss: 0.3518 - accuracy: 0.8682
# Epoch 17/40
#  - 0s - loss: 0.3740 - accuracy: 0.8579
# Epoch 18/40
#  - 0s - loss: 0.3432 - accuracy: 0.8647
# Epoch 19/40
#  - 0s - loss: 0.3323 - accuracy: 0.8801
# Epoch 20/40
#  - 0s - loss: 0.3532 - accuracy: 0.8682
# Epoch 21/40
#  - 0s - loss: 0.3445 - accuracy: 0.8818
# Epoch 22/40
#  - 0s - loss: 0.3767 - accuracy: 0.8545
# Epoch 23/40
#  - 0s - loss: 0.3614 - accuracy: 0.8613
# Epoch 24/40
#  - 0s - loss: 0.3216 - accuracy: 0.8921
# Epoch 25/40
#  - 0s - loss: 0.3295 - accuracy: 0.8836
# Epoch 26/40
#  - 0s - loss: 0.3329 - accuracy: 0.8904
# Epoch 27/40
#  - 0s - loss: 0.3313 - accuracy: 0.8767
# Epoch 28/40
#  - 0s - loss: 0.3108 - accuracy: 0.8973
# Epoch 29/40
#  - 0s - loss: 0.3444 - accuracy: 0.8699
# Epoch 30/40
#  - 0s - loss: 0.3351 - accuracy: 0.8784
# Epoch 31/40
#  - 0s - loss: 0.3367 - accuracy: 0.8733
# Epoch 32/40
#  - 0s - loss: 0.3401 - accuracy: 0.8613
# Epoch 33/40
#  - 0s - loss: 0.3426 - accuracy: 0.8767
# Epoch 34/40
#  - 0s - loss: 0.3430 - accuracy: 0.8613
# Epoch 35/40
#  - 0s - loss: 0.3285 - accuracy: 0.8716
# Epoch 36/40
#  - 0s - loss: 0.3417 - accuracy: 0.8853
# Epoch 37/40
#  - 0s - loss: 0.3332 - accuracy: 0.8784
# Epoch 38/40
#  - 0s - loss: 0.3268 - accuracy: 0.8938
# Epoch 39/40
#  - 0s - loss: 0.3279 - accuracy: 0.8836
# Epoch 40/40
#  - 0s - loss: 0.3467 - accuracy: 0.8579
# 291/291 [==============================] - 0s 425us/step
# activation: sigmoid, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.7657 - accuracy: 0.7015
# Epoch 2/40
#  - 0s - loss: 0.4841 - accuracy: 0.7959
# Epoch 3/40
#  - 0s - loss: 0.4383 - accuracy: 0.8130
# Epoch 4/40
#  - 0s - loss: 0.4172 - accuracy: 0.8388
# Epoch 5/40
#  - 0s - loss: 0.3770 - accuracy: 0.8508
# Epoch 6/40
#  - 0s - loss: 0.3577 - accuracy: 0.8542
# Epoch 7/40
#  - 0s - loss: 0.3672 - accuracy: 0.8628
# Epoch 8/40
#  - 0s - loss: 0.3698 - accuracy: 0.8576
# Epoch 9/40
#  - 0s - loss: 0.3482 - accuracy: 0.8628
# Epoch 10/40
#  - 0s - loss: 0.3584 - accuracy: 0.8731
# Epoch 11/40
#  - 0s - loss: 0.3117 - accuracy: 0.8834
# Epoch 12/40
#  - 0s - loss: 0.3304 - accuracy: 0.8885
# Epoch 13/40
#  - 0s - loss: 0.3216 - accuracy: 0.8834
# Epoch 14/40
#  - 0s - loss: 0.3325 - accuracy: 0.8696
# Epoch 15/40
#  - 0s - loss: 0.3066 - accuracy: 0.8868
# Epoch 16/40
#  - 0s - loss: 0.3189 - accuracy: 0.8851
# Epoch 17/40
#  - 0s - loss: 0.3010 - accuracy: 0.8954
# Epoch 18/40
#  - 0s - loss: 0.3274 - accuracy: 0.8714
# Epoch 19/40
#  - 0s - loss: 0.3035 - accuracy: 0.8919
# Epoch 20/40
#  - 0s - loss: 0.3013 - accuracy: 0.8971
# Epoch 21/40
#  - 0s - loss: 0.3069 - accuracy: 0.8868
# Epoch 22/40
#  - 0s - loss: 0.3239 - accuracy: 0.8662
# Epoch 23/40
#  - 0s - loss: 0.2926 - accuracy: 0.9005
# Epoch 24/40
#  - 0s - loss: 0.3073 - accuracy: 0.8834
# Epoch 25/40
#  - 0s - loss: 0.3025 - accuracy: 0.8919
# Epoch 26/40
#  - 0s - loss: 0.2959 - accuracy: 0.8971
# Epoch 27/40
#  - 0s - loss: 0.2901 - accuracy: 0.8988
# Epoch 28/40
#  - 0s - loss: 0.3274 - accuracy: 0.8765
# Epoch 29/40
#  - 0s - loss: 0.2834 - accuracy: 0.8902
# Epoch 30/40
#  - 0s - loss: 0.2998 - accuracy: 0.8834
# Epoch 31/40
#  - 0s - loss: 0.2985 - accuracy: 0.8851
# Epoch 32/40
#  - 0s - loss: 0.2902 - accuracy: 0.8816
# Epoch 33/40
#  - 0s - loss: 0.2869 - accuracy: 0.8902
# Epoch 34/40
#  - 0s - loss: 0.2920 - accuracy: 0.8954
# Epoch 35/40
#  - 0s - loss: 0.2804 - accuracy: 0.8988
# Epoch 36/40
#  - 0s - loss: 0.2900 - accuracy: 0.8954
# Epoch 37/40
#  - 0s - loss: 0.2902 - accuracy: 0.8988
# Epoch 38/40
#  - 0s - loss: 0.2923 - accuracy: 0.9005
# Epoch 39/40
#  - 0s - loss: 0.2991 - accuracy: 0.8885
# Epoch 40/40
#  - 0s - loss: 0.2929 - accuracy: 0.8902
# 292/292 [==============================] - 0s 425us/step
# activation: sigmoid, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.7513 - accuracy: 0.7256
# Epoch 2/40
#  - 0s - loss: 0.4658 - accuracy: 0.8079
# Epoch 3/40
#  - 0s - loss: 0.4229 - accuracy: 0.8199
# Epoch 4/40
#  - 0s - loss: 0.3967 - accuracy: 0.8370
# Epoch 5/40
#  - 0s - loss: 0.3653 - accuracy: 0.8542
# Epoch 6/40
#  - 0s - loss: 0.3628 - accuracy: 0.8593
# Epoch 7/40
#  - 0s - loss: 0.3521 - accuracy: 0.8662
# Epoch 8/40
#  - 0s - loss: 0.3513 - accuracy: 0.8611
# Epoch 9/40
# ...
# Epoch 28/40
#  - 0s - loss: 0.3443 - accuracy: 0.8664
# Epoch 29/40
#  - 0s - loss: 0.3267 - accuracy: 0.8767
# Epoch 30/40
#  - 0s - loss: 0.3209 - accuracy: 0.8870
# Epoch 31/40
#  - 0s - loss: 0.3364 - accuracy: 0.8784
# Epoch 32/40
#  - 0s - loss: 0.3241 - accuracy: 0.8801
# Epoch 33/40
#  - 0s - loss: 0.3357 - accuracy: 0.8767
# Epoch 34/40
#  - 0s - loss: 0.3096 - accuracy: 0.8733
# Epoch 35/40
#  - 0s - loss: 0.3515 - accuracy: 0.8664
# Epoch 36/40
#  - 0s - loss: 0.3366 - accuracy: 0.8699
# Epoch 37/40
#  - 0s - loss: 0.3378 - accuracy: 0.8801
# Epoch 38/40
#  - 0s - loss: 0.3049 - accuracy: 0.8784
# Epoch 39/40
#  - 0s - loss: 0.3134 - accuracy: 0.8818
# Epoch 40/40
#  - 0s - loss: 0.3350 - accuracy: 0.8767
# 291/291 [==============================] - 0s 433us/step
# activation: tanh, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.8842 - accuracy: 0.7050
# Epoch 2/40
#  - 0s - loss: 0.4967 - accuracy: 0.7736
# Epoch 3/40
#  - 0s - loss: 0.4820 - accuracy: 0.7942
# Epoch 4/40
#  - 0s - loss: 0.4555 - accuracy: 0.8130
# Epoch 5/40
#  - 0s - loss: 0.3991 - accuracy: 0.8439
# Epoch 6/40
#  - 0s - loss: 0.4020 - accuracy: 0.8422
# Epoch 7/40
#  - 0s - loss: 0.3769 - accuracy: 0.8302
# Epoch 8/40
#  - 0s - loss: 0.3303 - accuracy: 0.8593
# Epoch 9/40
#  - 0s - loss: 0.3528 - accuracy: 0.8628
# Epoch 10/40
#  - 0s - loss: 0.3490 - accuracy: 0.8628
# Epoch 11/40
#  - 0s - loss: 0.3577 - accuracy: 0.8611
# Epoch 12/40
#  - 0s - loss: 0.3301 - accuracy: 0.8868
# Epoch 13/40
#  - 0s - loss: 0.3301 - accuracy: 0.8645
# Epoch 14/40
#  - 0s - loss: 0.3413 - accuracy: 0.8816
# Epoch 15/40
#  - 0s - loss: 0.3162 - accuracy: 0.8885
# Epoch 16/40
#  - 0s - loss: 0.2934 - accuracy: 0.8885
# Epoch 17/40
#  - 0s - loss: 0.3033 - accuracy: 0.8885
# Epoch 18/40
#  - 0s - loss: 0.2861 - accuracy: 0.9039
# Epoch 19/40
#  - 0s - loss: 0.3094 - accuracy: 0.8868
# Epoch 20/40
#  - 0s - loss: 0.2848 - accuracy: 0.8834
# Epoch 21/40
#  - 0s - loss: 0.3005 - accuracy: 0.8971
# Epoch 22/40
#  - 0s - loss: 0.2840 - accuracy: 0.8851
# Epoch 23/40
#  - 0s - loss: 0.2751 - accuracy: 0.9022
# Epoch 24/40
#  - 0s - loss: 0.3185 - accuracy: 0.8885
# Epoch 25/40
#  - 0s - loss: 0.3050 - accuracy: 0.8868
# Epoch 26/40
#  - 0s - loss: 0.2951 - accuracy: 0.8765
# Epoch 27/40
#  - 0s - loss: 0.2817 - accuracy: 0.8902
# Epoch 28/40
#  - 0s - loss: 0.2939 - accuracy: 0.8851
# Epoch 29/40
#  - 0s - loss: 0.3054 - accuracy: 0.8868
# Epoch 30/40
#  - 0s - loss: 0.2728 - accuracy: 0.8885
# Epoch 31/40
#  - 0s - loss: 0.2946 - accuracy: 0.8868
# Epoch 32/40
#  - 0s - loss: 0.2706 - accuracy: 0.8971
# Epoch 33/40
#  - 0s - loss: 0.2665 - accuracy: 0.8971
# Epoch 34/40
#  - 0s - loss: 0.2882 - accuracy: 0.8902
# Epoch 35/40
#  - 0s - loss: 0.3114 - accuracy: 0.8885
# Epoch 36/40
#  - 0s - loss: 0.2468 - accuracy: 0.9125
# Epoch 37/40
#  - 0s - loss: 0.3014 - accuracy: 0.8816
# Epoch 38/40
#  - 0s - loss: 0.2734 - accuracy: 0.8954
# Epoch 39/40
#  - 0s - loss: 0.2602 - accuracy: 0.9005
# Epoch 40/40
#  - 0s - loss: 0.2709 - accuracy: 0.9039
# 292/292 [==============================] - 0s 495us/step
# activation: tanh, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.9775 - accuracy: 0.6449
# Epoch 2/40
#  - 0s - loss: 0.5744 - accuracy: 0.7256
# Epoch 3/40
#  - 0s - loss: 0.5236 - accuracy: 0.7736
# Epoch 4/40
#  - 0s - loss: 0.5039 - accuracy: 0.7770
# Epoch 5/40
#  - 0s - loss: 0.4503 - accuracy: 0.8010
# Epoch 6/40
#  - 0s - loss: 0.4371 - accuracy: 0.8285
# Epoch 7/40
#  - 0s - loss: 0.3979 - accuracy: 0.8422
# Epoch 8/40
#  - 0s - loss: 0.3995 - accuracy: 0.8353
# Epoch 9/40
#  - 0s - loss: 0.4026 - accuracy: 0.8439
# Epoch 10/40
#  - 0s - loss: 0.3703 - accuracy: 0.8662
# Epoch 11/40
#  - 0s - loss: 0.3623 - accuracy: 0.8662
# Epoch 12/40
#  - 0s - loss: 0.3282 - accuracy: 0.8679
# Epoch 13/40
#  - 0s - loss: 0.3517 - accuracy: 0.8731
# Epoch 14/40
#  - 0s - loss: 0.3563 - accuracy: 0.8748
# Epoch 15/40
#  - 0s - loss: 0.3670 - accuracy: 0.8576
# Epoch 16/40
#  - 0s - loss: 0.3381 - accuracy: 0.8799
# Epoch 17/40
#  - 0s - loss: 0.3430 - accuracy: 0.8679
# Epoch 18/40
#  - 0s - loss: 0.3361 - accuracy: 0.8765
# Epoch 19/40
#  - 0s - loss: 0.3577 - accuracy: 0.8559
# Epoch 20/40
#  - 0s - loss: 0.3198 - accuracy: 0.8816
# Epoch 21/40
#  - 0s - loss: 0.3222 - accuracy: 0.8799
# Epoch 22/40
#  - 0s - loss: 0.2884 - accuracy: 0.9005
# Epoch 23/40
#  - 0s - loss: 0.3233 - accuracy: 0.8748
# Epoch 24/40
#  - 0s - loss: 0.3372 - accuracy: 0.8696
# Epoch 25/40
#  - 0s - loss: 0.2885 - accuracy: 0.8834
# Epoch 26/40
#  - 0s - loss: 0.3181 - accuracy: 0.8731
# Epoch 27/40
#  - 0s - loss: 0.3068 - accuracy: 0.8902
# Epoch 28/40
#  - 0s - loss: 0.3409 - accuracy: 0.8679
# Epoch 29/40
#  - 0s - loss: 0.2980 - accuracy: 0.8902
# Epoch 30/40
#  - 0s - loss: 0.3192 - accuracy: 0.8748
# Epoch 31/40
#  - 0s - loss: 0.3018 - accuracy: 0.8851
# Epoch 32/40
#  - 0s - loss: 0.3188 - accuracy: 0.8851
# Epoch 33/40
#  - 0s - loss: 0.3106 - accuracy: 0.8919
# Epoch 34/40
#  - 0s - loss: 0.2759 - accuracy: 0.9022
# Epoch 35/40
#  - 0s - loss: 0.3090 - accuracy: 0.8748
# Epoch 36/40
#  - 0s - loss: 0.3174 - accuracy: 0.8799
# Epoch 37/40
#  - 0s - loss: 0.3074 - accuracy: 0.8816
# Epoch 38/40
#  - 0s - loss: 0.2893 - accuracy: 0.8816
# Epoch 39/40
#  - 0s - loss: 0.3111 - accuracy: 0.8834
# Epoch 40/40
#  - 0s - loss: 0.3133 - accuracy: 0.8816
# 292/292 [==============================] - 0s 478us/step
# activation: tanh, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.9208 - accuracy: 0.6695
# Epoch 2/40
#  - 0s - loss: 0.6149 - accuracy: 0.7192
# Epoch 3/40
#  - 0s - loss: 0.5645 - accuracy: 0.7432
# Epoch 4/40
#  - 0s - loss: 0.5010 - accuracy: 0.7808
# Epoch 5/40
#  - 0s - loss: 0.4883 - accuracy: 0.8065
# Epoch 6/40
#  - 0s - loss: 0.4487 - accuracy: 0.7997
# Epoch 7/40
#  - 0s - loss: 0.4284 - accuracy: 0.8322
# Epoch 8/40
#  - 0s - loss: 0.4148 - accuracy: 0.8271
# Epoch 9/40
#  - 0s - loss: 0.3849 - accuracy: 0.8425
# Epoch 10/40
#  - 0s - loss: 0.4118 - accuracy: 0.8322
# Epoch 11/40
#  - 0s - loss: 0.3722 - accuracy: 0.8716
# Epoch 12/40
#  - 0s - loss: 0.3764 - accuracy: 0.8527
# Epoch 13/40
#  - 0s - loss: 0.3637 - accuracy: 0.8613
# Epoch 14/40
#  - 0s - loss: 0.3812 - accuracy: 0.8545
# Epoch 15/40
#  - 0s - loss: 0.3790 - accuracy: 0.8562
# Epoch 16/40
#  - 0s - loss: 0.3688 - accuracy: 0.8630
# Epoch 17/40
#  - 0s - loss: 0.3700 - accuracy: 0.8613
# Epoch 18/40
#  - 0s - loss: 0.3375 - accuracy: 0.8750
# Epoch 19/40
#  - 0s - loss: 0.3265 - accuracy: 0.8682
# Epoch 20/40
#  - 0s - loss: 0.3353 - accuracy: 0.8750
# Epoch 21/40
#  - 0s - loss: 0.3488 - accuracy: 0.8664
# Epoch 22/40
#  - 0s - loss: 0.3494 - accuracy: 0.8716
# Epoch 23/40
#  - 0s - loss: 0.3417 - accuracy: 0.8699
# Epoch 24/40
#  - 0s - loss: 0.3352 - accuracy: 0.8596
# Epoch 25/40
#  - 0s - loss: 0.3698 - accuracy: 0.8459
# Epoch 26/40
#  - 0s - loss: 0.3486 - accuracy: 0.8784
# Epoch 27/40
#  - 0s - loss: 0.3362 - accuracy: 0.8699
# Epoch 28/40
#  - 0s - loss: 0.3385 - accuracy: 0.8733
# Epoch 29/40
#  - 0s - loss: 0.3218 - accuracy: 0.8733
# Epoch 30/40
#  - 0s - loss: 0.3179 - accuracy: 0.8818
# Epoch 31/40
#  - 0s - loss: 0.3101 - accuracy: 0.8887
# Epoch 32/40
#  - 0s - loss: 0.3574 - accuracy: 0.8664
# Epoch 33/40
#  - 0s - loss: 0.3246 - accuracy: 0.8733
# Epoch 34/40
#  - 0s - loss: 0.3405 - accuracy: 0.8767
# Epoch 35/40
#  - 0s - loss: 0.3413 - accuracy: 0.8716
# Epoch 36/40
#  - 0s - loss: 0.3177 - accuracy: 0.8921
# Epoch 37/40
#  - 0s - loss: 0.3261 - accuracy: 0.8767
# Epoch 38/40
#  - 0s - loss: 0.3230 - accuracy: 0.8836
# Epoch 39/40
#  - 0s - loss: 0.3224 - accuracy: 0.8767
# Epoch 40/40
#  - 0s - loss: 0.3189 - accuracy: 0.8870
# 291/291 [==============================] - 0s 478us/step
# activation: tanh, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 1.1110 - accuracy: 0.6810
# Epoch 2/40
#  - 0s - loss: 0.5485 - accuracy: 0.7667
# Epoch 3/40
#  - 0s - loss: 0.4805 - accuracy: 0.7822
# Epoch 4/40
#  - 0s - loss: 0.4265 - accuracy: 0.8353
# Epoch 5/40
#  - 0s - loss: 0.3963 - accuracy: 0.8353
# Epoch 6/40
#  - 0s - loss: 0.3456 - accuracy: 0.8473
# Epoch 7/40
#  - 0s - loss: 0.3769 - accuracy: 0.8611
# Epoch 8/40
#  - 0s - loss: 0.3691 - accuracy: 0.8525
# Epoch 9/40
#  - 0s - loss: 0.3480 - accuracy: 0.8696
# Epoch 10/40
#  - 0s - loss: 0.3013 - accuracy: 0.8919
# Epoch 11/40
#  - 0s - loss: 0.3079 - accuracy: 0.8885
# Epoch 12/40
#  - 0s - loss: 0.3304 - accuracy: 0.8748
# Epoch 13/40
#  - 0s - loss: 0.3134 - accuracy: 0.8731
# Epoch 14/40
#  - 0s - loss: 0.3204 - accuracy: 0.8868
# Epoch 15/40
#  - 0s - loss: 0.3153 - accuracy: 0.8714
# Epoch 16/40
#  - 0s - loss: 0.3326 - accuracy: 0.8851
# Epoch 17/40
#  - 0s - loss: 0.3185 - accuracy: 0.8799
# Epoch 18/40
#  - 0s - loss: 0.2906 - accuracy: 0.8971
# Epoch 19/40
#  - 0s - loss: 0.2688 - accuracy: 0.9074
# Epoch 20/40
#  - 0s - loss: 0.2909 - accuracy: 0.9022
# Epoch 21/40
#  - 0s - loss: 0.2566 - accuracy: 0.9039
# Epoch 22/40
#  - 0s - loss: 0.2920 - accuracy: 0.8971
# Epoch 23/40
#  - 0s - loss: 0.2980 - accuracy: 0.8988
# Epoch 24/40
#  - 0s - loss: 0.3208 - accuracy: 0.8782
# Epoch 25/40
#  - 0s - loss: 0.2939 - accuracy: 0.8799
# Epoch 26/40
#  - 0s - loss: 0.3153 - accuracy: 0.8868
# Epoch 27/40
#  - 0s - loss: 0.2910 - accuracy: 0.8919
# Epoch 28/40
#  - 0s - loss: 0.2871 - accuracy: 0.9057
# Epoch 29/40
#  - 0s - loss: 0.2591 - accuracy: 0.9005
# Epoch 30/40
#  - 0s - loss: 0.2887 - accuracy: 0.8851
# Epoch 31/40
#  - 0s - loss: 0.2719 - accuracy: 0.9057
# Epoch 32/40
#  - 0s - loss: 0.2645 - accuracy: 0.9022
# Epoch 33/40
#  - 0s - loss: 0.2709 - accuracy: 0.9039
# Epoch 34/40
#  - 0s - loss: 0.2813 - accuracy: 0.9039
# Epoch 35/40
#  - 0s - loss: 0.2889 - accuracy: 0.8988
# Epoch 36/40
#  - 0s - loss: 0.2744 - accuracy: 0.9022
# Epoch 37/40
#  - 0s - loss: 0.2747 - accuracy: 0.9005
# Epoch 38/40
#  - 0s - loss: 0.2810 - accuracy: 0.8885
# Epoch 39/40
#  - 0s - loss: 0.2767 - accuracy: 0.8902
# Epoch 40/40
#  - 0s - loss: 0.2830 - accuracy: 0.8868
# 292/292 [==============================] - 0s 505us/step
# activation: tanh, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 1.1075 - accuracy: 0.6278
# Epoch 2/40
#  - 0s - loss: 0.5691 - accuracy: 0.7307
# Epoch 3/40
#  - 0s - loss: 0.5217 - accuracy: 0.7684
# Epoch 4/40
#  - 0s - loss: 0.4948 - accuracy: 0.7581
# Epoch 5/40
#  - 0s - loss: 0.4062 - accuracy: 0.8302
# Epoch 6/40
#  - 0s - loss: 0.3830 - accuracy: 0.8439
# Epoch 7/40
#  - 0s - loss: 0.3815 - accuracy: 0.8422
# Epoch 8/40
#  - 0s - loss: 0.3640 - accuracy: 0.8593
# Epoch 9/40
#  - 0s - loss: 0.3703 - accuracy: 0.8456
# Epoch 10/40
#  - 0s - loss: 0.3483 - accuracy: 0.8834
# Epoch 11/40
#  - 0s - loss: 0.3435 - accuracy: 0.8628
# Epoch 12/40
#  - 0s - loss: 0.3431 - accuracy: 0.8525
# Epoch 13/40
#  - 0s - loss: 0.3302 - accuracy: 0.8782
# Epoch 14/40
#  - 0s - loss: 0.3376 - accuracy: 0.8679
# Epoch 15/40
#  - 0s - loss: 0.3422 - accuracy: 0.8834
# Epoch 16/40
#  - 0s - loss: 0.3167 - accuracy: 0.8782
# Epoch 17/40
#  - 0s - loss: 0.3099 - accuracy: 0.8954
# Epoch 18/40
#  - 0s - loss: 0.3439 - accuracy: 0.8576
# Epoch 19/40
#  - 0s - loss: 0.3272 - accuracy: 0.8799
# Epoch 20/40
#  - 0s - loss: 0.3233 - accuracy: 0.8799
# Epoch 21/40
#  - 0s - loss: 0.2955 - accuracy: 0.8816
# Epoch 22/40
#  - 0s - loss: 0.3227 - accuracy: 0.8816
# Epoch 23/40
#  - 0s - loss: 0.2926 - accuracy: 0.8851
# Epoch 24/40
#  - 0s - loss: 0.3227 - accuracy: 0.8919
# Epoch 25/40
#  - 0s - loss: 0.3009 - accuracy: 0.8799
# Epoch 26/40
#  - 0s - loss: 0.2954 - accuracy: 0.8937
# Epoch 27/40
#  - 0s - loss: 0.3483 - accuracy: 0.8679
# Epoch 28/40
#  - 0s - loss: 0.3262 - accuracy: 0.8816
# Epoch 29/40
#  - 0s - loss: 0.3132 - accuracy: 0.8885
# Epoch 30/40
#  - 0s - loss: 0.2993 - accuracy: 0.8816
# Epoch 31/40
#  - 0s - loss: 0.3133 - accuracy: 0.8868
# Epoch 32/40
#  - 0s - loss: 0.2886 - accuracy: 0.9074
# Epoch 33/40
#  - 0s - loss: 0.3044 - accuracy: 0.8919
# Epoch 34/40
#  - 0s - loss: 0.2719 - accuracy: 0.8937
# Epoch 35/40
#  - 0s - loss: 0.2871 - accuracy: 0.8954
# Epoch 36/40
#  - 0s - loss: 0.2949 - accuracy: 0.8851
# Epoch 37/40
#  - 0s - loss: 0.2845 - accuracy: 0.8954
# Epoch 38/40
#  - 0s - loss: 0.3089 - accuracy: 0.8782
# Epoch 39/40
#  - 0s - loss: 0.2949 - accuracy: 0.9039
# Epoch 40/40
#  - 0s - loss: 0.2698 - accuracy: 0.9039
# 292/292 [==============================] - 0s 532us/step
# activation: tanh, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 1.1122 - accuracy: 0.6524
# Epoch 2/40
#  - 0s - loss: 0.6059 - accuracy: 0.7123
# Epoch 3/40
#  - 0s - loss: 0.5362 - accuracy: 0.7671
# Epoch 4/40
#  - 0s - loss: 0.4939 - accuracy: 0.7860
# Epoch 5/40
#  - 0s - loss: 0.4194 - accuracy: 0.8322
# Epoch 6/40
#  - 0s - loss: 0.4362 - accuracy: 0.8202
# Epoch 7/40
#  - 0s - loss: 0.4225 - accuracy: 0.8493
# Epoch 8/40
#  - 0s - loss: 0.4304 - accuracy: 0.8390
# Epoch 9/40
#  - 0s - loss: 0.4036 - accuracy: 0.8356
# Epoch 10/40
#  - 0s - loss: 0.3840 - accuracy: 0.8562
# Epoch 11/40
#  - 0s - loss: 0.3791 - accuracy: 0.8630
# Epoch 12/40
#  - 0s - loss: 0.3666 - accuracy: 0.8647
# Epoch 13/40
#  - 0s - loss: 0.3672 - accuracy: 0.8664
# Epoch 14/40
#  - 0s - loss: 0.3360 - accuracy: 0.8750
# Epoch 15/40
#  - 0s - loss: 0.3592 - accuracy: 0.8699
# Epoch 16/40
#  - 0s - loss: 0.3271 - accuracy: 0.8733
# Epoch 17/40
#  - 0s - loss: 0.3521 - accuracy: 0.8545
# Epoch 18/40
#  - 0s - loss: 0.3439 - accuracy: 0.8784
# Epoch 19/40
#  - 0s - loss: 0.3521 - accuracy: 0.8579
# Epoch 20/40
#  - 0s - loss: 0.3593 - accuracy: 0.8613
# Epoch 21/40
#  - 0s - loss: 0.3408 - accuracy: 0.8818
# Epoch 22/40
#  - 0s - loss: 0.3425 - accuracy: 0.8716
# Epoch 23/40
#  - 0s - loss: 0.3486 - accuracy: 0.8733
# Epoch 24/40
#  - 0s - loss: 0.3041 - accuracy: 0.8887
# Epoch 25/40
#  - 0s - loss: 0.3262 - accuracy: 0.8630
# Epoch 26/40
#  - 0s - loss: 0.3325 - accuracy: 0.8716
# Epoch 27/40
#  - 0s - loss: 0.3044 - accuracy: 0.8818
# Epoch 28/40
#  - 0s - loss: 0.3301 - accuracy: 0.8613
# Epoch 29/40
#  - 0s - loss: 0.2988 - accuracy: 0.8904
# Epoch 30/40
#  - 0s - loss: 0.3294 - accuracy: 0.8682
# Epoch 31/40
#  - 0s - loss: 0.3202 - accuracy: 0.8836
# Epoch 32/40
#  - 0s - loss: 0.3166 - accuracy: 0.8853
# Epoch 33/40
#  - 0s - loss: 0.3108 - accuracy: 0.8818
# Epoch 34/40
#  - 0s - loss: 0.2968 - accuracy: 0.8870
# Epoch 35/40
#  - 0s - loss: 0.3179 - accuracy: 0.8853
# Epoch 36/40
#  - 0s - loss: 0.3071 - accuracy: 0.8767
# Epoch 37/40
#  - 0s - loss: 0.3190 - accuracy: 0.8853
# Epoch 38/40
#  - 0s - loss: 0.3413 - accuracy: 0.8630
# Epoch 39/40
#  - 0s - loss: 0.3046 - accuracy: 0.8784
# Epoch 40/40
#  - 0s - loss: 0.3458 - accuracy: 0.8630
# 291/291 [==============================] - 0s 490us/step
# activation: relu, optimizer=adagrad
# Epoch 1/40
#  - 1s - loss: 0.7542 - accuracy: 0.6937
# Epoch 2/40
#  - 0s - loss: 0.5655 - accuracy: 0.7577
# Epoch 3/40
#  - 0s - loss: 0.5160 - accuracy: 0.7829
# Epoch 4/40
#  - 0s - loss: 0.4912 - accuracy: 0.8023
# Epoch 5/40
#  - 0s - loss: 0.4719 - accuracy: 0.7909
# Epoch 6/40
#  - 0s - loss: 0.4683 - accuracy: 0.8160
# Epoch 7/40
#  - 0s - loss: 0.4449 - accuracy: 0.8171
# Epoch 8/40
#  - 0s - loss: 0.4168 - accuracy: 0.8297
# Epoch 9/40
#  - 0s - loss: 0.4098 - accuracy: 0.8354
# Epoch 10/40
#  - 0s - loss: 0.3903 - accuracy: 0.8480
# Epoch 11/40
#  - 0s - loss: 0.4253 - accuracy: 0.8411
# Epoch 12/40
#  - 0s - loss: 0.3960 - accuracy: 0.8446
# Epoch 13/40
#  - 0s - loss: 0.3944 - accuracy: 0.8457
# Epoch 14/40
#  - 0s - loss: 0.3353 - accuracy: 0.8686
# Epoch 15/40
#  - 0s - loss: 0.3454 - accuracy: 0.8651
# Epoch 16/40
#  - 0s - loss: 0.3602 - accuracy: 0.8594
# Epoch 17/40
#  - 0s - loss: 0.3328 - accuracy: 0.8674
# Epoch 18/40
#  - 0s - loss: 0.3518 - accuracy: 0.8686
# Epoch 19/40
#  - 0s - loss: 0.3297 - accuracy: 0.8709
# Epoch 20/40
#  - 0s - loss: 0.3167 - accuracy: 0.8766
# Epoch 21/40
#  - 0s - loss: 0.3221 - accuracy: 0.8766
# Epoch 22/40
#  - 0s - loss: 0.3298 - accuracy: 0.8697
# Epoch 23/40
#  - 0s - loss: 0.3009 - accuracy: 0.8823
# Epoch 24/40
#  - 0s - loss: 0.3145 - accuracy: 0.8766
# Epoch 25/40
#  - 0s - loss: 0.3429 - accuracy: 0.8720
# Epoch 26/40
#  - 0s - loss: 0.2981 - accuracy: 0.8891
# Epoch 27/40
#  - 0s - loss: 0.3280 - accuracy: 0.8857
# Epoch 28/40
#  - 0s - loss: 0.3101 - accuracy: 0.8811
# Epoch 29/40
#  - 0s - loss: 0.3037 - accuracy: 0.8834
# Epoch 30/40
#  - 0s - loss: 0.3117 - accuracy: 0.8754
# Epoch 31/40
#  - 0s - loss: 0.2930 - accuracy: 0.8880
# Epoch 32/40
#  - 0s - loss: 0.2882 - accuracy: 0.8960
# Epoch 33/40
#  - 0s - loss: 0.2956 - accuracy: 0.8937
# Epoch 34/40
#  - 0s - loss: 0.3316 - accuracy: 0.8754
# Epoch 35/40
#  - 0s - loss: 0.3114 - accuracy: 0.8857
# Epoch 36/40
#  - 0s - loss: 0.2975 - accuracy: 0.8811
# Epoch 37/40
#  - 0s - loss: 0.3112 - accuracy: 0.8823
# Epoch 38/40
#  - 0s - loss: 0.3155 - accuracy: 0.8823
# Epoch 39/40
#  - 0s - loss: 0.2888 - accuracy: 0.8903
# Epoch 40/40
#  - 0s - loss: 0.2679 - accuracy: 0.8891
# ==============================
# 0.8285709818204244
# {'activation': 'relu', 'dropout': 0.5, 'input_dim': 316, 'optimizer': 'adagrad', 'out_dim': 500}

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8285709818204244
# {'activation': 'relu', 'dropout': 0.5, 'input_dim': 316, 'optimizer': 'adagrad', 'out_dim': 500}

# %%
model = create_model_5dim_layer_perceptron(len(x_train.columns), \
                                           activation=grid.best_params_['activation'], \
                                           optimizer=grid.best_params_['optimizer'], \
                                           out_dim=grid.best_params_['out_dim'], \
                                           dropout=grid.best_params_['dropout'])
fit = model.fit(x_train, y_train, epochs=28, batch_size=16, verbose=2)
# Out:
# activation: relu, optimizer=adagrad
# Epoch 1/28
#  - 1s - loss: 0.7690 - accuracy: 0.6949
# Epoch 2/28
#  - 0s - loss: 0.5298 - accuracy: 0.7851
# Epoch 3/28
#  - 0s - loss: 0.5225 - accuracy: 0.7840
# Epoch 4/28
#  - 0s - loss: 0.4691 - accuracy: 0.8114
# Epoch 5/28
#  - 0s - loss: 0.4843 - accuracy: 0.7977
# Epoch 6/28
#  - 0s - loss: 0.4245 - accuracy: 0.8206
# Epoch 7/28
#  - 0s - loss: 0.4114 - accuracy: 0.8343
# Epoch 8/28
#  - 0s - loss: 0.3799 - accuracy: 0.8480
# Epoch 9/28
#  - 0s - loss: 0.3894 - accuracy: 0.8617
# Epoch 10/28
#  - 0s - loss: 0.4164 - accuracy: 0.8457
# Epoch 11/28
#  - 0s - loss: 0.3957 - accuracy: 0.8526
# Epoch 12/28
#  - 0s - loss: 0.3791 - accuracy: 0.8571
# Epoch 13/28
#  - 0s - loss: 0.3536 - accuracy: 0.8629
# Epoch 14/28
#  - 0s - loss: 0.3738 - accuracy: 0.8560
# Epoch 15/28
#  - 0s - loss: 0.3518 - accuracy: 0.8560
# Epoch 16/28
#  - 0s - loss: 0.3695 - accuracy: 0.8720
# Epoch 17/28
#  - 0s - loss: 0.3225 - accuracy: 0.8709
# Epoch 18/28
#  - 0s - loss: 0.3328 - accuracy: 0.8766
# Epoch 19/28
#  - 0s - loss: 0.3522 - accuracy: 0.8629
# Epoch 20/28
#  - 0s - loss: 0.3273 - accuracy: 0.8709
# Epoch 21/28
#  - 0s - loss: 0.3342 - accuracy: 0.8789
# Epoch 22/28
#  - 0s - loss: 0.3087 - accuracy: 0.8731
# Epoch 23/28
#  - 0s - loss: 0.3394 - accuracy: 0.8800
# Epoch 24/28
#  - 0s - loss: 0.3081 - accuracy: 0.8754
# Epoch 25/28
#  - 0s - loss: 0.3204 - accuracy: 0.8731
# Epoch 26/28
#  - 0s - loss: 0.3111 - accuracy: 0.8834
# Epoch 27/28
#  - 0s - loss: 0.3060 - accuracy: 0.8811
# Epoch 28/28
#  - 0s - loss: 0.3112 - accuracy: 0.8903

# %%
# Predict
y_test_proba = model.predict(x_test)
# y_test_proba = grid.predict(x_test)
y_test = numpy.round(y_test_proba).astype(int)

# Combine the data frame of PassengerId and the result
df_output = pandas.concat([y_test_index, pandas.DataFrame(y_test, columns=['Survived'])], axis=1)

# Write result.csv to the current directory
df_output.to_csv('result.csv', index=False)

# Training
# model = create_model_5dim_layer_perceptron(grid.best_params_)

# %%
loss, acc=model.evaluate(x_test,y_test)
print(loss, acc)
# Out:
# 418/418 [==============================] - 0s 326us/step
# 0.1843599399738905 1.0
